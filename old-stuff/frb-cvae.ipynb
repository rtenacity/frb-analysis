# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
import re
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, adjusted_rand_score, confusion_matrix
from sklearn.mixture import GaussianMixture
from sklearn.manifold import TSNE
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV

# %%
frb_data = pd.read_csv('frb-data.csv')
frb_data['Repeater'] = frb_data['Repeater'].map({'Yes': 1, 'No': 0})
frb_data['Repeater'] = frb_data['Repeater'].fillna(0)
frb_data['Repeater'] = frb_data['Repeater'].astype(int)

# %%
# Select numerical columns that are relevant for VAE training
# features = ['Observing_band', 'MJD', 'GL', 'GB', 'SNR', 'DM_SNR', 'DM_SNR_err', 'DM_alig', 'DM_alig_err', 'Flux_density', 
#             'Flux_density_err', 'Width', 'Width_err', 'Freq_high', 'Freq_low', 'Freq_peak', 'Fluence', 'Fluence_err', 'Energy', 
#             'Energy_err', 'Polar_l', 'Polar_l_err', 'Polar_c', 'Polar_c_err', 'RM_syn', 'RM_syn_err', 'RM_QUfit', 'RM_QUfit_err', 'Scatt_t', 'Scatt_t_err', 'Scin_f', 'Scin_f_err',]

labels = frb_data['Repeater']

features = ['Observing_band', 'MJD', 'GL', 'GB', 'SNR', 'DM_SNR', 'DM_alig', 'Flux_density', 
             'Width', 'Freq_high', 'Freq_low', 'Freq_peak', 'Fluence', 'Energy', 
             'Polar_l',  'Polar_c', 'RM_syn',  'RM_QUfit', 'Scatt_t', 'Scin_f',]

# Function to clean numerical strings and convert to float
def clean_numeric_value(value):
    if type(value)==str and len(value.strip()) > 0:
        try:
            if '/' in value:
                value = value.split('/')[0]
            if '-' in value and not '+' in value:
                value = value.split('-')[0]
            if value[0] == '+':
                value = value[1:]
                value.split('/')
                value = value[0]
            if value[0] == '<':
                value = value[1:]
            if value[0] == '>':
                value = value[1:]
            return float(value)
        except:
            # print(f"Error: {value}")
            return np.nan
    try:
        return float(value)
    except:
        return np.nan

for col in frb_data[features].columns:
    frb_data[col] = frb_data[col].apply(clean_numeric_value)

# %%
frb_data_clean = frb_data[features].fillna(0)
scaler = StandardScaler()
frb_data_scaled = scaler.fit_transform(frb_data_clean)

train_data, val_data, train_labels, val_labels = train_test_split(
    frb_data_scaled, labels, test_size=0.2, random_state=42, stratify=labels
)

# Convert to PyTorch tensors
train_tensor = torch.tensor(train_data, dtype=torch.float32)
val_tensor = torch.tensor(val_data, dtype=torch.float32)
train_labels_tensor = torch.tensor(train_labels.values, dtype=torch.long)
val_labels_tensor = torch.tensor(val_labels.values, dtype=torch.long)

# Create datasets and dataloaders
batch_size = 64
train_dataset = TensorDataset(train_tensor, train_labels_tensor)
val_dataset = TensorDataset(val_tensor, val_labels_tensor)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class CVAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim, condition_dim=1, dropout_rate=0.3, activation=nn.LeakyReLU(0.1)):
        super(CVAE, self).__init__()
        
        self.activation = activation
        
        # Encoder: Input dimension is input_dim + condition_dim
        self.encoder = nn.Sequential(
            nn.Linear(input_dim + condition_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate)
        )
        
        self.fc_mu = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        
        # Decoder: Input dimension is latent_dim + condition_dim
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim + condition_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, input_dim)
        )

    def encode(self, x, c):
        # Concatenate data and condition along the feature dimension
        x = torch.cat([x, c], dim=1)
        h = self.encoder(x)
        return self.fc_mu(h), self.fc_logvar(h)
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std
    
    def decode(self, z, c):
        # Concatenate latent vector and condition
        z = torch.cat([z, c], dim=1)
        return self.decoder(z)
    
    def forward(self, x, c):
        mu, logvar = self.encode(x, c)
        z = self.reparameterize(mu, logvar)
        return self.decode(z, c), mu, logvar

# %%
reconstruction_loss_fn = torch.nn.MSELoss(reduction='sum')

def loss_function(recon_x, x, mean, logvar):
    recon_loss = reconstruction_loss_fn(recon_x, x)
    kl_loss = -0.5 * torch.sum(1 + logvar - mean.pow(2) - logvar.exp())
    return recon_loss + kl_loss, recon_loss, kl_loss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

input_dim = frb_data_scaled.shape[1]
hidden_dim = 256
latent_dim = 10
condition_dim = 1
patience = 4
num_epochs = 150


model = CVAE(input_dim, hidden_dim, latent_dim, condition_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=patience, verbose=True)
# Out:
# /home/rtenacity/Projects/frb-analysis/.frb/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
def train(epoch):
    model.train()
    train_loss = 0
    recon_loss = 0
    for batch_idx, (data, labels) in enumerate(train_loader):
        data = data.to(device)
        labels = labels.to(device).unsqueeze(1).float()  # Convert labels to (batch_size, 1) and make them float
        optimizer.zero_grad()
        
        recon_batch, mu, logvar = model(data, labels)  # Pass data and labels to model
        full_loss, recon_loss_val, kl_loss = loss_function(recon_batch, data, mu, logvar)
        full_loss.backward()
        train_loss += full_loss.item()
        recon_loss += recon_loss_val.item()
        optimizer.step()

        if batch_idx % 100 == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {full_loss.item() / len(data):.6f}')

    avg_loss = train_loss / len(train_loader.dataset)
    avg_recon_loss = recon_loss / len(train_loader.dataset)
    print(f'====> Epoch: {epoch} Average training loss: {avg_loss:.4f}, Reconstruction loss: {avg_recon_loss:.4f}')
    return avg_loss, avg_recon_loss

def validate():
    model.eval()
    val_loss = 0
    val_recon_loss = 0
    with torch.no_grad():
        for (data, labels) in val_loader:
            data = data.to(device)
            labels = labels.to(device).unsqueeze(1).float()  # Convert labels to (batch_size, 1)
            recon_batch, mu, logvar = model(data, labels)
            full_loss, recon_loss_val, kl_loss = loss_function(recon_batch, data, mu, logvar)
            val_loss += full_loss.item()
            val_recon_loss += recon_loss_val.item()

    avg_loss = val_loss / len(val_loader.dataset)
    avg_recon_loss = val_recon_loss / len(val_loader.dataset)
    print(f'====> Validation loss: {avg_loss:.4f}, Reconstruction loss: {avg_recon_loss:.4f}')
    return avg_loss, avg_recon_loss

def early_stopping(val_losses, patience):
    if len(val_losses) > patience:
        if all(val_losses[-i-1] <= val_losses[-i] for i in range(1, patience+1)):
            return True
    return False

best_loss = float('inf')
train_losses, val_losses, learning_rates = [], [], []
train_recon_losses, val_recon_losses = [], []

# Training loop with early stopping and learning rate scheduling
for epoch in range(1, num_epochs + 1):
    train_loss, train_recon_loss = train(epoch)
    val_loss, val_recon_loss = validate()
    
    # Track losses and learning rates
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    learning_rates.append(optimizer.param_groups[0]['lr'])
    train_recon_losses.append(train_recon_loss)
    val_recon_losses.append(val_recon_loss)
    
    # Learning rate scheduling
    scheduler.step(val_loss)
    
    # Save best model
    if val_loss < best_loss:
        best_loss = val_loss
        torch.save(model.state_dict(), 'vae_best.pth')
        print(f"New best model saved with validation loss: {best_loss:.4f}")
    
    # Early stopping
    if early_stopping(val_losses, patience):
        print(f"Early stopping triggered at epoch {epoch}")
        break

print("Training complete.")

# Plot the training and validation loss and learning rate
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))

# Plot training and validation loss
ax1.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
ax1.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
ax1.set_title('Training and Validation Loss over Epochs')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Average Loss')
ax1.legend()

# Plot learning rate
ax2.plot(range(1, len(learning_rates) + 1), learning_rates)
ax2.set_title('Learning Rate over Epochs')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Learning Rate')

# Plot the training and validation reconstruction loss
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(range(1, len(train_recon_losses) + 1), train_recon_losses, label='Training Reconstruction Loss')
ax.plot(range(1, len(val_recon_losses) + 1), val_recon_losses, label='Validation Reconstruction Loss')
ax.set_title('Training and Validation Reconstruction Loss over Epochs')
ax.set_xlabel('Epoch')
ax.set_ylabel('Average Reconstruction Loss')
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Train Epoch: 1 [0/6931 (0%)]	Loss: 23.099579
# Train Epoch: 1 [6400/6931 (92%)]	Loss: 11.978749
# ====> Epoch: 1 Average training loss: 20.2184, Reconstruction loss: 17.2803
# ====> Validation loss: 12.3208, Reconstruction loss: 9.4242
# New best model saved with validation loss: 12.3208
# Train Epoch: 2 [0/6931 (0%)]	Loss: 12.027792
# Train Epoch: 2 [6400/6931 (92%)]	Loss: 15.974492
# ====> Epoch: 2 Average training loss: 16.8964, Reconstruction loss: 13.4334
# ====> Validation loss: 11.0944, Reconstruction loss: 8.4883
# New best model saved with validation loss: 11.0944
# Train Epoch: 3 [0/6931 (0%)]	Loss: 9.649096
# Train Epoch: 3 [6400/6931 (92%)]	Loss: 13.121181
# ====> Epoch: 3 Average training loss: 15.5053, Reconstruction loss: 11.9779
# ====> Validation loss: 10.7944, Reconstruction loss: 8.2184
# New best model saved with validation loss: 10.7944
# Train Epoch: 4 [0/6931 (0%)]	Loss: 12.346608
# Train Epoch: 4 [6400/6931 (92%)]	Loss: 9.114544
# ====> Epoch: 4 Average training loss: 14.7131, Reconstruction loss: 11.1256
# ====> Validation loss: 10.0120, Reconstruction loss: 7.0081
# New best model saved with validation loss: 10.0120
# Train Epoch: 5 [0/6931 (0%)]	Loss: 11.306290
# Train Epoch: 5 [6400/6931 (92%)]	Loss: 12.395100
# ====> Epoch: 5 Average training loss: 14.4240, Reconstruction loss: 10.7764
# ====> Validation loss: 9.5580, Reconstruction loss: 6.6225
# New best model saved with validation loss: 9.5580
# Train Epoch: 6 [0/6931 (0%)]	Loss: 8.645731
# Train Epoch: 6 [6400/6931 (92%)]	Loss: 11.664913
# ====> Epoch: 6 Average training loss: 13.9407, Reconstruction loss: 10.3112
# ====> Validation loss: 9.4236, Reconstruction loss: 6.3197
# New best model saved with validation loss: 9.4236
# Train Epoch: 7 [0/6931 (0%)]	Loss: 9.975430
# Train Epoch: 7 [6400/6931 (92%)]	Loss: 10.952782
# ====> Epoch: 7 Average training loss: 13.6816, Reconstruction loss: 10.0481
# ====> Validation loss: 9.9844, Reconstruction loss: 6.4435
# Train Epoch: 8 [0/6931 (0%)]	Loss: 8.883989
# Train Epoch: 8 [6400/6931 (92%)]	Loss: 19.682838
# ====> Epoch: 8 Average training loss: 13.4172, Reconstruction loss: 9.8703
# ====> Validation loss: 9.2194, Reconstruction loss: 5.6229
# New best model saved with validation loss: 9.2194
# Train Epoch: 9 [0/6931 (0%)]	Loss: 9.380583
# Train Epoch: 9 [6400/6931 (92%)]	Loss: 142.878235
# ====> Epoch: 9 Average training loss: 13.0838, Reconstruction loss: 9.5398
# ====> Validation loss: 8.7193, Reconstruction loss: 5.6926
# New best model saved with validation loss: 8.7193
# Train Epoch: 10 [0/6931 (0%)]	Loss: 11.742008
# Train Epoch: 10 [6400/6931 (92%)]	Loss: 11.814545
# ====> Epoch: 10 Average training loss: 12.7680, Reconstruction loss: 9.1936
# ====> Validation loss: 8.6703, Reconstruction loss: 5.2711
# New best model saved with validation loss: 8.6703
# Train Epoch: 11 [0/6931 (0%)]	Loss: 13.158922
# Train Epoch: 11 [6400/6931 (92%)]	Loss: 23.493114
# ====> Epoch: 11 Average training loss: 12.6103, Reconstruction loss: 9.1109
# ====> Validation loss: 8.6168, Reconstruction loss: 5.5605
# New best model saved with validation loss: 8.6168
# Train Epoch: 12 [0/6931 (0%)]	Loss: 9.195795
# Train Epoch: 12 [6400/6931 (92%)]	Loss: 11.683523
# ====> Epoch: 12 Average training loss: 12.4715, Reconstruction loss: 8.8824
# ====> Validation loss: 8.4547, Reconstruction loss: 5.0388
# New best model saved with validation loss: 8.4547
# Train Epoch: 13 [0/6931 (0%)]	Loss: 8.189344
# Train Epoch: 13 [6400/6931 (92%)]	Loss: 7.886487
# ====> Epoch: 13 Average training loss: 12.3285, Reconstruction loss: 8.7488
# ====> Validation loss: 8.4106, Reconstruction loss: 4.8865
# New best model saved with validation loss: 8.4106
# Train Epoch: 14 [0/6931 (0%)]	Loss: 8.474724
# Train Epoch: 14 [6400/6931 (92%)]	Loss: 8.083015
# ====> Epoch: 14 Average training loss: 12.0032, Reconstruction loss: 8.4405
# ====> Validation loss: 8.0296, Reconstruction loss: 5.0408
# New best model saved with validation loss: 8.0296
# Train Epoch: 15 [0/6931 (0%)]	Loss: 8.694653
# Train Epoch: 15 [6400/6931 (92%)]	Loss: 12.763574
# ====> Epoch: 15 Average training loss: 12.0546, Reconstruction loss: 8.5067
# ====> Validation loss: 7.9013, Reconstruction loss: 4.6358
# New best model saved with validation loss: 7.9013
# Train Epoch: 16 [0/6931 (0%)]	Loss: 7.694626
# Train Epoch: 16 [6400/6931 (92%)]	Loss: 8.462405
# ====> Epoch: 16 Average training loss: 11.7660, Reconstruction loss: 8.2502
# ====> Validation loss: 7.8099, Reconstruction loss: 4.5719
# New best model saved with validation loss: 7.8099
# Train Epoch: 17 [0/6931 (0%)]	Loss: 10.147503
# Train Epoch: 17 [6400/6931 (92%)]	Loss: 8.240015
# ====> Epoch: 17 Average training loss: 11.6896, Reconstruction loss: 8.1940
# ====> Validation loss: 7.7142, Reconstruction loss: 4.4658
# New best model saved with validation loss: 7.7142
# Train Epoch: 18 [0/6931 (0%)]	Loss: 13.109208
# Train Epoch: 18 [6400/6931 (92%)]	Loss: 11.682074
# ====> Epoch: 18 Average training loss: 11.5558, Reconstruction loss: 8.0140
# ====> Validation loss: 7.6147, Reconstruction loss: 4.4651
# New best model saved with validation loss: 7.6147
# Train Epoch: 19 [0/6931 (0%)]	Loss: 7.587618
# Train Epoch: 19 [6400/6931 (92%)]	Loss: 17.303776
# ====> Epoch: 19 Average training loss: 11.6456, Reconstruction loss: 8.1675
# ====> Validation loss: 7.8058, Reconstruction loss: 4.5536
# Train Epoch: 20 [0/6931 (0%)]	Loss: 10.296850
# Train Epoch: 20 [6400/6931 (92%)]	Loss: 17.870743
# ====> Epoch: 20 Average training loss: 11.1887, Reconstruction loss: 7.6745
# ====> Validation loss: 8.1953, Reconstruction loss: 4.9668
# Train Epoch: 21 [0/6931 (0%)]	Loss: 6.668956
# Train Epoch: 21 [6400/6931 (92%)]	Loss: 8.633476
# ====> Epoch: 21 Average training loss: 11.3364, Reconstruction loss: 7.7678
# ====> Validation loss: 7.4537, Reconstruction loss: 4.1729
# New best model saved with validation loss: 7.4537
# Train Epoch: 22 [0/6931 (0%)]	Loss: 9.927174
# Train Epoch: 22 [6400/6931 (92%)]	Loss: 11.356026
# ====> Epoch: 22 Average training loss: 11.0638, Reconstruction loss: 7.5797
# ====> Validation loss: 7.5670, Reconstruction loss: 4.5501
# Train Epoch: 23 [0/6931 (0%)]	Loss: 9.018168
# Train Epoch: 23 [6400/6931 (92%)]	Loss: 10.383151
# ====> Epoch: 23 Average training loss: 10.9561, Reconstruction loss: 7.4452
# ====> Validation loss: 7.9437, Reconstruction loss: 4.5579
# Train Epoch: 24 [0/6931 (0%)]	Loss: 7.148549
# Train Epoch: 24 [6400/6931 (92%)]	Loss: 13.990203
# ====> Epoch: 24 Average training loss: 10.8594, Reconstruction loss: 7.4246
# ====> Validation loss: 7.8588, Reconstruction loss: 4.8704
# Train Epoch: 25 [0/6931 (0%)]	Loss: 11.273564
# Train Epoch: 25 [6400/6931 (92%)]	Loss: 22.880964
# ====> Epoch: 25 Average training loss: 10.8276, Reconstruction loss: 7.3300
# ====> Validation loss: 7.5410, Reconstruction loss: 4.7807
# Train Epoch: 26 [0/6931 (0%)]	Loss: 10.976044
# Train Epoch: 26 [6400/6931 (92%)]	Loss: 7.602324
# ====> Epoch: 26 Average training loss: 10.7413, Reconstruction loss: 7.2939
# ====> Validation loss: 7.4198, Reconstruction loss: 4.4624
# New best model saved with validation loss: 7.4198
# Train Epoch: 27 [0/6931 (0%)]	Loss: 9.442719
# Train Epoch: 27 [6400/6931 (92%)]	Loss: 8.268078
# ====> Epoch: 27 Average training loss: 10.5419, Reconstruction loss: 7.0947
# ====> Validation loss: 7.6978, Reconstruction loss: 5.0152
# Train Epoch: 28 [0/6931 (0%)]	Loss: 9.883396
# Train Epoch: 28 [6400/6931 (92%)]	Loss: 8.354034
# ====> Epoch: 28 Average training loss: 10.6547, Reconstruction loss: 7.1869
# ====> Validation loss: 8.4614, Reconstruction loss: 4.9435
# Train Epoch: 29 [0/6931 (0%)]	Loss: 7.717712
# Train Epoch: 29 [6400/6931 (92%)]	Loss: 8.345673
# ====> Epoch: 29 Average training loss: 10.4711, Reconstruction loss: 7.0486
# ====> Validation loss: 7.8671, Reconstruction loss: 4.7019
# Train Epoch: 30 [0/6931 (0%)]	Loss: 8.853343
# Train Epoch: 30 [6400/6931 (92%)]	Loss: 7.461839
# ====> Epoch: 30 Average training loss: 10.3306, Reconstruction loss: 6.8592
# ====> Validation loss: 7.9375, Reconstruction loss: 4.6919
# Train Epoch: 31 [0/6931 (0%)]	Loss: 7.282766
# Train Epoch: 31 [6400/6931 (92%)]	Loss: 10.159586
# ====> Epoch: 31 Average training loss: 10.3638, Reconstruction loss: 6.9082
# ====> Validation loss: 8.2088, Reconstruction loss: 5.2912
# Train Epoch: 32 [0/6931 (0%)]	Loss: 11.730638
# Train Epoch: 32 [6400/6931 (92%)]	Loss: 7.227403
# ====> Epoch: 32 Average training loss: 9.9539, Reconstruction loss: 6.5497
# ====> Validation loss: 7.3641, Reconstruction loss: 4.3064
# New best model saved with validation loss: 7.3641
# Train Epoch: 33 [0/6931 (0%)]	Loss: 9.593398
# Train Epoch: 33 [6400/6931 (92%)]	Loss: 9.556403
# ====> Epoch: 33 Average training loss: 9.8367, Reconstruction loss: 6.4483
# ====> Validation loss: 7.2040, Reconstruction loss: 4.0111
# New best model saved with validation loss: 7.2040
# Train Epoch: 34 [0/6931 (0%)]	Loss: 6.718389
# Train Epoch: 34 [6400/6931 (92%)]	Loss: 12.139975
# ====> Epoch: 34 Average training loss: 9.8793, Reconstruction loss: 6.5116
# ====> Validation loss: 7.4923, Reconstruction loss: 4.6841
# Train Epoch: 35 [0/6931 (0%)]	Loss: 7.291353
# Train Epoch: 35 [6400/6931 (92%)]	Loss: 8.425829
# ====> Epoch: 35 Average training loss: 9.6006, Reconstruction loss: 6.2299
# ====> Validation loss: 7.1704, Reconstruction loss: 4.5175
# New best model saved with validation loss: 7.1704
# Train Epoch: 36 [0/6931 (0%)]	Loss: 8.428010
# Train Epoch: 36 [6400/6931 (92%)]	Loss: 8.412237
# ====> Epoch: 36 Average training loss: 10.0282, Reconstruction loss: 6.6587
# ====> Validation loss: 7.7922, Reconstruction loss: 4.4935
# Train Epoch: 37 [0/6931 (0%)]	Loss: 8.480213
# Train Epoch: 37 [6400/6931 (92%)]	Loss: 8.335992
# ====> Epoch: 37 Average training loss: 9.7862, Reconstruction loss: 6.4275
# ====> Validation loss: 7.3331, Reconstruction loss: 4.4148
# Train Epoch: 38 [0/6931 (0%)]	Loss: 7.803200
# Train Epoch: 38 [6400/6931 (92%)]	Loss: 7.554345
# ====> Epoch: 38 Average training loss: 9.6444, Reconstruction loss: 6.2775
# ====> Validation loss: 7.9510, Reconstruction loss: 4.6662
# Train Epoch: 39 [0/6931 (0%)]	Loss: 9.229218
# Train Epoch: 39 [6400/6931 (92%)]	Loss: 8.063866
# ====> Epoch: 39 Average training loss: 9.7123, Reconstruction loss: 6.3453
# ====> Validation loss: 7.3862, Reconstruction loss: 4.2314
# Train Epoch: 40 [0/6931 (0%)]	Loss: 8.509682
# Train Epoch: 40 [6400/6931 (92%)]	Loss: 7.859427
# ====> Epoch: 40 Average training loss: 9.6236, Reconstruction loss: 6.2719
# ====> Validation loss: 7.1371, Reconstruction loss: 4.0745
# New best model saved with validation loss: 7.1371
# Train Epoch: 41 [0/6931 (0%)]	Loss: 6.844077
# Train Epoch: 41 [6400/6931 (92%)]	Loss: 12.958643
# ====> Epoch: 41 Average training loss: 9.4632, Reconstruction loss: 6.1204
# ====> Validation loss: 7.2574, Reconstruction loss: 4.1382
# Train Epoch: 42 [0/6931 (0%)]	Loss: 6.719972
# Train Epoch: 42 [6400/6931 (92%)]	Loss: 6.729309
# ====> Epoch: 42 Average training loss: 9.4725, Reconstruction loss: 6.1088
# ====> Validation loss: 7.4836, Reconstruction loss: 4.5111
# Train Epoch: 43 [0/6931 (0%)]	Loss: 7.430193
# Train Epoch: 43 [6400/6931 (92%)]	Loss: 7.022007
# ====> Epoch: 43 Average training loss: 9.6519, Reconstruction loss: 6.2967
# ====> Validation loss: 7.4344, Reconstruction loss: 4.6407
# Train Epoch: 44 [0/6931 (0%)]	Loss: 9.893399
# Train Epoch: 44 [6400/6931 (92%)]	Loss: 10.213495
# ====> Epoch: 44 Average training loss: 9.5298, Reconstruction loss: 6.1241
# ====> Validation loss: 7.1196, Reconstruction loss: 4.0931
# New best model saved with validation loss: 7.1196
# Train Epoch: 45 [0/6931 (0%)]	Loss: 7.258264
# Train Epoch: 45 [6400/6931 (92%)]	Loss: 7.292191
# ====> Epoch: 45 Average training loss: 9.4302, Reconstruction loss: 6.1088
# ====> Validation loss: 7.6851, Reconstruction loss: 5.0238
# Train Epoch: 46 [0/6931 (0%)]	Loss: 6.965575
# Train Epoch: 46 [6400/6931 (92%)]	Loss: 8.734040
# ====> Epoch: 46 Average training loss: 9.2320, Reconstruction loss: 5.8737
# ====> Validation loss: 6.8802, Reconstruction loss: 4.1135
# New best model saved with validation loss: 6.8802
# Train Epoch: 47 [0/6931 (0%)]	Loss: 13.137053
# Train Epoch: 47 [6400/6931 (92%)]	Loss: 18.521135
# ====> Epoch: 47 Average training loss: 9.4540, Reconstruction loss: 6.1177
# ====> Validation loss: 7.8025, Reconstruction loss: 4.6944
# Train Epoch: 48 [0/6931 (0%)]	Loss: 9.278204
# Train Epoch: 48 [6400/6931 (92%)]	Loss: 7.067384
# ====> Epoch: 48 Average training loss: 9.3118, Reconstruction loss: 5.9295
# ====> Validation loss: 7.8598, Reconstruction loss: 4.5507
# Train Epoch: 49 [0/6931 (0%)]	Loss: 8.057341
# Train Epoch: 49 [6400/6931 (92%)]	Loss: 9.494905
# ====> Epoch: 49 Average training loss: 9.1580, Reconstruction loss: 5.8705
# ====> Validation loss: 7.3402, Reconstruction loss: 4.3756
# Train Epoch: 50 [0/6931 (0%)]	Loss: 9.369621
# Train Epoch: 50 [6400/6931 (92%)]	Loss: 7.872396
# ====> Epoch: 50 Average training loss: 9.2457, Reconstruction loss: 5.8728
# ====> Validation loss: 6.9774, Reconstruction loss: 4.0899
# Train Epoch: 51 [0/6931 (0%)]	Loss: 9.527134
# Train Epoch: 51 [6400/6931 (92%)]	Loss: 6.772307
# ====> Epoch: 51 Average training loss: 9.2830, Reconstruction loss: 5.9335
# ====> Validation loss: 7.8276, Reconstruction loss: 4.6299
# Train Epoch: 52 [0/6931 (0%)]	Loss: 10.082940
# Train Epoch: 52 [6400/6931 (92%)]	Loss: 7.551251
# ====> Epoch: 52 Average training loss: 9.1590, Reconstruction loss: 5.7749
# ====> Validation loss: 7.0163, Reconstruction loss: 4.1258
# Train Epoch: 53 [0/6931 (0%)]	Loss: 9.530446
# Train Epoch: 53 [6400/6931 (92%)]	Loss: 7.870866
# ====> Epoch: 53 Average training loss: 9.1572, Reconstruction loss: 5.8276
# ====> Validation loss: 7.4433, Reconstruction loss: 4.2999
# Train Epoch: 54 [0/6931 (0%)]	Loss: 6.712980
# Train Epoch: 54 [6400/6931 (92%)]	Loss: 9.454736
# ====> Epoch: 54 Average training loss: 9.1000, Reconstruction loss: 5.7763
# ====> Validation loss: 7.3401, Reconstruction loss: 4.6575
# Train Epoch: 55 [0/6931 (0%)]	Loss: 7.636325
# Train Epoch: 55 [6400/6931 (92%)]	Loss: 7.726627
# ====> Epoch: 55 Average training loss: 9.1397, Reconstruction loss: 5.7975
# ====> Validation loss: 7.3391, Reconstruction loss: 4.1946
# Train Epoch: 56 [0/6931 (0%)]	Loss: 8.140553
# Train Epoch: 56 [6400/6931 (92%)]	Loss: 7.389343
# ====> Epoch: 56 Average training loss: 9.1272, Reconstruction loss: 5.7660
# ====> Validation loss: 7.5713, Reconstruction loss: 4.6298
# Train Epoch: 57 [0/6931 (0%)]	Loss: 7.718596
# Train Epoch: 57 [6400/6931 (92%)]	Loss: 10.969634
# ====> Epoch: 57 Average training loss: 9.1564, Reconstruction loss: 5.8485
# ====> Validation loss: 8.2897, Reconstruction loss: 6.1828
# Train Epoch: 58 [0/6931 (0%)]	Loss: 6.374591
# Train Epoch: 58 [6400/6931 (92%)]	Loss: 6.211927
# ====> Epoch: 58 Average training loss: 8.8638, Reconstruction loss: 5.5481
# ====> Validation loss: 7.7383, Reconstruction loss: 4.7058
# Train Epoch: 59 [0/6931 (0%)]	Loss: 8.314837
# Train Epoch: 59 [6400/6931 (92%)]	Loss: 6.673346
# ====> Epoch: 59 Average training loss: 9.1456, Reconstruction loss: 5.8059
# ====> Validation loss: 7.1445, Reconstruction loss: 4.3326
# Train Epoch: 60 [0/6931 (0%)]	Loss: 7.388759
# Train Epoch: 60 [6400/6931 (92%)]	Loss: 8.253703
# ====> Epoch: 60 Average training loss: 9.0205, Reconstruction loss: 5.7271
# ====> Validation loss: 7.4461, Reconstruction loss: 4.3400
# Train Epoch: 61 [0/6931 (0%)]	Loss: 5.646089
# Train Epoch: 61 [6400/6931 (92%)]	Loss: 7.133874
# ====> Epoch: 61 Average training loss: 8.9017, Reconstruction loss: 5.5473
# ====> Validation loss: 7.2525, Reconstruction loss: 4.1830
# Train Epoch: 62 [0/6931 (0%)]	Loss: 8.275591
# Train Epoch: 62 [6400/6931 (92%)]	Loss: 8.776073
# ====> Epoch: 62 Average training loss: 8.9235, Reconstruction loss: 5.6186
# ====> Validation loss: 7.2851, Reconstruction loss: 4.2829
# Train Epoch: 63 [0/6931 (0%)]	Loss: 6.815060
# Train Epoch: 63 [6400/6931 (92%)]	Loss: 11.742583
# ====> Epoch: 63 Average training loss: 9.0535, Reconstruction loss: 5.7552
# ====> Validation loss: 7.3912, Reconstruction loss: 4.5057
# Train Epoch: 64 [0/6931 (0%)]	Loss: 10.206343
# Train Epoch: 64 [6400/6931 (92%)]	Loss: 7.690151
# ====> Epoch: 64 Average training loss: 8.9416, Reconstruction loss: 5.6326
# ====> Validation loss: 7.1875, Reconstruction loss: 4.4492
# Train Epoch: 65 [0/6931 (0%)]	Loss: 8.566767
# Train Epoch: 65 [6400/6931 (92%)]	Loss: 14.642463
# ====> Epoch: 65 Average training loss: 9.0150, Reconstruction loss: 5.7116
# ====> Validation loss: 7.4604, Reconstruction loss: 4.3642
# Train Epoch: 66 [0/6931 (0%)]	Loss: 7.854560
# Train Epoch: 66 [6400/6931 (92%)]	Loss: 6.866434
# ====> Epoch: 66 Average training loss: 8.8886, Reconstruction loss: 5.5852
# ====> Validation loss: 7.1082, Reconstruction loss: 3.9784
# Train Epoch: 67 [0/6931 (0%)]	Loss: 6.999942
# Train Epoch: 67 [6400/6931 (92%)]	Loss: 17.031406
# ====> Epoch: 67 Average training loss: 8.8053, Reconstruction loss: 5.5399
# ====> Validation loss: 7.3104, Reconstruction loss: 4.4222
# Train Epoch: 68 [0/6931 (0%)]	Loss: 7.209249
# Train Epoch: 68 [6400/6931 (92%)]	Loss: 7.748708
# ====> Epoch: 68 Average training loss: 9.0150, Reconstruction loss: 5.7006
# ====> Validation loss: 7.2561, Reconstruction loss: 4.3619
# Train Epoch: 69 [0/6931 (0%)]	Loss: 6.152090
# Train Epoch: 69 [6400/6931 (92%)]	Loss: 8.820198
# ====> Epoch: 69 Average training loss: 8.7790, Reconstruction loss: 5.4494
# ====> Validation loss: 6.9964, Reconstruction loss: 4.0754
# Train Epoch: 70 [0/6931 (0%)]	Loss: 9.028097
# Train Epoch: 70 [6400/6931 (92%)]	Loss: 6.457476
# ====> Epoch: 70 Average training loss: 8.6594, Reconstruction loss: 5.3611
# ====> Validation loss: 7.6531, Reconstruction loss: 4.5110
# Train Epoch: 71 [0/6931 (0%)]	Loss: 11.187323
# Train Epoch: 71 [6400/6931 (92%)]	Loss: 8.658400
# ====> Epoch: 71 Average training loss: 8.8526, Reconstruction loss: 5.5440
# ====> Validation loss: 7.3479, Reconstruction loss: 4.2980
# Train Epoch: 72 [0/6931 (0%)]	Loss: 6.789005
# Train Epoch: 72 [6400/6931 (92%)]	Loss: 7.732694
# ====> Epoch: 72 Average training loss: 8.8601, Reconstruction loss: 5.5406
# ====> Validation loss: 7.0827, Reconstruction loss: 4.1044
# Train Epoch: 73 [0/6931 (0%)]	Loss: 7.377561
# Train Epoch: 73 [6400/6931 (92%)]	Loss: 8.983505
# ====> Epoch: 73 Average training loss: 8.7949, Reconstruction loss: 5.4874
# ====> Validation loss: 7.6429, Reconstruction loss: 5.1517
# Train Epoch: 74 [0/6931 (0%)]	Loss: 8.888316
# Train Epoch: 74 [6400/6931 (92%)]	Loss: 7.538339
# ====> Epoch: 74 Average training loss: 8.8870, Reconstruction loss: 5.5830
# ====> Validation loss: 7.0572, Reconstruction loss: 4.2960
# Train Epoch: 75 [0/6931 (0%)]	Loss: 6.917382
# Train Epoch: 75 [6400/6931 (92%)]	Loss: 7.675166
# ====> Epoch: 75 Average training loss: 8.7149, Reconstruction loss: 5.3693
# ====> Validation loss: 7.3398, Reconstruction loss: 4.4237
# Train Epoch: 76 [0/6931 (0%)]	Loss: 8.617983
# Train Epoch: 76 [6400/6931 (92%)]	Loss: 7.765724
# ====> Epoch: 76 Average training loss: 8.8749, Reconstruction loss: 5.5612
# ====> Validation loss: 7.2603, Reconstruction loss: 4.2677
# Train Epoch: 77 [0/6931 (0%)]	Loss: 8.981461
# Train Epoch: 77 [6400/6931 (92%)]	Loss: 7.192124
# ====> Epoch: 77 Average training loss: 8.8324, Reconstruction loss: 5.5410
# ====> Validation loss: 7.4321, Reconstruction loss: 4.3463
# Train Epoch: 78 [0/6931 (0%)]	Loss: 10.101720
# Train Epoch: 78 [6400/6931 (92%)]	Loss: 11.001652
# ====> Epoch: 78 Average training loss: 8.7620, Reconstruction loss: 5.4727
# ====> Validation loss: 7.6322, Reconstruction loss: 4.4834
# Train Epoch: 79 [0/6931 (0%)]	Loss: 8.990795
# Train Epoch: 79 [6400/6931 (92%)]	Loss: 8.408014
# ====> Epoch: 79 Average training loss: 8.7687, Reconstruction loss: 5.4601
# ====> Validation loss: 7.0513, Reconstruction loss: 4.3031
# Train Epoch: 80 [0/6931 (0%)]	Loss: 8.337926
# Train Epoch: 80 [6400/6931 (92%)]	Loss: 7.295684
# ====> Epoch: 80 Average training loss: 8.7048, Reconstruction loss: 5.3885
# ====> Validation loss: 6.9688, Reconstruction loss: 4.0460
# Train Epoch: 81 [0/6931 (0%)]	Loss: 11.115976
# Train Epoch: 81 [6400/6931 (92%)]	Loss: 7.824635
# ====> Epoch: 81 Average training loss: 8.8565, Reconstruction loss: 5.5384
# ====> Validation loss: 7.0968, Reconstruction loss: 4.1026
# Train Epoch: 82 [0/6931 (0%)]	Loss: 8.564043
# Train Epoch: 82 [6400/6931 (92%)]	Loss: 6.601903
# ====> Epoch: 82 Average training loss: 8.8218, Reconstruction loss: 5.4925
# ====> Validation loss: 7.3347, Reconstruction loss: 4.1676
# Train Epoch: 83 [0/6931 (0%)]	Loss: 7.313358
# Train Epoch: 83 [6400/6931 (92%)]	Loss: 10.873835
# ====> Epoch: 83 Average training loss: 8.8559, Reconstruction loss: 5.5903
# ====> Validation loss: 7.0540, Reconstruction loss: 4.0185
# Train Epoch: 84 [0/6931 (0%)]	Loss: 6.521129
# Train Epoch: 84 [6400/6931 (92%)]	Loss: 7.709048
# ====> Epoch: 84 Average training loss: 8.8170, Reconstruction loss: 5.5301
# ====> Validation loss: 7.3536, Reconstruction loss: 4.2064
# Train Epoch: 85 [0/6931 (0%)]	Loss: 6.572170
# Train Epoch: 85 [6400/6931 (92%)]	Loss: 9.534892
# ====> Epoch: 85 Average training loss: 8.8626, Reconstruction loss: 5.5641
# ====> Validation loss: 6.9727, Reconstruction loss: 4.3964
# Train Epoch: 86 [0/6931 (0%)]	Loss: 7.819379
# Train Epoch: 86 [6400/6931 (92%)]	Loss: 9.309601
# ====> Epoch: 86 Average training loss: 8.8229, Reconstruction loss: 5.5309
# ====> Validation loss: 7.2695, Reconstruction loss: 4.1239
# Train Epoch: 87 [0/6931 (0%)]	Loss: 6.134101
# Train Epoch: 87 [6400/6931 (92%)]	Loss: 7.629955
# ====> Epoch: 87 Average training loss: 8.8324, Reconstruction loss: 5.5043
# ====> Validation loss: 7.3579, Reconstruction loss: 4.2640
# Train Epoch: 88 [0/6931 (0%)]	Loss: 8.394795
# Train Epoch: 88 [6400/6931 (92%)]	Loss: 7.886418
# ====> Epoch: 88 Average training loss: 8.8606, Reconstruction loss: 5.5932
# ====> Validation loss: 7.0012, Reconstruction loss: 3.9922
# Train Epoch: 89 [0/6931 (0%)]	Loss: 6.569775
# Train Epoch: 89 [6400/6931 (92%)]	Loss: 7.153050
# ====> Epoch: 89 Average training loss: 8.9084, Reconstruction loss: 5.6036
# ====> Validation loss: 7.2181, Reconstruction loss: 4.2321
# Train Epoch: 90 [0/6931 (0%)]	Loss: 8.801576
# Train Epoch: 90 [6400/6931 (92%)]	Loss: 6.588083
# ====> Epoch: 90 Average training loss: 8.8780, Reconstruction loss: 5.5810
# ====> Validation loss: 7.2710, Reconstruction loss: 4.2441
# Train Epoch: 91 [0/6931 (0%)]	Loss: 6.947339
# Train Epoch: 91 [6400/6931 (92%)]	Loss: 12.717666
# ====> Epoch: 91 Average training loss: 8.9992, Reconstruction loss: 5.6951
# ====> Validation loss: 6.9690, Reconstruction loss: 4.0727
# Train Epoch: 92 [0/6931 (0%)]	Loss: 8.469479
# Train Epoch: 92 [6400/6931 (92%)]	Loss: 8.486328
# ====> Epoch: 92 Average training loss: 8.7577, Reconstruction loss: 5.4757
# ====> Validation loss: 7.5088, Reconstruction loss: 4.3233
# Train Epoch: 93 [0/6931 (0%)]	Loss: 8.753055
# Train Epoch: 93 [6400/6931 (92%)]	Loss: 7.104754
# ====> Epoch: 93 Average training loss: 8.7502, Reconstruction loss: 5.4453
# ====> Validation loss: 7.1122, Reconstruction loss: 4.1067
# Train Epoch: 94 [0/6931 (0%)]	Loss: 9.592548
# Train Epoch: 94 [6400/6931 (92%)]	Loss: 7.726260
# ====> Epoch: 94 Average training loss: 8.9476, Reconstruction loss: 5.6684
# ====> Validation loss: 7.5288, Reconstruction loss: 4.3155
# Train Epoch: 95 [0/6931 (0%)]	Loss: 6.697650
# Train Epoch: 95 [6400/6931 (92%)]	Loss: 8.901789
# ====> Epoch: 95 Average training loss: 8.7660, Reconstruction loss: 5.4680
# ====> Validation loss: 7.0931, Reconstruction loss: 4.0044
# Train Epoch: 96 [0/6931 (0%)]	Loss: 7.164620
# Train Epoch: 96 [6400/6931 (92%)]	Loss: 9.797312
# ====> Epoch: 96 Average training loss: 8.6828, Reconstruction loss: 5.3779
# ====> Validation loss: 7.2376, Reconstruction loss: 4.3710
# Train Epoch: 97 [0/6931 (0%)]	Loss: 10.188313
# Train Epoch: 97 [6400/6931 (92%)]	Loss: 6.032577
# ====> Epoch: 97 Average training loss: 8.9506, Reconstruction loss: 5.6222
# ====> Validation loss: 7.2526, Reconstruction loss: 4.4562
# Train Epoch: 98 [0/6931 (0%)]	Loss: 64.183228
# Train Epoch: 98 [6400/6931 (92%)]	Loss: 7.210887
# ====> Epoch: 98 Average training loss: 8.8324, Reconstruction loss: 5.5360
# ====> Validation loss: 7.1846, Reconstruction loss: 4.0943
# Train Epoch: 99 [0/6931 (0%)]	Loss: 6.017819
# Train Epoch: 99 [6400/6931 (92%)]	Loss: 9.737154
# ====> Epoch: 99 Average training loss: 8.8685, Reconstruction loss: 5.5555
# ====> Validation loss: 6.9431, Reconstruction loss: 4.0137
# Train Epoch: 100 [0/6931 (0%)]	Loss: 7.747522
# Train Epoch: 100 [6400/6931 (92%)]	Loss: 9.524342
# ====> Epoch: 100 Average training loss: 8.7501, Reconstruction loss: 5.4361
# ====> Validation loss: 7.1285, Reconstruction loss: 4.0134
# Train Epoch: 101 [0/6931 (0%)]	Loss: 7.632085
# Train Epoch: 101 [6400/6931 (92%)]	Loss: 7.587376
# ====> Epoch: 101 Average training loss: 8.8485, Reconstruction loss: 5.5197
# ====> Validation loss: 7.0272, Reconstruction loss: 4.1829
# Train Epoch: 102 [0/6931 (0%)]	Loss: 8.656372
# Train Epoch: 102 [6400/6931 (92%)]	Loss: 43.205887
# ====> Epoch: 102 Average training loss: 8.6109, Reconstruction loss: 5.3069
# ====> Validation loss: 7.1187, Reconstruction loss: 4.2795
# Train Epoch: 103 [0/6931 (0%)]	Loss: 6.392221
# Train Epoch: 103 [6400/6931 (92%)]	Loss: 6.832665
# ====> Epoch: 103 Average training loss: 8.7547, Reconstruction loss: 5.4568
# ====> Validation loss: 7.1738, Reconstruction loss: 4.1562
# Train Epoch: 104 [0/6931 (0%)]	Loss: 8.840834
# Train Epoch: 104 [6400/6931 (92%)]	Loss: 7.459270
# ====> Epoch: 104 Average training loss: 8.7904, Reconstruction loss: 5.4857
# ====> Validation loss: 7.0450, Reconstruction loss: 4.1198
# Train Epoch: 105 [0/6931 (0%)]	Loss: 10.421890
# Train Epoch: 105 [6400/6931 (92%)]	Loss: 7.686519
# ====> Epoch: 105 Average training loss: 8.8195, Reconstruction loss: 5.5309
# ====> Validation loss: 7.8653, Reconstruction loss: 4.4896
# Train Epoch: 106 [0/6931 (0%)]	Loss: 8.395945
# Train Epoch: 106 [6400/6931 (92%)]	Loss: 8.754025
# ====> Epoch: 106 Average training loss: 8.6943, Reconstruction loss: 5.3855
# ====> Validation loss: 7.1646, Reconstruction loss: 4.5503
# Train Epoch: 107 [0/6931 (0%)]	Loss: 7.844367
# Train Epoch: 107 [6400/6931 (92%)]	Loss: 12.166333
# ====> Epoch: 107 Average training loss: 8.7685, Reconstruction loss: 5.4856
# ====> Validation loss: 7.2402, Reconstruction loss: 4.2647
# Train Epoch: 108 [0/6931 (0%)]	Loss: 11.229131
# Train Epoch: 108 [6400/6931 (92%)]	Loss: 7.915532
# ====> Epoch: 108 Average training loss: 8.8462, Reconstruction loss: 5.5789
# ====> Validation loss: 7.1309, Reconstruction loss: 4.1382
# Train Epoch: 109 [0/6931 (0%)]	Loss: 9.239450
# Train Epoch: 109 [6400/6931 (92%)]	Loss: 7.522838
# ====> Epoch: 109 Average training loss: 8.9290, Reconstruction loss: 5.6232
# ====> Validation loss: 7.2306, Reconstruction loss: 4.1441
# Train Epoch: 110 [0/6931 (0%)]	Loss: 6.553685
# Train Epoch: 110 [6400/6931 (92%)]	Loss: 6.564240
# ====> Epoch: 110 Average training loss: 8.8148, Reconstruction loss: 5.5027
# ====> Validation loss: 7.1207, Reconstruction loss: 4.2046
# Train Epoch: 111 [0/6931 (0%)]	Loss: 6.582401
# Train Epoch: 111 [6400/6931 (92%)]	Loss: 7.777002
# ====> Epoch: 111 Average training loss: 8.8448, Reconstruction loss: 5.5459
# ====> Validation loss: 7.3829, Reconstruction loss: 4.2421
# Train Epoch: 112 [0/6931 (0%)]	Loss: 6.928808
# Train Epoch: 112 [6400/6931 (92%)]	Loss: 8.515668
# ====> Epoch: 112 Average training loss: 8.7599, Reconstruction loss: 5.4439
# ====> Validation loss: 7.0741, Reconstruction loss: 4.0214
# Train Epoch: 113 [0/6931 (0%)]	Loss: 11.563467
# Train Epoch: 113 [6400/6931 (92%)]	Loss: 17.533978
# ====> Epoch: 113 Average training loss: 8.7455, Reconstruction loss: 5.4425
# ====> Validation loss: 7.4509, Reconstruction loss: 4.2974
# Train Epoch: 114 [0/6931 (0%)]	Loss: 11.097635
# Train Epoch: 114 [6400/6931 (92%)]	Loss: 7.479480
# ====> Epoch: 114 Average training loss: 8.6913, Reconstruction loss: 5.4011
# ====> Validation loss: 6.9840, Reconstruction loss: 4.0204
# Train Epoch: 115 [0/6931 (0%)]	Loss: 8.520630
# Train Epoch: 115 [6400/6931 (92%)]	Loss: 6.976704
# ====> Epoch: 115 Average training loss: 8.8811, Reconstruction loss: 5.5793
# ====> Validation loss: 7.3036, Reconstruction loss: 4.2232
# Train Epoch: 116 [0/6931 (0%)]	Loss: 7.580681
# Train Epoch: 116 [6400/6931 (92%)]	Loss: 7.399244
# ====> Epoch: 116 Average training loss: 8.8486, Reconstruction loss: 5.5234
# ====> Validation loss: 7.2893, Reconstruction loss: 4.2781
# Train Epoch: 117 [0/6931 (0%)]	Loss: 6.851918
# Train Epoch: 117 [6400/6931 (92%)]	Loss: 6.782492
# ====> Epoch: 117 Average training loss: 8.8688, Reconstruction loss: 5.5351
# ====> Validation loss: 7.1734, Reconstruction loss: 4.3667
# Train Epoch: 118 [0/6931 (0%)]	Loss: 8.699887
# Train Epoch: 118 [6400/6931 (92%)]	Loss: 8.204304
# ====> Epoch: 118 Average training loss: 8.6640, Reconstruction loss: 5.3533
# ====> Validation loss: 7.0828, Reconstruction loss: 4.2213
# Train Epoch: 119 [0/6931 (0%)]	Loss: 12.255931
# Train Epoch: 119 [6400/6931 (92%)]	Loss: 7.086658
# ====> Epoch: 119 Average training loss: 8.7252, Reconstruction loss: 5.4274
# ====> Validation loss: 7.3353, Reconstruction loss: 4.2632
# Train Epoch: 120 [0/6931 (0%)]	Loss: 9.364424
# Train Epoch: 120 [6400/6931 (92%)]	Loss: 8.742729
# ====> Epoch: 120 Average training loss: 8.8025, Reconstruction loss: 5.5022
# ====> Validation loss: 7.0703, Reconstruction loss: 4.2147
# Train Epoch: 121 [0/6931 (0%)]	Loss: 9.151958
# Train Epoch: 121 [6400/6931 (92%)]	Loss: 8.845103
# ====> Epoch: 121 Average training loss: 8.7664, Reconstruction loss: 5.4779
# ====> Validation loss: 7.0524, Reconstruction loss: 4.1294
# Train Epoch: 122 [0/6931 (0%)]	Loss: 7.135527
# Train Epoch: 122 [6400/6931 (92%)]	Loss: 7.819187
# ====> Epoch: 122 Average training loss: 8.6989, Reconstruction loss: 5.3969
# ====> Validation loss: 7.3116, Reconstruction loss: 4.2645
# Train Epoch: 123 [0/6931 (0%)]	Loss: 6.530679
# Train Epoch: 123 [6400/6931 (92%)]	Loss: 9.024654
# ====> Epoch: 123 Average training loss: 8.7930, Reconstruction loss: 5.5138
# ====> Validation loss: 7.4070, Reconstruction loss: 4.3125
# Train Epoch: 124 [0/6931 (0%)]	Loss: 7.580217
# Train Epoch: 124 [6400/6931 (92%)]	Loss: 8.930449
# ====> Epoch: 124 Average training loss: 8.7128, Reconstruction loss: 5.4104
# ====> Validation loss: 7.1278, Reconstruction loss: 4.1086
# Train Epoch: 125 [0/6931 (0%)]	Loss: 7.747931
# Train Epoch: 125 [6400/6931 (92%)]	Loss: 7.783250
# ====> Epoch: 125 Average training loss: 8.8625, Reconstruction loss: 5.5523
# ====> Validation loss: 7.1961, Reconstruction loss: 4.1361
# Train Epoch: 126 [0/6931 (0%)]	Loss: 9.964403
# Train Epoch: 126 [6400/6931 (92%)]	Loss: 11.340944
# ====> Epoch: 126 Average training loss: 8.7938, Reconstruction loss: 5.5245
# ====> Validation loss: 7.0438, Reconstruction loss: 4.0396
# Train Epoch: 127 [0/6931 (0%)]	Loss: 8.434210
# Train Epoch: 127 [6400/6931 (92%)]	Loss: 9.477962
# ====> Epoch: 127 Average training loss: 8.8126, Reconstruction loss: 5.5403
# ====> Validation loss: 7.3285, Reconstruction loss: 4.2675
# Train Epoch: 128 [0/6931 (0%)]	Loss: 8.231586
# Train Epoch: 128 [6400/6931 (92%)]	Loss: 8.502812
# ====> Epoch: 128 Average training loss: 8.7005, Reconstruction loss: 5.3816
# ====> Validation loss: 7.2431, Reconstruction loss: 4.6002
# Train Epoch: 129 [0/6931 (0%)]	Loss: 6.792851
# Train Epoch: 129 [6400/6931 (92%)]	Loss: 11.903274
# ====> Epoch: 129 Average training loss: 8.7059, Reconstruction loss: 5.3922
# ====> Validation loss: 7.1220, Reconstruction loss: 3.9919
# Train Epoch: 130 [0/6931 (0%)]	Loss: 7.308139
# Train Epoch: 130 [6400/6931 (92%)]	Loss: 11.110787
# ====> Epoch: 130 Average training loss: 8.6012, Reconstruction loss: 5.2858
# ====> Validation loss: 7.1325, Reconstruction loss: 4.1791
# Train Epoch: 131 [0/6931 (0%)]	Loss: 7.738919
# Train Epoch: 131 [6400/6931 (92%)]	Loss: 6.350374
# ====> Epoch: 131 Average training loss: 8.7277, Reconstruction loss: 5.4274
# ====> Validation loss: 7.1302, Reconstruction loss: 4.4737
# Train Epoch: 132 [0/6931 (0%)]	Loss: 7.796710
# Train Epoch: 132 [6400/6931 (92%)]	Loss: 8.927009
# ====> Epoch: 132 Average training loss: 8.7314, Reconstruction loss: 5.4418
# ====> Validation loss: 7.1226, Reconstruction loss: 4.1186
# Train Epoch: 133 [0/6931 (0%)]	Loss: 7.248216
# Train Epoch: 133 [6400/6931 (92%)]	Loss: 7.095672
# ====> Epoch: 133 Average training loss: 8.8979, Reconstruction loss: 5.6104
# ====> Validation loss: 7.2136, Reconstruction loss: 4.4828
# Train Epoch: 134 [0/6931 (0%)]	Loss: 8.912536
# Train Epoch: 134 [6400/6931 (92%)]	Loss: 8.124470
# ====> Epoch: 134 Average training loss: 8.8486, Reconstruction loss: 5.5426
# ====> Validation loss: 7.4790, Reconstruction loss: 4.9789
# Train Epoch: 135 [0/6931 (0%)]	Loss: 8.916981
# Train Epoch: 135 [6400/6931 (92%)]	Loss: 11.227243
# ====> Epoch: 135 Average training loss: 8.8437, Reconstruction loss: 5.5130
# ====> Validation loss: 7.2010, Reconstruction loss: 4.1754
# Train Epoch: 136 [0/6931 (0%)]	Loss: 7.534226
# Train Epoch: 136 [6400/6931 (92%)]	Loss: 7.458933
# ====> Epoch: 136 Average training loss: 8.8576, Reconstruction loss: 5.5347
# ====> Validation loss: 7.4840, Reconstruction loss: 5.0438
# Train Epoch: 137 [0/6931 (0%)]	Loss: 8.409709
# Train Epoch: 137 [6400/6931 (92%)]	Loss: 6.599194
# ====> Epoch: 137 Average training loss: 8.8914, Reconstruction loss: 5.6019
# ====> Validation loss: 6.9957, Reconstruction loss: 4.1233
# Train Epoch: 138 [0/6931 (0%)]	Loss: 7.128751
# Train Epoch: 138 [6400/6931 (92%)]	Loss: 8.986147
# ====> Epoch: 138 Average training loss: 8.8148, Reconstruction loss: 5.5141
# ====> Validation loss: 7.0974, Reconstruction loss: 4.2322
# Train Epoch: 139 [0/6931 (0%)]	Loss: 7.850603
# Train Epoch: 139 [6400/6931 (92%)]	Loss: 6.035873
# ====> Epoch: 139 Average training loss: 8.7977, Reconstruction loss: 5.4952
# ====> Validation loss: 6.8870, Reconstruction loss: 3.9724
# Train Epoch: 140 [0/6931 (0%)]	Loss: 10.445170
# Train Epoch: 140 [6400/6931 (92%)]	Loss: 9.132099
# ====> Epoch: 140 Average training loss: 8.8388, Reconstruction loss: 5.5374
# ====> Validation loss: 6.9561, Reconstruction loss: 4.0495
# Train Epoch: 141 [0/6931 (0%)]	Loss: 10.566372
# Train Epoch: 141 [6400/6931 (92%)]	Loss: 17.182634
# ====> Epoch: 141 Average training loss: 8.9195, Reconstruction loss: 5.5818
# ====> Validation loss: 6.9443, Reconstruction loss: 3.9542
# Train Epoch: 142 [0/6931 (0%)]	Loss: 7.646355
# Train Epoch: 142 [6400/6931 (92%)]	Loss: 7.168151
# ====> Epoch: 142 Average training loss: 8.8365, Reconstruction loss: 5.5182
# ====> Validation loss: 7.0283, Reconstruction loss: 4.1029
# Train Epoch: 143 [0/6931 (0%)]	Loss: 8.655003
# Train Epoch: 143 [6400/6931 (92%)]	Loss: 18.323952
# ====> Epoch: 143 Average training loss: 8.8267, Reconstruction loss: 5.5362
# ====> Validation loss: 7.3386, Reconstruction loss: 4.2733
# Train Epoch: 144 [0/6931 (0%)]	Loss: 6.430723
# Train Epoch: 144 [6400/6931 (92%)]	Loss: 7.438509
# ====> Epoch: 144 Average training loss: 8.8788, Reconstruction loss: 5.5652
# ====> Validation loss: 7.3785, Reconstruction loss: 4.2848
# Train Epoch: 145 [0/6931 (0%)]	Loss: 7.180178
# Train Epoch: 145 [6400/6931 (92%)]	Loss: 6.820400
# ====> Epoch: 145 Average training loss: 8.8178, Reconstruction loss: 5.4956
# ====> Validation loss: 7.2736, Reconstruction loss: 4.2414
# Train Epoch: 146 [0/6931 (0%)]	Loss: 7.343887
# Train Epoch: 146 [6400/6931 (92%)]	Loss: 7.885663
# ====> Epoch: 146 Average training loss: 8.6785, Reconstruction loss: 5.3634
# ====> Validation loss: 7.1239, Reconstruction loss: 4.3540
# Train Epoch: 147 [0/6931 (0%)]	Loss: 8.783472
# Train Epoch: 147 [6400/6931 (92%)]	Loss: 7.366446
# ====> Epoch: 147 Average training loss: 8.7787, Reconstruction loss: 5.4939
# ====> Validation loss: 7.4583, Reconstruction loss: 4.4057
# Train Epoch: 148 [0/6931 (0%)]	Loss: 8.174207
# Train Epoch: 148 [6400/6931 (92%)]	Loss: 11.599057
# ====> Epoch: 148 Average training loss: 8.8957, Reconstruction loss: 5.5776
# ====> Validation loss: 7.3724, Reconstruction loss: 4.3436
# Train Epoch: 149 [0/6931 (0%)]	Loss: 8.860038
# Train Epoch: 149 [6400/6931 (92%)]	Loss: 7.582427
# ====> Epoch: 149 Average training loss: 8.7250, Reconstruction loss: 5.4193
# ====> Validation loss: 7.3072, Reconstruction loss: 4.1221
# Train Epoch: 150 [0/6931 (0%)]	Loss: 7.387049
# Train Epoch: 150 [6400/6931 (92%)]	Loss: 9.682504
# ====> Epoch: 150 Average training loss: 8.9543, Reconstruction loss: 5.6576
# ====> Validation loss: 7.3886, Reconstruction loss: 4.8490
# Training complete.

# %%
def get_latent_representations(model, dataloader, device):
    model.eval()
    latent_representations = []
    all_labels = []
    with torch.no_grad():
        for data, labels in dataloader:
            data = data.to(device)
            labels = labels.to(device).unsqueeze(1).float()  # Convert labels to (batch_size, 1)
            mu, _ = model.encode(data, labels)  # Pass labels to encoder
            latent_representations.append(mu.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
    return np.concatenate(latent_representations), np.concatenate(all_labels).flatten()

def visualize_latent_space_pca(latent_representations, labels):
    # Perform PCA
    pca = PCA(n_components=2)
    latent_2d = pca.fit_transform(latent_representations)

    # Plot the 2D latent space
    plt.figure(figsize=(12, 10))
    sns.scatterplot(x=latent_2d[:, 0], y=latent_2d[:, 1], hue=labels, palette='coolwarm', s=60, alpha=0.8)
    plt.title('PCA of Latent Space Representations')
    plt.xlabel('First Principal Component')
    plt.ylabel('Second Principal Component')
    plt.show()

# Extract latent representations and visualize
train_latent, train_labels_np = get_latent_representations(model, train_loader, device)
visualize_latent_space_pca(train_latent, train_labels_np)

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(train_latent)
train_clusters = kmeans.labels_

sil_score = silhouette_score(train_latent, train_clusters)
ari_score = adjusted_rand_score(train_labels_np, train_clusters)

print(f"KMeans Silhouette Score: {sil_score:.4f}")
print(f"KMeans Adjusted Rand Index: {ari_score:.4f}")

conf_matrix = confusion_matrix(train_labels_np, train_clusters)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# KMeans Silhouette Score: 0.3091
# KMeans Adjusted Rand Index: -0.0310
# Confusion Matrix:
# [[ 192  761]
#  [1871 4107]]

# %%
gmm = GaussianMixture(n_components=2, random_state=42)
gmm_clusters = gmm.fit_predict(train_latent)
sil_score = silhouette_score(train_latent, gmm_clusters)
ari_score = adjusted_rand_score(train_labels_np, gmm_clusters)
print(f"GMM Silhouette Score: {sil_score:.4f}")
print(f"GMM Adjusted Rand Index: {ari_score:.4f}")

conf_matrix = confusion_matrix(train_labels_np, gmm_clusters)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# GMM Silhouette Score: 0.3038
# GMM Adjusted Rand Index: -0.0181
# Confusion Matrix:
# [[ 235  718]
#  [1859 4119]]
