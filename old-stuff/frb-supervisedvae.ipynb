# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
import re
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, adjusted_rand_score, confusion_matrix
from sklearn.mixture import GaussianMixture
from sklearn.manifold import TSNE
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc
from sklearn.model_selection import GridSearchCV

# %%
frb_data = pd.read_csv('frb-data.csv')
frb_data['Repeater'] = frb_data['Repeater'].map({'Yes': 1, 'No': 0})
frb_data['Repeater'] = frb_data['Repeater'].fillna(0)
frb_data['Repeater'] = frb_data['Repeater'].astype(int)

# %%
# Select numerical columns that are relevant for VAE training
# features = ['Observing_band', 'MJD', 'GL', 'GB', 'SNR', 'DM_SNR', 'DM_SNR_err', 'DM_alig', 'DM_alig_err', 'Flux_density', 
#             'Flux_density_err', 'Width', 'Width_err', 'Freq_high', 'Freq_low', 'Freq_peak', 'Fluence', 'Fluence_err', 'Energy', 
#             'Energy_err', 'Polar_l', 'Polar_l_err', 'Polar_c', 'Polar_c_err', 'RM_syn', 'RM_syn_err', 'RM_QUfit', 'RM_QUfit_err', 'Scatt_t', 'Scatt_t_err', 'Scin_f', 'Scin_f_err',]

labels = frb_data['Repeater']

# Function to clean numerical strings and convert to float
def clean_numeric_value(value):
    if isinstance(value, str):
        value = value.strip()
        if not value:
            return np.nan
        try:
            # Remove special characters and split if necessary
            for char in ['/', '+', '<', '>', '~']:
                value = value.replace(char, '')
            if '-' in value:
                value = value.split('-')[0]
            return float(value)
        except ValueError:
            return np.nan
    try:
        return float(value)
    except (ValueError, TypeError):
        return np.nan
    
error_features = [
    'DM_SNR', 'DM_alig', 'Flux_density', 'Width', 'Fluence', 'Energy',
    'Polar_l', 'Polar_c', 'RM_syn', 'RM_QUfit', 'Scatt_t', 'Scin_f'
]
base_features = [
    'Observing_band', 'MJD', 'GL', 'GB', 'SNR', 'Freq_high',
    'Freq_low', 'Freq_peak', 'Repeater'
]

for feature in base_features + error_features:
    frb_data[feature] = frb_data[feature].apply(clean_numeric_value)

for feature in error_features:
    frb_data[f'{feature}_err'] = frb_data[f'{feature}_err'].apply(clean_numeric_value)

for feature in error_features:
    frb_data[f'{feature}_upper'] = frb_data[feature] + frb_data[f'{feature}_err']
    frb_data[f'{feature}_lower'] = frb_data[feature] - frb_data[f'{feature}_err']
    frb_data[f'{feature}_lower'] = frb_data[f'{feature}_lower'].clip(lower=0)

features = (
    base_features +
    error_features +
    [f'{feature}_upper' for feature in error_features] +
    [f'{feature}_lower' for feature in error_features]
)

# %%
frb_data_clean = frb_data[features].fillna(0)
scaler = StandardScaler()
frb_data_scaled = scaler.fit_transform(frb_data_clean)

# Retain the original indices
indices = frb_data_clean.index

# Split the data and retain indices
train_data, val_data, train_labels, val_labels, train_indices, val_indices = train_test_split(
    frb_data_scaled, labels, indices, test_size=0.2, random_state=42, stratify=labels
)

# Convert to PyTorch tensors
train_tensor = torch.tensor(train_data, dtype=torch.float32)
val_tensor = torch.tensor(val_data, dtype=torch.float32)
train_labels_tensor = torch.tensor(train_labels.values, dtype=torch.long)
val_labels_tensor = torch.tensor(val_labels.values, dtype=torch.long)

# Create datasets and dataloaders
batch_size = 64
train_dataset = TensorDataset(train_tensor, train_labels_tensor)
val_dataset = TensorDataset(val_tensor, val_labels_tensor)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class SupervisedVAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim, dropout_rate=0.3, activation=nn.LeakyReLU(0.1)):
        super(SupervisedVAE, self).__init__()
        
        self.activation = activation
        
        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate)
        )
        
        self.fc_mu = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        
        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, input_dim)
        )
        
        # Classification head for binary classification
        self.classifier = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim // 2),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim // 2, 1),
            nn.Sigmoid()
        )
    
    def encode(self, x):
        h = self.encoder(x)
        return self.fc_mu(h), self.fc_logvar(h)
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std
    
    def decode(self, z):
        return self.decoder(z)
    
    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        class_prob = self.classifier(z)
        return recon_x, mu, logvar, class_prob

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_dim = frb_data_scaled.shape[1]
hidden_dim = 256
latent_dim = 10
patience = 4
num_epochs = 150

model = SupervisedVAE(input_dim, hidden_dim, latent_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=patience, verbose=True)
# Out:
# /home/rtenacity/Projects/frb-analysis/.frb/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
reconstruction_loss_fn = nn.MSELoss(reduction='sum')
classification_loss_fn = nn.BCELoss() 

def loss_function(recon_x, x, mu, logvar, class_prob, labels):
    recon_loss = reconstruction_loss_fn(recon_x, x)
    kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    class_loss = classification_loss_fn(class_prob, labels.unsqueeze(1).float())  # Ensure labels match dimensions
    return recon_loss + kl_loss + class_loss, recon_loss, kl_loss, class_loss

# %%
def train_supervised(epoch):
    model.train()
    train_loss = 0
    recon_loss_total = 0
    kl_loss_total = 0
    classification_loss_total = 0
    
    correct = 0
    total = 0
    
    for batch_idx, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        optimizer.zero_grad()
        recon_batch, mu, logvar, class_logits = model(data)
        
        # Supervised loss function
        loss, recon_loss, kl_loss, classification_loss = loss_function(
            recon_batch, data, mu, logvar, class_logits, labels
        )
        
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        recon_loss_total += recon_loss.item()
        kl_loss_total += kl_loss.item()
        classification_loss_total += classification_loss.item()
        
        predicted = (class_logits > 0.5).float()
        total += labels.size(0)
        correct += (predicted.squeeze() == labels).sum().item()
        
        if batch_idx % 100 == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} '
                  f'({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item() / len(data):.6f}')
    
    # Calculate average loss and accuracy for the epoch
    avg_loss = train_loss / len(train_loader.dataset)
    avg_recon = recon_loss_total / len(train_loader.dataset)
    avg_kl = kl_loss_total / len(train_loader.dataset)
    avg_class = classification_loss_total / len(train_loader.dataset)
    accuracy = correct / total
    
    print(f'====> Epoch: {epoch} Average loss: {avg_loss:.4f}, Recon: {avg_recon:.4f}, KL: {avg_kl:.4f}, '
          f'Class: {avg_class:.4f}, Accuracy: {accuracy:.4f}')
    return avg_loss, avg_recon, avg_kl, avg_class, accuracy

def validate_supervised():
    model.eval()
    val_loss = 0
    recon_loss_total = 0
    kl_loss_total = 0
    classification_loss_total = 0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for data, labels in val_loader:
            data, labels = data.to(device), labels.to(device)
            recon_batch, mu, logvar, class_logits = model(data)
            
            loss, recon_loss, kl_loss, classification_loss = loss_function(
                recon_batch, data, mu, logvar, class_logits, labels
            )
            
            val_loss += loss.item()
            recon_loss_total += recon_loss.item()
            kl_loss_total += kl_loss.item()
            classification_loss_total += classification_loss.item()
            
            predicted = (class_logits > 0.5).float()
            total += labels.size(0)
            correct += (predicted.squeeze() == labels).sum().item()
    
    avg_loss = val_loss / len(val_loader.dataset)
    avg_recon = recon_loss_total / len(val_loader.dataset)
    avg_kl = kl_loss_total / len(val_loader.dataset)
    avg_class = classification_loss_total / len(val_loader.dataset)
    accuracy = correct / total
    
    print(f'====> Validation loss: {avg_loss:.4f}, Recon: {avg_recon:.4f}, KL: {avg_kl:.4f}, '
          f'Class: {avg_class:.4f}, Accuracy: {accuracy:.4f}')
    return avg_loss, avg_recon, avg_kl, avg_class, accuracy


best_val_accuracy = 0
best_loss = float('inf')
train_losses, val_losses = [], []
train_recon_losses, val_recon_losses = [], []
train_kl_losses, val_kl_losses = [], []
train_class_losses, val_class_losses = [], []
val_accuracies = []
learning_rates = []

def early_stopping(val_losses, patience):
    if len(val_losses) > patience:
        if all(val_losses[-i-1] <= val_losses[-i] for i in range(1, patience+1)):
            return True
    return False

for epoch in range(1, num_epochs + 1):
    # Training step
    train_loss, train_recon, train_kl, train_class, train_accuracy = train_supervised(epoch)
    
    # Validation step
    val_loss, val_recon, val_kl, val_class, val_accuracy = validate_supervised()
    
    # Track losses and accuracy
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_recon_losses.append(train_recon)
    val_recon_losses.append(val_recon)
    train_kl_losses.append(train_kl)
    val_kl_losses.append(val_kl)
    train_class_losses.append(train_class)
    val_class_losses.append(val_class)
    val_accuracies.append(val_accuracy)
    learning_rates.append(optimizer.param_groups[0]['lr'])
    
    # Scheduler step
    scheduler.step(val_loss)

    # Save the best model based on validation loss
    if val_loss < best_loss:
        best_loss = val_loss
        torch.save(model.state_dict(), 'supervised_vae_best_loss.pth')
        print(f"New best model saved with validation loss: {best_loss:.4f}")
    
    # Save the best model based on validation accuracy
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        torch.save(model.state_dict(), 'supervised_vae_best_acc.pth')
        print(f"New best model saved with validation accuracy: {best_val_accuracy:.4f}")
    
    # Early stopping
    if early_stopping(val_losses, patience):
        print(f"Early stopping triggered at epoch {epoch}")
        break

print("Training complete.")

# Plot training and validation loss, learning rates, and reconstruction loss
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))

# Plot training and validation loss
ax1.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
ax1.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
ax1.set_title('Training and Validation Loss over Epochs')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Average Loss')
ax1.legend()

# Plot learning rate
ax2.plot(range(1, len(learning_rates) + 1), learning_rates)
ax2.set_title('Learning Rate over Epochs')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Learning Rate')

# Plot the training and validation reconstruction loss
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(range(1, len(train_recon_losses) + 1), train_recon_losses, label='Training Reconstruction Loss')
ax.plot(range(1, len(val_recon_losses) + 1), val_recon_losses, label='Validation Reconstruction Loss')
ax.set_title('Training and Validation Reconstruction Loss over Epochs')
ax.set_xlabel('Epoch')
ax.set_ylabel('Average Reconstruction Loss')
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Train Epoch: 1 [0/6931 (0%)]	Loss: 43.477158
# Train Epoch: 1 [6400/6931 (92%)]	Loss: 161.684982
# ====> Epoch: 1 Average loss: 42.5021, Recon: 37.8433, KL: 4.6526, Class: 0.0062, Accuracy: 0.8481
# ====> Validation loss: 28.4998, Recon: 23.9086, KL: 4.5867, Class: 0.0045, Accuracy: 0.8782
# New best model saved with validation loss: 28.4998
# New best model saved with validation accuracy: 0.8782
# Train Epoch: 2 [0/6931 (0%)]	Loss: 41.727039
# Train Epoch: 2 [6400/6931 (92%)]	Loss: 18.954044
# ====> Epoch: 2 Average loss: 33.3358, Recon: 27.2471, KL: 6.0852, Class: 0.0035, Accuracy: 0.9107
# ====> Validation loss: 23.7797, Recon: 17.9061, KL: 5.8709, Class: 0.0028, Accuracy: 0.9336
# New best model saved with validation loss: 23.7797
# New best model saved with validation accuracy: 0.9336
# Train Epoch: 3 [0/6931 (0%)]	Loss: 23.685438
# Train Epoch: 3 [6400/6931 (92%)]	Loss: 139.534592
# ====> Epoch: 3 Average loss: 30.2957, Recon: 24.1706, KL: 6.1224, Class: 0.0027, Accuracy: 0.9357
# ====> Validation loss: 22.5268, Recon: 17.5289, KL: 4.9950, Class: 0.0029, Accuracy: 0.9359
# New best model saved with validation loss: 22.5268
# New best model saved with validation accuracy: 0.9359
# Train Epoch: 4 [0/6931 (0%)]	Loss: 16.091341
# Train Epoch: 4 [6400/6931 (92%)]	Loss: 84.739868
# ====> Epoch: 4 Average loss: 29.0961, Recon: 22.8388, KL: 6.2549, Class: 0.0024, Accuracy: 0.9430
# ====> Validation loss: 20.9825, Recon: 15.2896, KL: 5.6904, Class: 0.0024, Accuracy: 0.9515
# New best model saved with validation loss: 20.9825
# New best model saved with validation accuracy: 0.9515
# Train Epoch: 5 [0/6931 (0%)]	Loss: 62.378124
# Train Epoch: 5 [6400/6931 (92%)]	Loss: 18.781471
# ====> Epoch: 5 Average loss: 28.0336, Recon: 21.7541, KL: 6.2773, Class: 0.0022, Accuracy: 0.9476
# ====> Validation loss: 20.9822, Recon: 14.6792, KL: 6.3011, Class: 0.0020, Accuracy: 0.9585
# New best model saved with validation loss: 20.9822
# New best model saved with validation accuracy: 0.9585
# Train Epoch: 6 [0/6931 (0%)]	Loss: 15.843882
# Train Epoch: 6 [6400/6931 (92%)]	Loss: 25.776320
# ====> Epoch: 6 Average loss: 27.3728, Recon: 21.1669, KL: 6.2038, Class: 0.0021, Accuracy: 0.9491
# ====> Validation loss: 19.6659, Recon: 12.8261, KL: 6.8377, Class: 0.0021, Accuracy: 0.9463
# New best model saved with validation loss: 19.6659
# Train Epoch: 7 [0/6931 (0%)]	Loss: 15.024719
# Train Epoch: 7 [6400/6931 (92%)]	Loss: 14.567537
# ====> Epoch: 7 Average loss: 26.4540, Recon: 20.3379, KL: 6.1139, Class: 0.0021, Accuracy: 0.9455
# ====> Validation loss: 18.4132, Recon: 12.9517, KL: 5.4595, Class: 0.0020, Accuracy: 0.9567
# New best model saved with validation loss: 18.4132
# Train Epoch: 8 [0/6931 (0%)]	Loss: 22.546061
# Train Epoch: 8 [6400/6931 (92%)]	Loss: 37.196892
# ====> Epoch: 8 Average loss: 25.9952, Recon: 19.8276, KL: 6.1655, Class: 0.0021, Accuracy: 0.9494
# ====> Validation loss: 18.5743, Recon: 12.0696, KL: 6.5028, Class: 0.0018, Accuracy: 0.9654
# New best model saved with validation accuracy: 0.9654
# Train Epoch: 9 [0/6931 (0%)]	Loss: 18.711145
# Train Epoch: 9 [6400/6931 (92%)]	Loss: 17.475782
# ====> Epoch: 9 Average loss: 25.7021, Recon: 19.4992, KL: 6.2009, Class: 0.0020, Accuracy: 0.9528
# ====> Validation loss: 17.7871, Recon: 11.6196, KL: 6.1657, Class: 0.0019, Accuracy: 0.9544
# New best model saved with validation loss: 17.7871
# Train Epoch: 10 [0/6931 (0%)]	Loss: 16.265833
# Train Epoch: 10 [6400/6931 (92%)]	Loss: 22.419125
# ====> Epoch: 10 Average loss: 25.0617, Recon: 18.9715, KL: 6.0883, Class: 0.0020, Accuracy: 0.9492
# ====> Validation loss: 17.6311, Recon: 11.6812, KL: 5.9483, Class: 0.0016, Accuracy: 0.9642
# New best model saved with validation loss: 17.6311
# Train Epoch: 11 [0/6931 (0%)]	Loss: 19.001005
# Train Epoch: 11 [6400/6931 (92%)]	Loss: 17.043638
# ====> Epoch: 11 Average loss: 24.8352, Recon: 18.7170, KL: 6.1164, Class: 0.0019, Accuracy: 0.9551
# ====> Validation loss: 18.4205, Recon: 12.6237, KL: 5.7949, Class: 0.0019, Accuracy: 0.9550
# Train Epoch: 12 [0/6931 (0%)]	Loss: 14.216577
# Train Epoch: 12 [6400/6931 (92%)]	Loss: 14.503759
# ====> Epoch: 12 Average loss: 24.7304, Recon: 18.5464, KL: 6.1822, Class: 0.0018, Accuracy: 0.9593
# ====> Validation loss: 16.7730, Recon: 11.5907, KL: 5.1805, Class: 0.0018, Accuracy: 0.9573
# New best model saved with validation loss: 16.7730
# Train Epoch: 13 [0/6931 (0%)]	Loss: 15.544698
# Train Epoch: 13 [6400/6931 (92%)]	Loss: 17.541981
# ====> Epoch: 13 Average loss: 23.9390, Recon: 17.8912, KL: 6.0459, Class: 0.0019, Accuracy: 0.9553
# ====> Validation loss: 17.8949, Recon: 11.7648, KL: 6.1284, Class: 0.0017, Accuracy: 0.9619
# Train Epoch: 14 [0/6931 (0%)]	Loss: 17.126392
# Train Epoch: 14 [6400/6931 (92%)]	Loss: 16.812693
# ====> Epoch: 14 Average loss: 23.9767, Recon: 17.9235, KL: 6.0512, Class: 0.0020, Accuracy: 0.9531
# ====> Validation loss: 17.9339, Recon: 11.7132, KL: 6.2189, Class: 0.0018, Accuracy: 0.9625
# Train Epoch: 15 [0/6931 (0%)]	Loss: 15.383619
# Train Epoch: 15 [6400/6931 (92%)]	Loss: 12.796297
# ====> Epoch: 15 Average loss: 23.6199, Recon: 17.5883, KL: 6.0296, Class: 0.0019, Accuracy: 0.9527
# ====> Validation loss: 17.2080, Recon: 11.0379, KL: 6.1685, Class: 0.0015, Accuracy: 0.9688
# New best model saved with validation accuracy: 0.9688
# Train Epoch: 16 [0/6931 (0%)]	Loss: 13.847564
# Train Epoch: 16 [6400/6931 (92%)]	Loss: 19.053720
# ====> Epoch: 16 Average loss: 23.2163, Recon: 17.2261, KL: 5.9883, Class: 0.0018, Accuracy: 0.9566
# ====> Validation loss: 16.7764, Recon: 10.7377, KL: 6.0372, Class: 0.0015, Accuracy: 0.9665
# Train Epoch: 17 [0/6931 (0%)]	Loss: 15.371185
# Train Epoch: 17 [6400/6931 (92%)]	Loss: 15.339787
# ====> Epoch: 17 Average loss: 23.2040, Recon: 17.2453, KL: 5.9569, Class: 0.0018, Accuracy: 0.9548
# ====> Validation loss: 18.3799, Recon: 12.0303, KL: 6.3479, Class: 0.0017, Accuracy: 0.9642
# Train Epoch: 18 [0/6931 (0%)]	Loss: 157.106400
# Train Epoch: 18 [6400/6931 (92%)]	Loss: 16.794813
# ====> Epoch: 18 Average loss: 22.9857, Recon: 16.9976, KL: 5.9864, Class: 0.0017, Accuracy: 0.9592
# ====> Validation loss: 16.3507, Recon: 10.7386, KL: 5.6102, Class: 0.0018, Accuracy: 0.9619
# New best model saved with validation loss: 16.3507
# Train Epoch: 19 [0/6931 (0%)]	Loss: 14.228521
# Train Epoch: 19 [6400/6931 (92%)]	Loss: 24.485363
# ====> Epoch: 19 Average loss: 22.5214, Recon: 16.5495, KL: 5.9702, Class: 0.0017, Accuracy: 0.9613
# ====> Validation loss: 17.4071, Recon: 11.4600, KL: 5.9454, Class: 0.0017, Accuracy: 0.9573
# Train Epoch: 20 [0/6931 (0%)]	Loss: 17.131073
# Train Epoch: 20 [6400/6931 (92%)]	Loss: 17.966362
# ====> Epoch: 20 Average loss: 22.0853, Recon: 16.1656, KL: 5.9181, Class: 0.0017, Accuracy: 0.9602
# ====> Validation loss: 17.3058, Recon: 10.9560, KL: 6.3484, Class: 0.0013, Accuracy: 0.9740
# New best model saved with validation accuracy: 0.9740
# Train Epoch: 21 [0/6931 (0%)]	Loss: 13.178401
# Train Epoch: 21 [6400/6931 (92%)]	Loss: 14.374413
# ====> Epoch: 21 Average loss: 22.3361, Recon: 16.4625, KL: 5.8718, Class: 0.0018, Accuracy: 0.9563
# ====> Validation loss: 16.9500, Recon: 10.9871, KL: 5.9612, Class: 0.0016, Accuracy: 0.9625
# Train Epoch: 22 [0/6931 (0%)]	Loss: 13.920553
# Train Epoch: 22 [6400/6931 (92%)]	Loss: 14.807275
# ====> Epoch: 22 Average loss: 21.8673, Recon: 15.9524, KL: 5.9133, Class: 0.0016, Accuracy: 0.9647
# ====> Validation loss: 17.6783, Recon: 11.8727, KL: 5.8041, Class: 0.0016, Accuracy: 0.9665
# Train Epoch: 23 [0/6931 (0%)]	Loss: 135.165375
# Train Epoch: 23 [6400/6931 (92%)]	Loss: 16.444490
# ====> Epoch: 23 Average loss: 21.7639, Recon: 15.8331, KL: 5.9291, Class: 0.0017, Accuracy: 0.9579
# ====> Validation loss: 15.2271, Recon: 9.5195, KL: 5.7061, Class: 0.0015, Accuracy: 0.9642
# New best model saved with validation loss: 15.2271
# Train Epoch: 24 [0/6931 (0%)]	Loss: 14.081949
# Train Epoch: 24 [6400/6931 (92%)]	Loss: 27.081703
# ====> Epoch: 24 Average loss: 22.0249, Recon: 16.2243, KL: 5.7989, Class: 0.0017, Accuracy: 0.9608
# ====> Validation loss: 17.3803, Recon: 11.5252, KL: 5.8534, Class: 0.0016, Accuracy: 0.9694
# Train Epoch: 25 [0/6931 (0%)]	Loss: 13.747894
# Train Epoch: 25 [6400/6931 (92%)]	Loss: 14.871106
# ====> Epoch: 25 Average loss: 21.8397, Recon: 16.0181, KL: 5.8198, Class: 0.0017, Accuracy: 0.9592
# ====> Validation loss: 16.6697, Recon: 10.8242, KL: 5.8439, Class: 0.0015, Accuracy: 0.9677
# Train Epoch: 26 [0/6931 (0%)]	Loss: 17.683865
# Train Epoch: 26 [6400/6931 (92%)]	Loss: 23.988214
# ====> Epoch: 26 Average loss: 21.7428, Recon: 15.8818, KL: 5.8593, Class: 0.0017, Accuracy: 0.9612
# ====> Validation loss: 16.5520, Recon: 11.0945, KL: 5.4558, Class: 0.0017, Accuracy: 0.9608
# Train Epoch: 27 [0/6931 (0%)]	Loss: 17.518625
# Train Epoch: 27 [6400/6931 (92%)]	Loss: 21.653988
# ====> Epoch: 27 Average loss: 21.2306, Recon: 15.3344, KL: 5.8945, Class: 0.0017, Accuracy: 0.9619
# ====> Validation loss: 16.0393, Recon: 11.0630, KL: 4.9745, Class: 0.0018, Accuracy: 0.9527
# Train Epoch: 28 [0/6931 (0%)]	Loss: 14.272862
# Train Epoch: 28 [6400/6931 (92%)]	Loss: 12.519812
# ====> Epoch: 28 Average loss: 21.6162, Recon: 15.8365, KL: 5.7779, Class: 0.0019, Accuracy: 0.9554
# ====> Validation loss: 17.3312, Recon: 11.3717, KL: 5.9580, Class: 0.0015, Accuracy: 0.9683
# Train Epoch: 29 [0/6931 (0%)]	Loss: 15.363965
# Train Epoch: 29 [6400/6931 (92%)]	Loss: 13.329806
# ====> Epoch: 29 Average loss: 21.1145, Recon: 15.2619, KL: 5.8508, Class: 0.0017, Accuracy: 0.9586
# ====> Validation loss: 16.6473, Recon: 10.9464, KL: 5.6993, Class: 0.0016, Accuracy: 0.9665
# Train Epoch: 30 [0/6931 (0%)]	Loss: 16.474493
# Train Epoch: 30 [6400/6931 (92%)]	Loss: 21.347019
# ====> Epoch: 30 Average loss: 20.9073, Recon: 15.0295, KL: 5.8761, Class: 0.0016, Accuracy: 0.9642
# ====> Validation loss: 15.6130, Recon: 9.8321, KL: 5.7794, Class: 0.0015, Accuracy: 0.9683
# Train Epoch: 31 [0/6931 (0%)]	Loss: 17.301743
# Train Epoch: 31 [6400/6931 (92%)]	Loss: 17.284433
# ====> Epoch: 31 Average loss: 20.8864, Recon: 15.0717, KL: 5.8130, Class: 0.0017, Accuracy: 0.9592
# ====> Validation loss: 16.0998, Recon: 10.3617, KL: 5.7366, Class: 0.0014, Accuracy: 0.9706
# Train Epoch: 32 [0/6931 (0%)]	Loss: 13.056326
# Train Epoch: 32 [6400/6931 (92%)]	Loss: 21.652025
# ====> Epoch: 32 Average loss: 21.0314, Recon: 15.2305, KL: 5.7994, Class: 0.0016, Accuracy: 0.9636
# ====> Validation loss: 15.9553, Recon: 10.0761, KL: 5.8777, Class: 0.0015, Accuracy: 0.9677
# Train Epoch: 33 [0/6931 (0%)]	Loss: 12.735781
# Train Epoch: 33 [6400/6931 (92%)]	Loss: 16.739782
# ====> Epoch: 33 Average loss: 20.7591, Recon: 14.9654, KL: 5.7921, Class: 0.0016, Accuracy: 0.9631
# ====> Validation loss: 15.3526, Recon: 9.4303, KL: 5.9208, Class: 0.0014, Accuracy: 0.9677
# Train Epoch: 34 [0/6931 (0%)]	Loss: 22.199326
# Train Epoch: 34 [6400/6931 (92%)]	Loss: 13.637392
# ====> Epoch: 34 Average loss: 20.5380, Recon: 14.7837, KL: 5.7527, Class: 0.0017, Accuracy: 0.9609
# ====> Validation loss: 15.3154, Recon: 9.9668, KL: 5.3470, Class: 0.0015, Accuracy: 0.9671
# Train Epoch: 35 [0/6931 (0%)]	Loss: 18.479017
# Train Epoch: 35 [6400/6931 (92%)]	Loss: 16.433071
# ====> Epoch: 35 Average loss: 20.3169, Recon: 14.6147, KL: 5.7005, Class: 0.0016, Accuracy: 0.9605
# ====> Validation loss: 15.0026, Recon: 9.7858, KL: 5.2152, Class: 0.0016, Accuracy: 0.9590
# New best model saved with validation loss: 15.0026
# Train Epoch: 36 [0/6931 (0%)]	Loss: 16.316412
# Train Epoch: 36 [6400/6931 (92%)]	Loss: 18.180136
# ====> Epoch: 36 Average loss: 20.6928, Recon: 14.9471, KL: 5.7441, Class: 0.0016, Accuracy: 0.9605
# ====> Validation loss: 15.7248, Recon: 10.0836, KL: 5.6397, Class: 0.0016, Accuracy: 0.9671
# Train Epoch: 37 [0/6931 (0%)]	Loss: 17.982864
# Train Epoch: 37 [6400/6931 (92%)]	Loss: 14.391418
# ====> Epoch: 37 Average loss: 20.3938, Recon: 14.5560, KL: 5.8362, Class: 0.0016, Accuracy: 0.9618
# ====> Validation loss: 16.1807, Recon: 10.2712, KL: 5.9081, Class: 0.0014, Accuracy: 0.9700
# Train Epoch: 38 [0/6931 (0%)]	Loss: 18.965466
# Train Epoch: 38 [6400/6931 (92%)]	Loss: 13.977886
# ====> Epoch: 38 Average loss: 20.5653, Recon: 14.7935, KL: 5.7701, Class: 0.0017, Accuracy: 0.9609
# ====> Validation loss: 15.6052, Recon: 10.0276, KL: 5.5763, Class: 0.0014, Accuracy: 0.9660
# Train Epoch: 39 [0/6931 (0%)]	Loss: 12.779215
# Train Epoch: 39 [6400/6931 (92%)]	Loss: 16.975695
# ====> Epoch: 39 Average loss: 20.5173, Recon: 14.7744, KL: 5.7413, Class: 0.0016, Accuracy: 0.9602
# ====> Validation loss: 15.4336, Recon: 9.9510, KL: 5.4809, Class: 0.0016, Accuracy: 0.9631
# Train Epoch: 40 [0/6931 (0%)]	Loss: 16.150257
# Train Epoch: 40 [6400/6931 (92%)]	Loss: 12.881194
# ====> Epoch: 40 Average loss: 20.5475, Recon: 14.8470, KL: 5.6990, Class: 0.0015, Accuracy: 0.9636
# ====> Validation loss: 15.0021, Recon: 9.7065, KL: 5.2940, Class: 0.0016, Accuracy: 0.9631
# New best model saved with validation loss: 15.0021
# Train Epoch: 41 [0/6931 (0%)]	Loss: 115.363396
# Train Epoch: 41 [6400/6931 (92%)]	Loss: 12.026503
# ====> Epoch: 41 Average loss: 20.3326, Recon: 14.5236, KL: 5.8074, Class: 0.0017, Accuracy: 0.9602
# ====> Validation loss: 16.2319, Recon: 10.1564, KL: 6.0743, Class: 0.0012, Accuracy: 0.9758
# New best model saved with validation accuracy: 0.9758
# Train Epoch: 42 [0/6931 (0%)]	Loss: 14.058289
# Train Epoch: 42 [6400/6931 (92%)]	Loss: 13.498091
# ====> Epoch: 42 Average loss: 20.2766, Recon: 14.5070, KL: 5.7680, Class: 0.0016, Accuracy: 0.9600
# ====> Validation loss: 16.1779, Recon: 10.2228, KL: 5.9536, Class: 0.0015, Accuracy: 0.9648
# Train Epoch: 43 [0/6931 (0%)]	Loss: 15.129021
# Train Epoch: 43 [6400/6931 (92%)]	Loss: 12.596376
# ====> Epoch: 43 Average loss: 20.5176, Recon: 14.7854, KL: 5.7304, Class: 0.0017, Accuracy: 0.9609
# ====> Validation loss: 15.7463, Recon: 10.2031, KL: 5.5416, Class: 0.0016, Accuracy: 0.9642
# Train Epoch: 44 [0/6931 (0%)]	Loss: 13.694165
# Train Epoch: 44 [6400/6931 (92%)]	Loss: 15.750978
# ====> Epoch: 44 Average loss: 20.2228, Recon: 14.4186, KL: 5.8025, Class: 0.0016, Accuracy: 0.9610
# ====> Validation loss: 15.2801, Recon: 9.9138, KL: 5.3647, Class: 0.0016, Accuracy: 0.9660
# Train Epoch: 45 [0/6931 (0%)]	Loss: 12.409386
# Train Epoch: 45 [6400/6931 (92%)]	Loss: 12.797412
# ====> Epoch: 45 Average loss: 20.2359, Recon: 14.4766, KL: 5.7576, Class: 0.0017, Accuracy: 0.9649
# ====> Validation loss: 15.5155, Recon: 10.0823, KL: 5.4317, Class: 0.0015, Accuracy: 0.9608
# Train Epoch: 46 [0/6931 (0%)]	Loss: 14.550343
# Train Epoch: 46 [6400/6931 (92%)]	Loss: 12.404632
# ====> Epoch: 46 Average loss: 20.4077, Recon: 14.6031, KL: 5.8029, Class: 0.0017, Accuracy: 0.9625
# ====> Validation loss: 15.6073, Recon: 10.2346, KL: 5.3714, Class: 0.0013, Accuracy: 0.9717
# Train Epoch: 47 [0/6931 (0%)]	Loss: 14.500442
# Train Epoch: 47 [6400/6931 (92%)]	Loss: 16.650633
# ====> Epoch: 47 Average loss: 20.2916, Recon: 14.5037, KL: 5.7863, Class: 0.0016, Accuracy: 0.9615
# ====> Validation loss: 16.6709, Recon: 10.5524, KL: 6.1171, Class: 0.0013, Accuracy: 0.9769
# New best model saved with validation accuracy: 0.9769
# Train Epoch: 48 [0/6931 (0%)]	Loss: 13.473678
# Train Epoch: 48 [6400/6931 (92%)]	Loss: 13.392909
# ====> Epoch: 48 Average loss: 20.3262, Recon: 14.5505, KL: 5.7740, Class: 0.0017, Accuracy: 0.9610
# ====> Validation loss: 15.0505, Recon: 9.6084, KL: 5.4407, Class: 0.0014, Accuracy: 0.9677
# Train Epoch: 49 [0/6931 (0%)]	Loss: 13.520571
# Train Epoch: 49 [6400/6931 (92%)]	Loss: 13.406034
# ====> Epoch: 49 Average loss: 19.9989, Recon: 14.2708, KL: 5.7266, Class: 0.0015, Accuracy: 0.9660
# ====> Validation loss: 15.4693, Recon: 10.1575, KL: 5.3100, Class: 0.0018, Accuracy: 0.9550
# Train Epoch: 50 [0/6931 (0%)]	Loss: 18.531021
# Train Epoch: 50 [6400/6931 (92%)]	Loss: 14.893723
# ====> Epoch: 50 Average loss: 20.0369, Recon: 14.3166, KL: 5.7186, Class: 0.0017, Accuracy: 0.9613
# ====> Validation loss: 15.5569, Recon: 9.7232, KL: 5.8323, Class: 0.0014, Accuracy: 0.9683
# Train Epoch: 51 [0/6931 (0%)]	Loss: 12.626619
# Train Epoch: 51 [6400/6931 (92%)]	Loss: 20.484509
# ====> Epoch: 51 Average loss: 20.1540, Recon: 14.3726, KL: 5.7797, Class: 0.0016, Accuracy: 0.9616
# ====> Validation loss: 16.3157, Recon: 10.2044, KL: 6.1100, Class: 0.0013, Accuracy: 0.9711
# Train Epoch: 52 [0/6931 (0%)]	Loss: 12.921911
# Train Epoch: 52 [6400/6931 (92%)]	Loss: 41.562515
# ====> Epoch: 52 Average loss: 20.3137, Recon: 14.5619, KL: 5.7502, Class: 0.0016, Accuracy: 0.9626
# ====> Validation loss: 15.5479, Recon: 9.9250, KL: 5.6214, Class: 0.0015, Accuracy: 0.9694
# Train Epoch: 53 [0/6931 (0%)]	Loss: 14.267553
# Train Epoch: 53 [6400/6931 (92%)]	Loss: 12.871184
# ====> Epoch: 53 Average loss: 20.2430, Recon: 14.4592, KL: 5.7821, Class: 0.0017, Accuracy: 0.9602
# ====> Validation loss: 15.6139, Recon: 10.1127, KL: 5.4999, Class: 0.0014, Accuracy: 0.9700
# Train Epoch: 54 [0/6931 (0%)]	Loss: 18.590572
# Train Epoch: 54 [6400/6931 (92%)]	Loss: 14.751677
# ====> Epoch: 54 Average loss: 20.1384, Recon: 14.3580, KL: 5.7785, Class: 0.0019, Accuracy: 0.9590
# ====> Validation loss: 15.5140, Recon: 9.8780, KL: 5.6346, Class: 0.0014, Accuracy: 0.9683
# Train Epoch: 55 [0/6931 (0%)]	Loss: 18.571579
# Train Epoch: 55 [6400/6931 (92%)]	Loss: 19.810442
# ====> Epoch: 55 Average loss: 20.4133, Recon: 14.6494, KL: 5.7623, Class: 0.0016, Accuracy: 0.9629
# ====> Validation loss: 15.8817, Recon: 10.0266, KL: 5.8535, Class: 0.0016, Accuracy: 0.9665
# Train Epoch: 56 [0/6931 (0%)]	Loss: 15.401211
# Train Epoch: 56 [6400/6931 (92%)]	Loss: 14.253229
# ====> Epoch: 56 Average loss: 20.1071, Recon: 14.3215, KL: 5.7839, Class: 0.0017, Accuracy: 0.9597
# ====> Validation loss: 15.4409, Recon: 9.7507, KL: 5.6887, Class: 0.0015, Accuracy: 0.9642
# Train Epoch: 57 [0/6931 (0%)]	Loss: 29.739164
# Train Epoch: 57 [6400/6931 (92%)]	Loss: 14.239325
# ====> Epoch: 57 Average loss: 20.2531, Recon: 14.4852, KL: 5.7663, Class: 0.0016, Accuracy: 0.9629
# ====> Validation loss: 15.9245, Recon: 10.0866, KL: 5.8366, Class: 0.0013, Accuracy: 0.9700
# Train Epoch: 58 [0/6931 (0%)]	Loss: 12.930419
# Train Epoch: 58 [6400/6931 (92%)]	Loss: 11.455325
# ====> Epoch: 58 Average loss: 20.1343, Recon: 14.3730, KL: 5.7597, Class: 0.0016, Accuracy: 0.9603
# ====> Validation loss: 15.4189, Recon: 9.6939, KL: 5.7236, Class: 0.0014, Accuracy: 0.9735
# Train Epoch: 59 [0/6931 (0%)]	Loss: 11.726877
# Train Epoch: 59 [6400/6931 (92%)]	Loss: 13.863105
# ====> Epoch: 59 Average loss: 20.1996, Recon: 14.4424, KL: 5.7555, Class: 0.0016, Accuracy: 0.9579
# ====> Validation loss: 15.5185, Recon: 10.4085, KL: 5.1085, Class: 0.0016, Accuracy: 0.9654
# Train Epoch: 60 [0/6931 (0%)]	Loss: 17.433105
# Train Epoch: 60 [6400/6931 (92%)]	Loss: 34.556778
# ====> Epoch: 60 Average loss: 20.1850, Recon: 14.4544, KL: 5.7287, Class: 0.0019, Accuracy: 0.9639
# ====> Validation loss: 15.4102, Recon: 10.0149, KL: 5.3938, Class: 0.0016, Accuracy: 0.9671
# Train Epoch: 61 [0/6931 (0%)]	Loss: 13.210476
# Train Epoch: 61 [6400/6931 (92%)]	Loss: 14.937164
# ====> Epoch: 61 Average loss: 20.2650, Recon: 14.4855, KL: 5.7779, Class: 0.0016, Accuracy: 0.9608
# ====> Validation loss: 15.7784, Recon: 9.8217, KL: 5.9556, Class: 0.0012, Accuracy: 0.9752
# Train Epoch: 62 [0/6931 (0%)]	Loss: 21.766556
# Train Epoch: 62 [6400/6931 (92%)]	Loss: 14.768127
# ====> Epoch: 62 Average loss: 20.5453, Recon: 14.8092, KL: 5.7345, Class: 0.0016, Accuracy: 0.9639
# ====> Validation loss: 15.5260, Recon: 10.5812, KL: 4.9432, Class: 0.0017, Accuracy: 0.9613
# Train Epoch: 63 [0/6931 (0%)]	Loss: 14.468183
# Train Epoch: 63 [6400/6931 (92%)]	Loss: 29.927710
# ====> Epoch: 63 Average loss: 20.2820, Recon: 14.5117, KL: 5.7687, Class: 0.0016, Accuracy: 0.9626
# ====> Validation loss: 16.4128, Recon: 10.4653, KL: 5.9462, Class: 0.0014, Accuracy: 0.9700
# Train Epoch: 64 [0/6931 (0%)]	Loss: 15.014449
# Train Epoch: 64 [6400/6931 (92%)]	Loss: 13.803633
# ====> Epoch: 64 Average loss: 20.3705, Recon: 14.6023, KL: 5.7665, Class: 0.0017, Accuracy: 0.9583
# ====> Validation loss: 15.4384, Recon: 9.9191, KL: 5.5178, Class: 0.0015, Accuracy: 0.9636
# Train Epoch: 65 [0/6931 (0%)]	Loss: 15.403197
# Train Epoch: 65 [6400/6931 (92%)]	Loss: 15.102237
# ====> Epoch: 65 Average loss: 20.1268, Recon: 14.3649, KL: 5.7602, Class: 0.0016, Accuracy: 0.9612
# ====> Validation loss: 15.5148, Recon: 9.8481, KL: 5.6654, Class: 0.0013, Accuracy: 0.9717
# Train Epoch: 66 [0/6931 (0%)]	Loss: 18.724817
# Train Epoch: 66 [6400/6931 (92%)]	Loss: 14.017273
# ====> Epoch: 66 Average loss: 20.3041, Recon: 14.5336, KL: 5.7689, Class: 0.0016, Accuracy: 0.9613
# ====> Validation loss: 15.5094, Recon: 9.9711, KL: 5.5370, Class: 0.0013, Accuracy: 0.9688
# Train Epoch: 67 [0/6931 (0%)]	Loss: 13.739108
# Train Epoch: 67 [6400/6931 (92%)]	Loss: 14.470643
# ====> Epoch: 67 Average loss: 19.9374, Recon: 14.2024, KL: 5.7334, Class: 0.0016, Accuracy: 0.9631
# ====> Validation loss: 15.7243, Recon: 9.8809, KL: 5.8419, Class: 0.0014, Accuracy: 0.9694
# Train Epoch: 68 [0/6931 (0%)]	Loss: 15.897928
# Train Epoch: 68 [6400/6931 (92%)]	Loss: 13.499051
# ====> Epoch: 68 Average loss: 20.1862, Recon: 14.4437, KL: 5.7410, Class: 0.0016, Accuracy: 0.9657
# ====> Validation loss: 15.4884, Recon: 10.0290, KL: 5.4577, Class: 0.0017, Accuracy: 0.9700
# Train Epoch: 69 [0/6931 (0%)]	Loss: 13.304068
# Train Epoch: 69 [6400/6931 (92%)]	Loss: 17.576357
# ====> Epoch: 69 Average loss: 19.9989, Recon: 14.2377, KL: 5.7595, Class: 0.0016, Accuracy: 0.9609
# ====> Validation loss: 15.4499, Recon: 9.8293, KL: 5.6190, Class: 0.0016, Accuracy: 0.9654
# Train Epoch: 70 [0/6931 (0%)]	Loss: 12.801009
# Train Epoch: 70 [6400/6931 (92%)]	Loss: 12.450884
# ====> Epoch: 70 Average loss: 20.1142, Recon: 14.3760, KL: 5.7363, Class: 0.0018, Accuracy: 0.9583
# ====> Validation loss: 15.2333, Recon: 9.8056, KL: 5.4262, Class: 0.0015, Accuracy: 0.9665
# Train Epoch: 71 [0/6931 (0%)]	Loss: 14.640455
# Train Epoch: 71 [6400/6931 (92%)]	Loss: 14.580609
# ====> Epoch: 71 Average loss: 20.4441, Recon: 14.7114, KL: 5.7311, Class: 0.0016, Accuracy: 0.9628
# ====> Validation loss: 15.1237, Recon: 9.6157, KL: 5.5064, Class: 0.0016, Accuracy: 0.9648
# Train Epoch: 72 [0/6931 (0%)]	Loss: 13.854179
# Train Epoch: 72 [6400/6931 (92%)]	Loss: 11.260304
# ====> Epoch: 72 Average loss: 20.0174, Recon: 14.2848, KL: 5.7310, Class: 0.0016, Accuracy: 0.9609
# ====> Validation loss: 15.7028, Recon: 9.8810, KL: 5.8205, Class: 0.0013, Accuracy: 0.9752
# Train Epoch: 73 [0/6931 (0%)]	Loss: 15.722035
# Train Epoch: 73 [6400/6931 (92%)]	Loss: 16.633007
# ====> Epoch: 73 Average loss: 20.1279, Recon: 14.3296, KL: 5.7967, Class: 0.0016, Accuracy: 0.9615
# ====> Validation loss: 15.5091, Recon: 9.9646, KL: 5.5430, Class: 0.0015, Accuracy: 0.9677
# Train Epoch: 74 [0/6931 (0%)]	Loss: 13.916119
# Train Epoch: 74 [6400/6931 (92%)]	Loss: 16.080719
# ====> Epoch: 74 Average loss: 20.0141, Recon: 14.2659, KL: 5.7466, Class: 0.0016, Accuracy: 0.9622
# ====> Validation loss: 15.6966, Recon: 9.8057, KL: 5.8896, Class: 0.0013, Accuracy: 0.9706
# Train Epoch: 75 [0/6931 (0%)]	Loss: 22.838564
# Train Epoch: 75 [6400/6931 (92%)]	Loss: 15.362988
# ====> Epoch: 75 Average loss: 20.0917, Recon: 14.3413, KL: 5.7487, Class: 0.0017, Accuracy: 0.9589
# ====> Validation loss: 15.2940, Recon: 9.5725, KL: 5.7203, Class: 0.0012, Accuracy: 0.9746
# Train Epoch: 76 [0/6931 (0%)]	Loss: 14.395126
# Train Epoch: 76 [6400/6931 (92%)]	Loss: 12.655517
# ====> Epoch: 76 Average loss: 20.1708, Recon: 14.4355, KL: 5.7338, Class: 0.0016, Accuracy: 0.9619
# ====> Validation loss: 15.6327, Recon: 9.9000, KL: 5.7314, Class: 0.0012, Accuracy: 0.9706
# Train Epoch: 77 [0/6931 (0%)]	Loss: 11.986826
# Train Epoch: 77 [6400/6931 (92%)]	Loss: 11.413138
# ====> Epoch: 77 Average loss: 20.0797, Recon: 14.3646, KL: 5.7135, Class: 0.0017, Accuracy: 0.9623
# ====> Validation loss: 15.4041, Recon: 9.7110, KL: 5.6917, Class: 0.0014, Accuracy: 0.9723
# Train Epoch: 78 [0/6931 (0%)]	Loss: 12.329501
# Train Epoch: 78 [6400/6931 (92%)]	Loss: 16.384512
# ====> Epoch: 78 Average loss: 20.2101, Recon: 14.4774, KL: 5.7310, Class: 0.0017, Accuracy: 0.9612
# ====> Validation loss: 14.9231, Recon: 9.5048, KL: 5.4168, Class: 0.0014, Accuracy: 0.9723
# New best model saved with validation loss: 14.9231
# Train Epoch: 79 [0/6931 (0%)]	Loss: 40.429443
# Train Epoch: 79 [6400/6931 (92%)]	Loss: 28.304008
# ====> Epoch: 79 Average loss: 20.1141, Recon: 14.3870, KL: 5.7255, Class: 0.0017, Accuracy: 0.9605
# ====> Validation loss: 15.0631, Recon: 9.5601, KL: 5.5017, Class: 0.0013, Accuracy: 0.9694
# Train Epoch: 80 [0/6931 (0%)]	Loss: 12.313751
# Train Epoch: 80 [6400/6931 (92%)]	Loss: 14.819898
# ====> Epoch: 80 Average loss: 19.9681, Recon: 14.1952, KL: 5.7713, Class: 0.0017, Accuracy: 0.9595
# ====> Validation loss: 15.9982, Recon: 9.9778, KL: 6.0190, Class: 0.0015, Accuracy: 0.9700
# Train Epoch: 81 [0/6931 (0%)]	Loss: 13.537338
# Train Epoch: 81 [6400/6931 (92%)]	Loss: 15.042792
# ====> Epoch: 81 Average loss: 20.1608, Recon: 14.4275, KL: 5.7315, Class: 0.0018, Accuracy: 0.9606
# ====> Validation loss: 15.3366, Recon: 9.9148, KL: 5.4202, Class: 0.0015, Accuracy: 0.9636
# Train Epoch: 82 [0/6931 (0%)]	Loss: 15.363524
# Train Epoch: 82 [6400/6931 (92%)]	Loss: 12.518635
# ====> Epoch: 82 Average loss: 20.0408, Recon: 14.2960, KL: 5.7431, Class: 0.0016, Accuracy: 0.9631
# ====> Validation loss: 15.8494, Recon: 10.1924, KL: 5.6557, Class: 0.0013, Accuracy: 0.9752
# Train Epoch: 83 [0/6931 (0%)]	Loss: 17.428528
# Train Epoch: 83 [6400/6931 (92%)]	Loss: 13.789580
# ====> Epoch: 83 Average loss: 20.1074, Recon: 14.3601, KL: 5.7457, Class: 0.0016, Accuracy: 0.9592
# ====> Validation loss: 15.9244, Recon: 10.1296, KL: 5.7933, Class: 0.0014, Accuracy: 0.9694
# Train Epoch: 84 [0/6931 (0%)]	Loss: 11.508938
# Train Epoch: 84 [6400/6931 (92%)]	Loss: 12.514207
# ====> Epoch: 84 Average loss: 20.4420, Recon: 14.6802, KL: 5.7602, Class: 0.0016, Accuracy: 0.9634
# ====> Validation loss: 15.7193, Recon: 9.9059, KL: 5.8120, Class: 0.0014, Accuracy: 0.9711
# Train Epoch: 85 [0/6931 (0%)]	Loss: 12.717727
# Train Epoch: 85 [6400/6931 (92%)]	Loss: 12.310006
# ====> Epoch: 85 Average loss: 20.1991, Recon: 14.4521, KL: 5.7453, Class: 0.0016, Accuracy: 0.9597
# ====> Validation loss: 15.0001, Recon: 9.7254, KL: 5.2732, Class: 0.0014, Accuracy: 0.9671
# Train Epoch: 86 [0/6931 (0%)]	Loss: 13.038802
# Train Epoch: 86 [6400/6931 (92%)]	Loss: 23.310808
# ====> Epoch: 86 Average loss: 20.0150, Recon: 14.2907, KL: 5.7228, Class: 0.0015, Accuracy: 0.9651
# ====> Validation loss: 15.5533, Recon: 9.9561, KL: 5.5959, Class: 0.0013, Accuracy: 0.9717
# Train Epoch: 87 [0/6931 (0%)]	Loss: 14.764656
# Train Epoch: 87 [6400/6931 (92%)]	Loss: 13.594687
# ====> Epoch: 87 Average loss: 19.9858, Recon: 14.2311, KL: 5.7531, Class: 0.0016, Accuracy: 0.9628
# ====> Validation loss: 16.0163, Recon: 10.1609, KL: 5.8541, Class: 0.0014, Accuracy: 0.9711
# Train Epoch: 88 [0/6931 (0%)]	Loss: 15.065104
# Train Epoch: 88 [6400/6931 (92%)]	Loss: 20.322397
# ====> Epoch: 88 Average loss: 20.2409, Recon: 14.5100, KL: 5.7293, Class: 0.0016, Accuracy: 0.9596
# ====> Validation loss: 15.6281, Recon: 9.9176, KL: 5.7091, Class: 0.0013, Accuracy: 0.9746
# Train Epoch: 89 [0/6931 (0%)]	Loss: 22.962141
# Train Epoch: 89 [6400/6931 (92%)]	Loss: 22.103254
# ====> Epoch: 89 Average loss: 20.3254, Recon: 14.5874, KL: 5.7363, Class: 0.0017, Accuracy: 0.9608
# ====> Validation loss: 15.0375, Recon: 9.4915, KL: 5.5446, Class: 0.0014, Accuracy: 0.9671
# Train Epoch: 90 [0/6931 (0%)]	Loss: 17.329351
# Train Epoch: 90 [6400/6931 (92%)]	Loss: 14.459512
# ====> Epoch: 90 Average loss: 20.3704, Recon: 14.6201, KL: 5.7486, Class: 0.0016, Accuracy: 0.9625
# ====> Validation loss: 15.3815, Recon: 10.1538, KL: 5.2263, Class: 0.0014, Accuracy: 0.9694
# Train Epoch: 91 [0/6931 (0%)]	Loss: 11.493988
# Train Epoch: 91 [6400/6931 (92%)]	Loss: 22.693699
# ====> Epoch: 91 Average loss: 20.6863, Recon: 14.8917, KL: 5.7929, Class: 0.0017, Accuracy: 0.9635
# ====> Validation loss: 15.4806, Recon: 9.8115, KL: 5.6676, Class: 0.0015, Accuracy: 0.9642
# Train Epoch: 92 [0/6931 (0%)]	Loss: 17.582142
# Train Epoch: 92 [6400/6931 (92%)]	Loss: 19.707123
# ====> Epoch: 92 Average loss: 20.1702, Recon: 14.4253, KL: 5.7434, Class: 0.0016, Accuracy: 0.9609
# ====> Validation loss: 15.1593, Recon: 9.5827, KL: 5.5753, Class: 0.0013, Accuracy: 0.9688
# Train Epoch: 93 [0/6931 (0%)]	Loss: 12.994713
# Train Epoch: 93 [6400/6931 (92%)]	Loss: 13.075350
# ====> Epoch: 93 Average loss: 19.9074, Recon: 14.1561, KL: 5.7496, Class: 0.0017, Accuracy: 0.9615
# ====> Validation loss: 15.0816, Recon: 9.6818, KL: 5.3983, Class: 0.0015, Accuracy: 0.9642
# Train Epoch: 94 [0/6931 (0%)]	Loss: 12.753279
# Train Epoch: 94 [6400/6931 (92%)]	Loss: 14.268771
# ====> Epoch: 94 Average loss: 19.9557, Recon: 14.2253, KL: 5.7288, Class: 0.0016, Accuracy: 0.9616
# ====> Validation loss: 15.4771, Recon: 9.7644, KL: 5.7111, Class: 0.0016, Accuracy: 0.9648
# Train Epoch: 95 [0/6931 (0%)]	Loss: 11.317722
# Train Epoch: 95 [6400/6931 (92%)]	Loss: 29.042013
# ====> Epoch: 95 Average loss: 19.9846, Recon: 14.2611, KL: 5.7217, Class: 0.0018, Accuracy: 0.9559
# ====> Validation loss: 15.4877, Recon: 10.3008, KL: 5.1853, Class: 0.0016, Accuracy: 0.9648
# Train Epoch: 96 [0/6931 (0%)]	Loss: 22.457739
# Train Epoch: 96 [6400/6931 (92%)]	Loss: 13.715040
# ====> Epoch: 96 Average loss: 20.0414, Recon: 14.2691, KL: 5.7706, Class: 0.0018, Accuracy: 0.9589
# ====> Validation loss: 15.3831, Recon: 9.9244, KL: 5.4571, Class: 0.0016, Accuracy: 0.9648
# Train Epoch: 97 [0/6931 (0%)]	Loss: 16.771828
# Train Epoch: 97 [6400/6931 (92%)]	Loss: 14.699492
# ====> Epoch: 97 Average loss: 20.1591, Recon: 14.4159, KL: 5.7415, Class: 0.0017, Accuracy: 0.9603
# ====> Validation loss: 15.5056, Recon: 9.8675, KL: 5.6364, Class: 0.0017, Accuracy: 0.9665
# Train Epoch: 98 [0/6931 (0%)]	Loss: 12.752391
# Train Epoch: 98 [6400/6931 (92%)]	Loss: 15.464594
# ====> Epoch: 98 Average loss: 20.5385, Recon: 14.7905, KL: 5.7464, Class: 0.0016, Accuracy: 0.9631
# ====> Validation loss: 15.7135, Recon: 9.9785, KL: 5.7336, Class: 0.0014, Accuracy: 0.9688
# Train Epoch: 99 [0/6931 (0%)]	Loss: 15.309966
# Train Epoch: 99 [6400/6931 (92%)]	Loss: 12.472095
# ====> Epoch: 99 Average loss: 20.3087, Recon: 14.5705, KL: 5.7367, Class: 0.0015, Accuracy: 0.9638
# ====> Validation loss: 15.6186, Recon: 9.7599, KL: 5.8574, Class: 0.0013, Accuracy: 0.9746
# Train Epoch: 100 [0/6931 (0%)]	Loss: 27.410000
# Train Epoch: 100 [6400/6931 (92%)]	Loss: 15.114825
# ====> Epoch: 100 Average loss: 19.9898, Recon: 14.2353, KL: 5.7529, Class: 0.0017, Accuracy: 0.9608
# ====> Validation loss: 15.2736, Recon: 9.5677, KL: 5.7045, Class: 0.0014, Accuracy: 0.9711
# Train Epoch: 101 [0/6931 (0%)]	Loss: 13.940475
# Train Epoch: 101 [6400/6931 (92%)]	Loss: 66.348251
# ====> Epoch: 101 Average loss: 20.1741, Recon: 14.4343, KL: 5.7381, Class: 0.0016, Accuracy: 0.9612
# ====> Validation loss: 15.1415, Recon: 9.7389, KL: 5.4012, Class: 0.0015, Accuracy: 0.9694
# Train Epoch: 102 [0/6931 (0%)]	Loss: 120.940979
# Train Epoch: 102 [6400/6931 (92%)]	Loss: 113.044884
# ====> Epoch: 102 Average loss: 20.1434, Recon: 14.3825, KL: 5.7593, Class: 0.0016, Accuracy: 0.9615
# ====> Validation loss: 15.2672, Recon: 9.7051, KL: 5.5608, Class: 0.0013, Accuracy: 0.9746
# Train Epoch: 103 [0/6931 (0%)]	Loss: 14.584446
# Train Epoch: 103 [6400/6931 (92%)]	Loss: 13.770704
# ====> Epoch: 103 Average loss: 19.9909, Recon: 14.2714, KL: 5.7179, Class: 0.0015, Accuracy: 0.9632
# ====> Validation loss: 16.0325, Recon: 9.9454, KL: 6.0858, Class: 0.0014, Accuracy: 0.9706
# Train Epoch: 104 [0/6931 (0%)]	Loss: 12.126645
# Train Epoch: 104 [6400/6931 (92%)]	Loss: 11.853921
# ====> Epoch: 104 Average loss: 20.0979, Recon: 14.3800, KL: 5.7163, Class: 0.0016, Accuracy: 0.9626
# ====> Validation loss: 15.4341, Recon: 9.7395, KL: 5.6932, Class: 0.0013, Accuracy: 0.9740
# Train Epoch: 105 [0/6931 (0%)]	Loss: 14.435854
# Train Epoch: 105 [6400/6931 (92%)]	Loss: 12.423760
# ====> Epoch: 105 Average loss: 20.0312, Recon: 14.2999, KL: 5.7298, Class: 0.0015, Accuracy: 0.9665
# ====> Validation loss: 16.2075, Recon: 10.3303, KL: 5.8756, Class: 0.0015, Accuracy: 0.9602
# Train Epoch: 106 [0/6931 (0%)]	Loss: 16.348837
# Train Epoch: 106 [6400/6931 (92%)]	Loss: 15.336617
# ====> Epoch: 106 Average loss: 20.3274, Recon: 14.5705, KL: 5.7553, Class: 0.0016, Accuracy: 0.9639
# ====> Validation loss: 15.4187, Recon: 9.6879, KL: 5.7294, Class: 0.0014, Accuracy: 0.9700
# Train Epoch: 107 [0/6931 (0%)]	Loss: 13.807082
# Train Epoch: 107 [6400/6931 (92%)]	Loss: 11.778338
# ====> Epoch: 107 Average loss: 20.1648, Recon: 14.3970, KL: 5.7661, Class: 0.0016, Accuracy: 0.9625
# ====> Validation loss: 15.9395, Recon: 9.9899, KL: 5.9482, Class: 0.0014, Accuracy: 0.9729
# Train Epoch: 108 [0/6931 (0%)]	Loss: 13.491228
# Train Epoch: 108 [6400/6931 (92%)]	Loss: 13.254016
# ====> Epoch: 108 Average loss: 20.1663, Recon: 14.4292, KL: 5.7356, Class: 0.0016, Accuracy: 0.9636
# ====> Validation loss: 15.7863, Recon: 10.1646, KL: 5.6202, Class: 0.0015, Accuracy: 0.9660
# Train Epoch: 109 [0/6931 (0%)]	Loss: 12.427229
# Train Epoch: 109 [6400/6931 (92%)]	Loss: 20.831577
# ====> Epoch: 109 Average loss: 20.3899, Recon: 14.6961, KL: 5.6920, Class: 0.0017, Accuracy: 0.9621
# ====> Validation loss: 15.1463, Recon: 9.4836, KL: 5.6613, Class: 0.0014, Accuracy: 0.9688
# Train Epoch: 110 [0/6931 (0%)]	Loss: 15.942937
# Train Epoch: 110 [6400/6931 (92%)]	Loss: 16.206541
# ====> Epoch: 110 Average loss: 20.2172, Recon: 14.5024, KL: 5.7130, Class: 0.0018, Accuracy: 0.9582
# ====> Validation loss: 15.4047, Recon: 9.6768, KL: 5.7267, Class: 0.0013, Accuracy: 0.9717
# Train Epoch: 111 [0/6931 (0%)]	Loss: 20.497829
# Train Epoch: 111 [6400/6931 (92%)]	Loss: 11.560122
# ====> Epoch: 111 Average loss: 20.1564, Recon: 14.4100, KL: 5.7447, Class: 0.0017, Accuracy: 0.9592
# ====> Validation loss: 15.3344, Recon: 9.5906, KL: 5.7425, Class: 0.0013, Accuracy: 0.9740
# Train Epoch: 112 [0/6931 (0%)]	Loss: 13.472015
# Train Epoch: 112 [6400/6931 (92%)]	Loss: 13.008940
# ====> Epoch: 112 Average loss: 20.2881, Recon: 14.5375, KL: 5.7488, Class: 0.0017, Accuracy: 0.9619
# ====> Validation loss: 15.6509, Recon: 9.9274, KL: 5.7221, Class: 0.0015, Accuracy: 0.9683
# Train Epoch: 113 [0/6931 (0%)]	Loss: 13.101525
# Train Epoch: 113 [6400/6931 (92%)]	Loss: 18.361340
# ====> Epoch: 113 Average loss: 20.6523, Recon: 14.9029, KL: 5.7478, Class: 0.0016, Accuracy: 0.9645
# ====> Validation loss: 15.2239, Recon: 9.8347, KL: 5.3875, Class: 0.0017, Accuracy: 0.9608
# Train Epoch: 114 [0/6931 (0%)]	Loss: 12.216074
# Train Epoch: 114 [6400/6931 (92%)]	Loss: 12.822416
# ====> Epoch: 114 Average loss: 19.9166, Recon: 14.1725, KL: 5.7424, Class: 0.0016, Accuracy: 0.9628
# ====> Validation loss: 15.6377, Recon: 9.9070, KL: 5.7294, Class: 0.0013, Accuracy: 0.9729
# Train Epoch: 115 [0/6931 (0%)]	Loss: 12.727454
# Train Epoch: 115 [6400/6931 (92%)]	Loss: 19.453451
# ====> Epoch: 115 Average loss: 20.4034, Recon: 14.6731, KL: 5.7288, Class: 0.0015, Accuracy: 0.9615
# ====> Validation loss: 15.3362, Recon: 10.0906, KL: 5.2438, Class: 0.0017, Accuracy: 0.9619
# Train Epoch: 116 [0/6931 (0%)]	Loss: 12.236582
# Train Epoch: 116 [6400/6931 (92%)]	Loss: 13.891885
# ====> Epoch: 116 Average loss: 19.9868, Recon: 14.2805, KL: 5.7046, Class: 0.0016, Accuracy: 0.9618
# ====> Validation loss: 15.1330, Recon: 9.7059, KL: 5.4258, Class: 0.0013, Accuracy: 0.9700
# Train Epoch: 117 [0/6931 (0%)]	Loss: 20.784334
# Train Epoch: 117 [6400/6931 (92%)]	Loss: 11.868391
# ====> Epoch: 117 Average loss: 20.0026, Recon: 14.2380, KL: 5.7630, Class: 0.0015, Accuracy: 0.9641
# ====> Validation loss: 15.5094, Recon: 9.9894, KL: 5.5184, Class: 0.0016, Accuracy: 0.9619
# Train Epoch: 118 [0/6931 (0%)]	Loss: 16.163315
# Train Epoch: 118 [6400/6931 (92%)]	Loss: 11.684955
# ====> Epoch: 118 Average loss: 20.0792, Recon: 14.3386, KL: 5.7389, Class: 0.0017, Accuracy: 0.9612
# ====> Validation loss: 15.1812, Recon: 9.5392, KL: 5.6407, Class: 0.0013, Accuracy: 0.9723
# Train Epoch: 119 [0/6931 (0%)]	Loss: 12.061790
# Train Epoch: 119 [6400/6931 (92%)]	Loss: 13.970352
# ====> Epoch: 119 Average loss: 20.2334, Recon: 14.4624, KL: 5.7694, Class: 0.0016, Accuracy: 0.9651
# ====> Validation loss: 15.5660, Recon: 9.9518, KL: 5.6128, Class: 0.0014, Accuracy: 0.9683
# Train Epoch: 120 [0/6931 (0%)]	Loss: 15.108310
# Train Epoch: 120 [6400/6931 (92%)]	Loss: 20.888750
# ====> Epoch: 120 Average loss: 20.2049, Recon: 14.4830, KL: 5.7203, Class: 0.0016, Accuracy: 0.9597
# ====> Validation loss: 15.3851, Recon: 9.7754, KL: 5.6083, Class: 0.0014, Accuracy: 0.9717
# Train Epoch: 121 [0/6931 (0%)]	Loss: 12.407548
# Train Epoch: 121 [6400/6931 (92%)]	Loss: 11.987274
# ====> Epoch: 121 Average loss: 19.8041, Recon: 14.0554, KL: 5.7470, Class: 0.0017, Accuracy: 0.9582
# ====> Validation loss: 15.9108, Recon: 9.9690, KL: 5.9404, Class: 0.0013, Accuracy: 0.9706
# Train Epoch: 122 [0/6931 (0%)]	Loss: 11.702399
# Train Epoch: 122 [6400/6931 (92%)]	Loss: 15.635335
# ====> Epoch: 122 Average loss: 20.1510, Recon: 14.4264, KL: 5.7229, Class: 0.0016, Accuracy: 0.9608
# ====> Validation loss: 15.5204, Recon: 10.0263, KL: 5.4925, Class: 0.0016, Accuracy: 0.9613
# Train Epoch: 123 [0/6931 (0%)]	Loss: 29.536062
# Train Epoch: 123 [6400/6931 (92%)]	Loss: 12.408897
# ====> Epoch: 123 Average loss: 20.0720, Recon: 14.3639, KL: 5.7065, Class: 0.0016, Accuracy: 0.9631
# ====> Validation loss: 15.8201, Recon: 9.8853, KL: 5.9333, Class: 0.0014, Accuracy: 0.9706
# Train Epoch: 124 [0/6931 (0%)]	Loss: 15.679432
# Train Epoch: 124 [6400/6931 (92%)]	Loss: 14.299130
# ====> Epoch: 124 Average loss: 20.0195, Recon: 14.2816, KL: 5.7364, Class: 0.0015, Accuracy: 0.9645
# ====> Validation loss: 15.4337, Recon: 9.8745, KL: 5.5578, Class: 0.0015, Accuracy: 0.9688
# Train Epoch: 125 [0/6931 (0%)]	Loss: 17.848623
# Train Epoch: 125 [6400/6931 (92%)]	Loss: 17.897732
# ====> Epoch: 125 Average loss: 20.1647, Recon: 14.4333, KL: 5.7298, Class: 0.0016, Accuracy: 0.9636
# ====> Validation loss: 15.6272, Recon: 10.4299, KL: 5.1958, Class: 0.0014, Accuracy: 0.9694
# Train Epoch: 126 [0/6931 (0%)]	Loss: 16.825638
# Train Epoch: 126 [6400/6931 (92%)]	Loss: 14.183161
# ====> Epoch: 126 Average loss: 20.1355, Recon: 14.4127, KL: 5.7212, Class: 0.0016, Accuracy: 0.9628
# ====> Validation loss: 15.6582, Recon: 9.9963, KL: 5.6605, Class: 0.0014, Accuracy: 0.9683
# Train Epoch: 127 [0/6931 (0%)]	Loss: 13.027412
# Train Epoch: 127 [6400/6931 (92%)]	Loss: 24.579155
# ====> Epoch: 127 Average loss: 20.1020, Recon: 14.3758, KL: 5.7246, Class: 0.0016, Accuracy: 0.9635
# ====> Validation loss: 15.3317, Recon: 9.6273, KL: 5.7030, Class: 0.0014, Accuracy: 0.9717
# Train Epoch: 128 [0/6931 (0%)]	Loss: 22.773275
# Train Epoch: 128 [6400/6931 (92%)]	Loss: 13.027006
# ====> Epoch: 128 Average loss: 20.0303, Recon: 14.2963, KL: 5.7324, Class: 0.0016, Accuracy: 0.9641
# ====> Validation loss: 16.1070, Recon: 10.0971, KL: 6.0084, Class: 0.0015, Accuracy: 0.9631
# Train Epoch: 129 [0/6931 (0%)]	Loss: 19.580221
# Train Epoch: 129 [6400/6931 (92%)]	Loss: 18.225710
# ====> Epoch: 129 Average loss: 20.0855, Recon: 14.3392, KL: 5.7447, Class: 0.0016, Accuracy: 0.9635
# ====> Validation loss: 15.9790, Recon: 10.1205, KL: 5.8571, Class: 0.0013, Accuracy: 0.9711
# Train Epoch: 130 [0/6931 (0%)]	Loss: 16.845943
# Train Epoch: 130 [6400/6931 (92%)]	Loss: 12.949657
# ====> Epoch: 130 Average loss: 20.1753, Recon: 14.4472, KL: 5.7264, Class: 0.0016, Accuracy: 0.9608
# ====> Validation loss: 15.5108, Recon: 9.6245, KL: 5.8849, Class: 0.0014, Accuracy: 0.9683
# Train Epoch: 131 [0/6931 (0%)]	Loss: 15.461342
# Train Epoch: 131 [6400/6931 (92%)]	Loss: 11.366348
# ====> Epoch: 131 Average loss: 20.3483, Recon: 14.6045, KL: 5.7422, Class: 0.0016, Accuracy: 0.9603
# ====> Validation loss: 15.4633, Recon: 9.8208, KL: 5.6412, Class: 0.0013, Accuracy: 0.9717
# Train Epoch: 132 [0/6931 (0%)]	Loss: 13.657059
# Train Epoch: 132 [6400/6931 (92%)]	Loss: 16.479448
# ====> Epoch: 132 Average loss: 20.2699, Recon: 14.5200, KL: 5.7483, Class: 0.0016, Accuracy: 0.9599
# ====> Validation loss: 15.5116, Recon: 9.8298, KL: 5.6805, Class: 0.0013, Accuracy: 0.9660
# Train Epoch: 133 [0/6931 (0%)]	Loss: 44.417622
# Train Epoch: 133 [6400/6931 (92%)]	Loss: 28.449789
# ====> Epoch: 133 Average loss: 20.3060, Recon: 14.5787, KL: 5.7256, Class: 0.0016, Accuracy: 0.9635
# ====> Validation loss: 15.8328, Recon: 9.9762, KL: 5.8552, Class: 0.0013, Accuracy: 0.9711
# Train Epoch: 134 [0/6931 (0%)]	Loss: 13.774714
# Train Epoch: 134 [6400/6931 (92%)]	Loss: 16.243355
# ====> Epoch: 134 Average loss: 20.0541, Recon: 14.3060, KL: 5.7465, Class: 0.0016, Accuracy: 0.9621
# ====> Validation loss: 15.8431, Recon: 9.9284, KL: 5.9135, Class: 0.0012, Accuracy: 0.9763
# Train Epoch: 135 [0/6931 (0%)]	Loss: 16.613976
# Train Epoch: 135 [6400/6931 (92%)]	Loss: 13.446647
# ====> Epoch: 135 Average loss: 20.3792, Recon: 14.6157, KL: 5.7619, Class: 0.0017, Accuracy: 0.9605
# ====> Validation loss: 16.2252, Recon: 10.1435, KL: 6.0802, Class: 0.0014, Accuracy: 0.9688
# Early stopping triggered at epoch 135
# Training complete.

# %%
torch.save(model.state_dict(), 'ssfrb_vae_model.pth')

# %%
def get_latent_representations(model, dataloader, device):
    model.eval()
    latent_representations = []
    all_labels = []
    with torch.no_grad():
        for data, labels in dataloader:
            data = data.to(device)
            mu, _ = model.encode(data)
            latent_representations.append(mu.cpu().numpy())
            all_labels.append(labels.numpy())
    return np.concatenate(latent_representations), np.concatenate(all_labels)


def visualize_latent_space_pca(latent_representations, labels, model, device):
    # Perform PCA
    pca = PCA(n_components=2)
    latent_2d = pca.fit_transform(latent_representations)

    # Plot the 2D latent space
    plt.figure(figsize=(12, 10))
    #scatter = plt.scatter(latent_2d[:, 0], latent_2d[:, 1], c=labels, cmap='plasma', s=10)
    sns.scatterplot(x=latent_2d[:, 0], y=latent_2d[:, 1], hue=labels, palette='coolwarm', s=60, alpha=0.8)
    plt.title('PCA of Latent Space Representations')
    plt.xlabel('First Principal Component')
    plt.ylabel('Second Principal Component')
    plt.show()

train_latent, train_labels_np = get_latent_representations(model, train_loader, device)
val_latent, val_labels_np = get_latent_representations(model, val_loader, device)
visualize_latent_space_pca(train_latent, train_labels_np, model, device)

# %%
# Apply K-Means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(train_latent)
train_clusters = kmeans.labels_

# Evaluate Clustering Performance
sil_score = silhouette_score(train_latent, train_clusters)
ari_score = adjusted_rand_score(train_labels_np, train_clusters)
conf_matrix = confusion_matrix(train_labels_np, train_clusters)

print(f"KMeans Silhouette Score: {sil_score:.4f}")
print(f"KMeans Adjusted Rand Index: {ari_score:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# KMeans Silhouette Score: 0.2405
# KMeans Adjusted Rand Index: -0.0555
# Confusion Matrix:
# [[  75  878]
#  [2142 3836]]

# %%
gmm = GaussianMixture(n_components=2, random_state=42)
gmm_clusters = gmm.fit_predict(train_latent)
sil_score = silhouette_score(train_latent, gmm_clusters)
ari_score = adjusted_rand_score(train_labels_np, gmm_clusters)
print(f"GMM Silhouette Score: {sil_score:.4f}")
print(f"GMM Adjusted Rand Index: {ari_score:.4f}")

conf_matrix = confusion_matrix(train_labels_np, gmm_clusters)
class_report = classification_report(train_labels_np, gmm_clusters)
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# GMM Silhouette Score: 0.1233
# GMM Adjusted Rand Index: -0.0021
# Confusion Matrix:
# [[ 611  342]
#  [3079 2899]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.17      0.64      0.26       953
#            1       0.89      0.48      0.63      5978
#
#     accuracy                           0.51      6931
#    macro avg       0.53      0.56      0.45      6931
# weighted avg       0.79      0.51      0.58      6931

# %%
def svm_on_pca(train_latent, train_labels, val_latent, val_labels, test_size=0.2, random_state=42):
    pca = PCA(n_components=2, random_state=random_state)
    pca.fit(train_latent)
    
    train_latent_pca = pca.transform(train_latent)
    val_latent_pca = pca.transform(val_latent)

    svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=random_state)
    svm_model.fit(train_latent_pca, train_labels)

    # Predict on validation set
    val_preds = svm_model.predict(val_latent_pca)
    print(f"Validation Accuracy: {accuracy_score(val_labels, val_preds):.4f}")
    print("Validation Confusion Matrix:")
    print(confusion_matrix(val_labels, val_preds))
    print("Validation Classification Report:")
    print(classification_report(val_labels, val_preds))

    plt.figure(figsize=(12, 10))
    sns.scatterplot(x=train_latent_pca[:, 0], y=train_latent_pca[:, 1], hue=train_labels, palette='coolwarm', s=60, alpha=0.8, edgecolor='k')

    x_min, x_max = train_latent_pca[:, 0].min() - 1, train_latent_pca[:, 0].max() + 1
    y_min, y_max = train_latent_pca[:, 1].min() - 1, train_latent_pca[:, 1].max() + 1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 500), np.linspace(y_min, y_max, 500))

    Z = svm_model.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, levels=20, cmap="RdBu", alpha=0.6)  # SVM decision boundary

    plt.colorbar()
    plt.title('SVM Decision Boundary on PCA-Transformed Training Data')
    plt.xlabel('PCA Component 1')
    plt.ylabel('PCA Component 2')
    plt.legend(title='Class Labels')
    plt.show()

svm_on_pca(train_latent, train_labels_np, val_latent, val_labels_np, test_size=0.2, random_state=42)
# Out:
# Validation Accuracy: 0.9821
# Validation Confusion Matrix:
# [[ 210   28]
#  [   3 1492]]
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93       238
#            1       0.98      1.00      0.99      1495
#
#     accuracy                           0.98      1733
#    macro avg       0.98      0.94      0.96      1733
# weighted avg       0.98      0.98      0.98      1733

# %% [markdown]
# ## Evaluating Classifier Head

# %%
def evaluate_classifier(model, dataloader, device):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for data, labels in dataloader:
            data = data.to(device)
            class_logits = model(data)[-1]
            preds = (class_logits > 0.5).float().cpu().numpy().squeeze()
            all_preds.extend(preds)
            all_labels.extend(labels.cpu().numpy())
    
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    
    accuracy = accuracy_score(all_labels, all_preds)
    class_report = classification_report(all_labels, all_preds, target_names=["Non-Repeater", "Repeater"])
    conf_matrix = confusion_matrix(all_labels, all_preds)
    
    return accuracy, class_report, conf_matrix, all_preds, all_labels


val_accuracy, val_class_report, val_conf_matrix, val_preds, val_labels = evaluate_classifier(model, val_loader, device)

print(f"Validation Accuracy: {val_accuracy:.4f}")
print("Classification Report:\n", val_class_report)
print("Confusion Matrix:\n", val_conf_matrix)

fpr, tpr, thresholds = roc_curve(val_labels, val_preds)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Validation Accuracy: 0.9706
# Classification Report:
#                precision    recall  f1-score   support
#
# Non-Repeater       0.89      0.89      0.89       238
#     Repeater       0.98      0.98      0.98      1495
#
#     accuracy                           0.97      1733
#    macro avg       0.94      0.94      0.94      1733
# weighted avg       0.97      0.97      0.97      1733
#
# Confusion Matrix:
#  [[ 213   25]
#  [  26 1469]]

# %%
garcia_list = '''
FRB20180907E
FRB20180920B
FRB20180928A
FRB20181017B
FRB20181022E
FRB20181125A
FRB20181125A
FRB20181125A
FRB20181214A
FRB20181220A
FRB20181226E
FRB20181229B
FRB20190112A
FRB20190128C
FRB20190206B
FRB20190206A
FRB20190218B
FRB20190223A
FRB20190308C
FRB20190308C
FRB20190323D
FRB20190329A
FRB20190410A
FRB20190412B
FRB20190423B
FRB20190423B
FRB20190429B
FRB20190430A
FRB20190527A
FRB20190527A
FRB20190601C
FRB20190601C
FRB20190617B
FRB20180910A
FRB20190210C
FRB20200726D
'''.split()

luo_list = '''
FRB20181229B
FRB20190423B
FRB20190410A
FRB20181017B
FRB20181128C
FRB20190422A
FRB20190409B
FRB20190329A
FRB20190423B
FRB20190206A
FRB20190128C
FRB20190106A
FRB20190129A
FRB20181030E
FRB20190527A
FRB20190218B
FRB20190609A
FRB20190412B
FRB20190125B
FRB20181231B
FRB20181221A
FRB20190112A
FRB20190125A
FRB20181218C
FRB20190429B
FRB20190109B
FRB20190206B
'''.split()

zhu_ge_list = '''
FRB20180911A
FRB20180915B
FRB20180920B
FRB20180923A
FRB20180923C
FRB20180928A
FRB20181013E
FRB20181017B
FRB20181030E
FRB20181125A
FRB20181125A
FRB20181125A
FRB20181130A
FRB20181214A
FRB20181220A
FRB20181221A
FRB20181226E
FRB20181229B
FRB20181231B
FRB20190106B
FRB20190109B
FRB20190110C
FRB20190111A
FRB20190112A
FRB20190129A
FRB20190204A
FRB20190206A
FRB20190218B
FRB20190220A
FRB20190221A
FRB20190222B
FRB20190223A
FRB20190228A
FRB20190308C
FRB20190308C
FRB20190308B
FRB20190308B
FRB20190323D
FRB20190329A
FRB20190403E
FRB20190409B
FRB20190410A
FRB20190412B
FRB20190418A
FRB20190419A
FRB20190422A
FRB20190422A
FRB20190423A
FRB20190423B
FRB20190423B
FRB20190429B
FRB20190430A
FRB20190517C
FRB20190527A
FRB20190527A
FRB20190531C
FRB20190601B
FRB20190601C
FRB20190601C
FRB20190609A
FRB20190617A
FRB20190617B
FRB20190618A
FRB20190625A
'''.split()

# %%
original_data = pd.read_csv('frb-data.csv')
original_data['Repeater'] = original_data['Repeater'].map({'Yes': 1, 'No': 0}).fillna(0).astype(int)

misclassified_non_repeaters = (val_labels == 0) & (val_preds == 1)
misclassified_indices = val_indices[misclassified_non_repeaters]
misclassified_sources = original_data.loc[misclassified_indices, "Source"]

misclassified_sources
# Out:
# 3092    FRB20181226E
# 3237    FRB20180919B
# 3247    FRB20190201B
# 3410    FRB20190806B
# 3321    FRB20190630D
# 3310    FRB20190316A
# 2950    FRB20190224C
# 8054    FRB20220912A
# 6603    FRB20220825A
# 8130    FRB20220912A
# 5321    FRB19970528A
# 6607    FRB20220926A
# 6614    FRB20221106A
# 7737    FRB20240123A
# 3117    FRB20181129B
# 7724    FRB20230124A
# 6591    FRB20220208A
# 7950    FRB20220912A
# 3411    FRB20191223B
# 2961    FRB20180814B
# 3129    FRB20190402A
# 3042    FRB20190128C
# 5358    FRB20001118A
# 3419    FRB20201123A
# 3228    FRB20190410A
# Name: Source, dtype: object

# %%
for source in misclassified_sources:
    if source in luo_list:
        print(source)
# Out:
# FRB20190128C
# FRB20190410A

# %%
for source in misclassified_sources:
    if source in garcia_list:
        print(f"{source}")
# Out:
# FRB20181226E
# FRB20190128C
# FRB20190410A

# %%
for source in misclassified_sources:
    if source in zhu_ge_list:
        print(source)
# Out:
# FRB20181226E
# FRB20190410A

# %%
for source in misclassified_sources:
    if source in garcia_list and source in luo_list and source in zhu_ge_list:
        print(source)
# Out:
# FRB20190410A

# %%
for source in misclassified_sources:
    if source in garcia_list or source in luo_list or source in zhu_ge_list:
        print(source)
# Out:
# FRB20181226E
# FRB20190128C
# FRB20190410A

# %% [markdown]
# ## SVM on PCA latent space analysis

# %%
val_latent, val_labels_np = get_latent_representations(model, val_loader, device)
pca = PCA(n_components=2, random_state=42)
pca.fit(train_latent)

train_latent_pca = pca.transform(train_latent)
val_latent_pca = pca.transform(val_latent)

svm_pca = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=42)
svm_pca.fit(train_latent_pca, train_labels_np)

val_pca_preds = svm_pca.predict(val_latent_pca)
print(confusion_matrix(val_labels_np, val_pca_preds))

fpr, tpr, thresholds = roc_curve(val_labels_np, val_pca_preds)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# [[ 210   28]
#  [   3 1492]]
# [ True  True  True ...  True  True  True]

# %%
misclassified_repeaters_svm = (val_labels_np == 0) & (val_pca_preds == 1)   

misclassified_repeaters_indices_svm = val_indices[misclassified_repeaters_svm]
misclassified_repeaters_sources_svm = original_data.loc[misclassified_repeaters_indices_svm, "Source"]

misclassified_repeaters_sources_svm
# Out:
# 6577    FRB20210202D
# 3092    FRB20181226E
# 2875    FRB20181222E
# 3339    FRB20190628B
# 3247    FRB20190201B
# 3028    FRB20180714A
# 3321    FRB20190630D
# 2950    FRB20190224C
# 3349    FRB20190617A
# 3134    FRB20190502B
# 6603    FRB20220825A
# 2836    FRB20171209A
# 3404    FRB20190627C
# 6588    FRB20220121B
# 6607    FRB20220926A
# 3145    FRB20181112A
# 3229    FRB20190419B
# 7737    FRB20240123A
# 3158    FRB20190213D
# 3388    FRB20190613B
# 6591    FRB20220208A
# 3371    FRB20190609B
# 6604    FRB20220831A
# 3093    FRB20181228B
# 2849    FRB20181231B
# 3070    FRB20190304B
# 2856    FRB20190224D
# 3188    FRB20181214C
# Name: Source, dtype: object

# %%
for source in misclassified_repeaters_sources_svm:
    if source in garcia_list:
        print(f"{source}")
        
for source in misclassified_repeaters_sources_svm:
    if source in luo_list:
        print(f"{source}")

for source in misclassified_repeaters_sources_svm:
    if source in zhu_ge_list:
        print(f"{source}")
# Out:
# FRB20181226E
# FRB20181231B
# FRB20181226E
# FRB20190617A
# FRB20181231B

# %%
for source in misclassified_repeaters_sources_svm:
    if source in garcia_list or source in luo_list or source in zhu_ge_list:
        print(source)
# Out:
# FRB20181226E
# FRB20190617A
# FRB20181231B

# %%
for source in misclassified_repeaters_svm:
    if source in misclassified_sources:
        print(source)
        
# indicates no overlap
