# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
import re
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, adjusted_rand_score, confusion_matrix
from sklearn.mixture import GaussianMixture
from sklearn.manifold import TSNE
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV

# %%
frb_data = pd.read_csv('frb-data.csv')
frb_data['Repeater'] = frb_data['Repeater'].map({'Yes': 1, 'No': 0})
frb_data['Repeater'] = frb_data['Repeater'].fillna(0)
frb_data['Repeater'] = frb_data['Repeater'].astype(int)

# %%
# Select numerical columns that are relevant for VAE training
# features = ['Observing_band', 'MJD', 'GL', 'GB', 'SNR', 'DM_SNR', 'DM_SNR_err', 'DM_alig', 'DM_alig_err', 'Flux_density', 
#             'Flux_density_err', 'Width', 'Width_err', 'Freq_high', 'Freq_low', 'Freq_peak', 'Fluence', 'Fluence_err', 'Energy', 
#             'Energy_err', 'Polar_l', 'Polar_l_err', 'Polar_c', 'Polar_c_err', 'RM_syn', 'RM_syn_err', 'RM_QUfit', 'RM_QUfit_err', 'Scatt_t', 'Scatt_t_err', 'Scin_f', 'Scin_f_err',]

labels = frb_data['Repeater']

features = ['Observing_band', 'MJD', 'GL', 'GB', 'SNR', 'DM_SNR', 'DM_alig', 'Flux_density', 
             'Width', 'Freq_high', 'Freq_low', 'Freq_peak', 'Fluence', 'Energy', 
             'Polar_l',  'Polar_c', 'RM_syn',  'RM_QUfit', 'Scatt_t', 'Scin_f',]

# Function to clean numerical strings and convert to float
def clean_numeric_value(value):
    if type(value)==str and len(value.strip()) > 0:
        try:
            if '/' in value:
                value = value.split('/')[0]
            if '-' in value and not '+' in value:
                value = value.split('-')[0]
            if value[0] == '+':
                value = value[1:]
                value.split('/')
                value = value[0]
            if value[0] == '<':
                value = value[1:]
            if value[0] == '>':
                value = value[1:]
            return float(value)
        except:
            # print(f"Error: {value}")
            return np.nan
    try:
        return float(value)
    except:
        return np.nan

for col in frb_data[features].columns:
    frb_data[col] = frb_data[col].apply(clean_numeric_value)

# %%
frb_data_clean = frb_data[features].fillna(0)
scaler = StandardScaler()
frb_data_scaled = scaler.fit_transform(frb_data_clean)

train_data, val_data, train_labels, val_labels = train_test_split(
    frb_data_scaled, labels, test_size=0.2, random_state=42, stratify=labels
)

# Convert to PyTorch tensors
train_tensor = torch.tensor(train_data, dtype=torch.float32)
val_tensor = torch.tensor(val_data, dtype=torch.float32)
train_labels_tensor = torch.tensor(train_labels.values, dtype=torch.long)
val_labels_tensor = torch.tensor(val_labels.values, dtype=torch.long)

# Create datasets and dataloaders
batch_size = 64
train_dataset = TensorDataset(train_tensor, train_labels_tensor)
val_dataset = TensorDataset(val_tensor, val_labels_tensor)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

class SemiSupervisedVAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim, num_classes, dropout_rate=0.3, activation=nn.LeakyReLU(0.1)):
        super(SemiSupervisedVAE, self).__init__()
        
        self.activation = activation
        
        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate)
        )
        
        self.fc_mu = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        
        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, input_dim)
        )
        
        # Classification head
        self.classifier = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim // 2),
            self.activation,
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim // 2, num_classes)
        )
    
    def encode(self, x):
        h = self.encoder(x)
        return self.fc_mu(h), self.fc_logvar(h)
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std
    
    def decode(self, z):
        return self.decoder(z)
    
    def classify(self, z):
        return self.classifier(z)
    
    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon = self.decode(z)
        class_logits = self.classifier(z)
        return recon, mu, logvar, class_logits

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

input_dim = frb_data_scaled.shape[1]
hidden_dim = 256
latent_dim = 10
patience = 4
num_epochs = 150


num_classes = 2  # 'Repeater' and 'Non-Repeater'
model = SemiSupervisedVAE(input_dim=input_dim, hidden_dim=hidden_dim, latent_dim=latent_dim, num_classes=num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=patience, verbose=True)
classification_loss_fn = nn.CrossEntropyLoss()
# Out:
# /home/rtenacity/Projects/frb-analysis/.frb/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
def semi_supervised_loss_function(recon_x, x, mu, logvar, class_logits, labels, classification_loss_fn, beta=1.0):
    recon_loss = nn.MSELoss(reduction='sum')(recon_x, x)
    kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    classification_loss = classification_loss_fn(class_logits, labels)
    
    total_loss = recon_loss + beta * kl_loss + classification_loss
    return total_loss, recon_loss, kl_loss, classification_loss

# %%
def train_semi_supervised(epoch):
    model.train()
    train_loss = 0
    recon_loss_total = 0
    kl_loss_total = 0
    classification_loss_total = 0
    
    for batch_idx, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        optimizer.zero_grad()
        recon_batch, mu, logvar, class_logits = model(data)
        loss, recon_loss, kl_loss, classification_loss = semi_supervised_loss_function(
            recon_batch, data, mu, logvar, class_logits, labels, classification_loss_fn
        )
        loss.backward()
        train_loss += loss.item()
        recon_loss_total += recon_loss.item()
        kl_loss_total += kl_loss.item()
        classification_loss_total += classification_loss.item()
        optimizer.step()
        
        if batch_idx % 100 == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} '
                  f'({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item() / len(data):.6f}')
    
    avg_loss = train_loss / len(train_loader.dataset)
    avg_recon = recon_loss_total / len(train_loader.dataset)
    avg_kl = kl_loss_total / len(train_loader.dataset)
    avg_class = classification_loss_total / len(train_loader.dataset)
    print(f'====> Epoch: {epoch} Average loss: {avg_loss:.4f}, Recon: {avg_recon:.4f}, KL: {avg_kl:.4f}, Class: {avg_class:.4f}')
    return avg_loss, avg_recon, avg_kl, avg_class

def validate_semi_supervised():
    model.eval()
    val_loss = 0
    recon_loss_total = 0
    kl_loss_total = 0
    classification_loss_total = 0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for data, labels in val_loader:
            data, labels = data.to(device), labels.to(device)
            recon_batch, mu, logvar, class_logits = model(data)
            loss, recon_loss, kl_loss, classification_loss = semi_supervised_loss_function(
                recon_batch, data, mu, logvar, class_logits, labels, classification_loss_fn
            )
            val_loss += loss.item()
            recon_loss_total += recon_loss.item()
            kl_loss_total += kl_loss.item()
            classification_loss_total += classification_loss.item()
            
            # Calculate accuracy
            _, predicted = torch.max(class_logits, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    avg_loss = val_loss / len(val_loader.dataset)
    avg_recon = recon_loss_total / len(val_loader.dataset)
    avg_kl = kl_loss_total / len(val_loader.dataset)
    avg_class = classification_loss_total / len(val_loader.dataset)
    accuracy = correct / total
    print(f'====> Validation loss: {avg_loss:.4f}, Recon: {avg_recon:.4f}, KL: {avg_kl:.4f}, '
          f'Class: {avg_class:.4f}, Accuracy: {accuracy:.4f}')
    return avg_loss, avg_recon, avg_kl, avg_class, accuracy

best_val_accuracy = 0
best_loss = float('inf')
train_losses, val_losses = [], []
train_recon_losses, val_recon_losses = [], []
train_kl_losses, val_kl_losses = [], []
train_class_losses, val_class_losses = [], []
val_accuracies = []
learning_rates = []

def early_stopping(val_losses, patience):
    if len(val_losses) > patience:
        if all(val_losses[-i-1] <= val_losses[-i] for i in range(1, patience+1)):
            return True
    return False

for epoch in range(1, num_epochs + 1):
    # Training step
    train_loss, train_recon, train_kl, train_class = train_semi_supervised(epoch)
    val_loss, val_recon, val_kl, val_class, val_accuracy = validate_semi_supervised()
    
    # Track losses and accuracy
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_recon_losses.append(train_recon)
    val_recon_losses.append(val_recon)
    train_kl_losses.append(train_kl)
    val_kl_losses.append(val_kl)
    train_class_losses.append(train_class)
    val_class_losses.append(val_class)
    val_accuracies.append(val_accuracy)
    learning_rates.append(optimizer.param_groups[0]['lr'])

    # Scheduler step
    scheduler.step(val_loss)

    # Save best model based on validation loss
    if val_loss < best_loss:
        best_loss = val_loss
        torch.save(model.state_dict(), 'semi_supervised_vae_best_loss.pth')
        print(f"New best model saved with validation loss: {best_loss:.4f}")
    
    # Save best model based on validation accuracy
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        torch.save(model.state_dict(), 'semi_supervised_vae_best_acc.pth')
        print(f"New best model saved with validation accuracy: {best_val_accuracy:.4f}")
    
    # Early stopping
    if early_stopping(val_losses, patience):
        print(f"Early stopping triggered at epoch {epoch}")
        break

print("Training complete.")

# Plot the training and validation loss and learning rate
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))

# Plot training and validation loss
ax1.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
ax1.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
ax1.set_title('Training and Validation Loss over Epochs')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Average Loss')
ax1.legend()

# Plot learning rate
ax2.plot(range(1, len(learning_rates) + 1), learning_rates)
ax2.set_title('Learning Rate over Epochs')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Learning Rate')

# Plot the training and validation reconstruction loss
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(range(1, len(train_recon_losses) + 1), train_recon_losses, label='Training Reconstruction Loss')
ax.plot(range(1, len(val_recon_losses) + 1), val_recon_losses, label='Validation Reconstruction Loss')
ax.set_title('Training and Validation Reconstruction Loss over Epochs')
ax.set_xlabel('Epoch')
ax.set_ylabel('Average Reconstruction Loss')
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Train Epoch: 1 [0/6931 (0%)]	Loss: 16.800140
# Train Epoch: 1 [6400/6931 (92%)]	Loss: 12.125270
# ====> Epoch: 1 Average loss: 20.2395, Recon: 17.2167, KL: 3.0164, Class: 0.0063
# ====> Validation loss: 12.4566, Recon: 9.6822, KL: 2.7689, Class: 0.0055, Accuracy: 0.8627
# New best model saved with validation loss: 12.4566
# New best model saved with validation accuracy: 0.8627
# Train Epoch: 2 [0/6931 (0%)]	Loss: 12.124205
# Train Epoch: 2 [6400/6931 (92%)]	Loss: 9.912365
# ====> Epoch: 2 Average loss: 16.7814, Recon: 13.1130, KL: 3.6630, Class: 0.0054
# ====> Validation loss: 11.0968, Recon: 7.9569, KL: 3.1348, Class: 0.0052, Accuracy: 0.8679
# New best model saved with validation loss: 11.0968
# New best model saved with validation accuracy: 0.8679
# Train Epoch: 3 [0/6931 (0%)]	Loss: 13.566213
# Train Epoch: 3 [6400/6931 (92%)]	Loss: 9.198703
# ====> Epoch: 3 Average loss: 15.6808, Recon: 11.9595, KL: 3.7162, Class: 0.0051
# ====> Validation loss: 11.0022, Recon: 8.4135, KL: 2.5836, Class: 0.0051, Accuracy: 0.8713
# New best model saved with validation loss: 11.0022
# New best model saved with validation accuracy: 0.8713
# Train Epoch: 4 [0/6931 (0%)]	Loss: 13.028609
# Train Epoch: 4 [6400/6931 (92%)]	Loss: 12.261063
# ====> Epoch: 4 Average loss: 14.9063, Recon: 11.1451, KL: 3.7563, Class: 0.0049
# ====> Validation loss: 10.0635, Recon: 6.9950, KL: 3.0636, Class: 0.0049, Accuracy: 0.8857
# New best model saved with validation loss: 10.0635
# New best model saved with validation accuracy: 0.8857
# Train Epoch: 5 [0/6931 (0%)]	Loss: 9.296662
# Train Epoch: 5 [6400/6931 (92%)]	Loss: 8.524343
# ====> Epoch: 5 Average loss: 14.4950, Recon: 10.6621, KL: 3.8282, Class: 0.0048
# ====> Validation loss: 9.6519, Recon: 5.9940, KL: 3.6534, Class: 0.0044, Accuracy: 0.8904
# New best model saved with validation loss: 9.6519
# New best model saved with validation accuracy: 0.8904
# Train Epoch: 6 [0/6931 (0%)]	Loss: 15.271493
# Train Epoch: 6 [6400/6931 (92%)]	Loss: 10.258941
# ====> Epoch: 6 Average loss: 14.0866, Recon: 10.2753, KL: 3.8066, Class: 0.0047
# ====> Validation loss: 9.7953, Recon: 6.0741, KL: 3.7169, Class: 0.0043, Accuracy: 0.8967
# New best model saved with validation accuracy: 0.8967
# Train Epoch: 7 [0/6931 (0%)]	Loss: 11.547922
# Train Epoch: 7 [6400/6931 (92%)]	Loss: 8.944446
# ====> Epoch: 7 Average loss: 13.7079, Recon: 9.8932, KL: 3.8100, Class: 0.0046
# ====> Validation loss: 9.3721, Recon: 5.6970, KL: 3.6706, Class: 0.0044, Accuracy: 0.8996
# New best model saved with validation loss: 9.3721
# New best model saved with validation accuracy: 0.8996
# Train Epoch: 8 [0/6931 (0%)]	Loss: 12.506898
# Train Epoch: 8 [6400/6931 (92%)]	Loss: 9.235975
# ====> Epoch: 8 Average loss: 13.6044, Recon: 9.7842, KL: 3.8158, Class: 0.0044
# ====> Validation loss: 9.2078, Recon: 5.7601, KL: 3.4435, Class: 0.0041, Accuracy: 0.8950
# New best model saved with validation loss: 9.2078
# Train Epoch: 9 [0/6931 (0%)]	Loss: 9.709339
# Train Epoch: 9 [6400/6931 (92%)]	Loss: 10.036367
# ====> Epoch: 9 Average loss: 13.1554, Recon: 9.3418, KL: 3.8093, Class: 0.0043
# ====> Validation loss: 9.1163, Recon: 5.7356, KL: 3.3764, Class: 0.0043, Accuracy: 0.8921
# New best model saved with validation loss: 9.1163
# Train Epoch: 10 [0/6931 (0%)]	Loss: 12.927505
# Train Epoch: 10 [6400/6931 (92%)]	Loss: 8.766436
# ====> Epoch: 10 Average loss: 13.0262, Recon: 9.2392, KL: 3.7827, Class: 0.0044
# ====> Validation loss: 9.5145, Recon: 5.9128, KL: 3.5976, Class: 0.0041, Accuracy: 0.9019
# New best model saved with validation accuracy: 0.9019
# Train Epoch: 11 [0/6931 (0%)]	Loss: 30.932316
# Train Epoch: 11 [6400/6931 (92%)]	Loss: 9.445065
# ====> Epoch: 11 Average loss: 12.8994, Recon: 9.0129, KL: 3.8823, Class: 0.0042
# ====> Validation loss: 8.7448, Recon: 5.3895, KL: 3.3510, Class: 0.0042, Accuracy: 0.9048
# New best model saved with validation loss: 8.7448
# New best model saved with validation accuracy: 0.9048
# Train Epoch: 12 [0/6931 (0%)]	Loss: 7.659486
# Train Epoch: 12 [6400/6931 (92%)]	Loss: 8.187345
# ====> Epoch: 12 Average loss: 12.7754, Recon: 8.9841, KL: 3.7869, Class: 0.0043
# ====> Validation loss: 9.0300, Recon: 5.3089, KL: 3.7172, Class: 0.0039, Accuracy: 0.9065
# New best model saved with validation accuracy: 0.9065
# Train Epoch: 13 [0/6931 (0%)]	Loss: 8.722019
# Train Epoch: 13 [6400/6931 (92%)]	Loss: 9.490959
# ====> Epoch: 13 Average loss: 12.4842, Recon: 8.7030, KL: 3.7769, Class: 0.0044
# ====> Validation loss: 8.5624, Recon: 4.6775, KL: 3.8809, Class: 0.0040, Accuracy: 0.9129
# New best model saved with validation loss: 8.5624
# New best model saved with validation accuracy: 0.9129
# Train Epoch: 14 [0/6931 (0%)]	Loss: 11.444600
# Train Epoch: 14 [6400/6931 (92%)]	Loss: 12.241294
# ====> Epoch: 14 Average loss: 12.3629, Recon: 8.5690, KL: 3.7896, Class: 0.0044
# ====> Validation loss: 8.3391, Recon: 4.9368, KL: 3.3981, Class: 0.0042, Accuracy: 0.9042
# New best model saved with validation loss: 8.3391
# Train Epoch: 15 [0/6931 (0%)]	Loss: 8.567427
# Train Epoch: 15 [6400/6931 (92%)]	Loss: 11.371082
# ====> Epoch: 15 Average loss: 12.1792, Recon: 8.4074, KL: 3.7675, Class: 0.0043
# ====> Validation loss: 8.3403, Recon: 4.8626, KL: 3.4734, Class: 0.0043, Accuracy: 0.8979
# Train Epoch: 16 [0/6931 (0%)]	Loss: 9.745967
# Train Epoch: 16 [6400/6931 (92%)]	Loss: 12.816089
# ====> Epoch: 16 Average loss: 12.1892, Recon: 8.4332, KL: 3.7518, Class: 0.0042
# ====> Validation loss: 8.5056, Recon: 5.0550, KL: 3.4465, Class: 0.0042, Accuracy: 0.9002
# Train Epoch: 17 [0/6931 (0%)]	Loss: 7.756413
# Train Epoch: 17 [6400/6931 (92%)]	Loss: 9.307792
# ====> Epoch: 17 Average loss: 12.1826, Recon: 8.3606, KL: 3.8177, Class: 0.0043
# ====> Validation loss: 8.8867, Recon: 5.0896, KL: 3.7932, Class: 0.0039, Accuracy: 0.9146
# New best model saved with validation accuracy: 0.9146
# Train Epoch: 18 [0/6931 (0%)]	Loss: 8.919995
# Train Epoch: 18 [6400/6931 (92%)]	Loss: 10.908063
# ====> Epoch: 18 Average loss: 11.9600, Recon: 8.2070, KL: 3.7489, Class: 0.0041
# ====> Validation loss: 8.4767, Recon: 5.3372, KL: 3.1352, Class: 0.0042, Accuracy: 0.9106
# Train Epoch: 19 [0/6931 (0%)]	Loss: 19.801125
# Train Epoch: 19 [6400/6931 (92%)]	Loss: 10.011312
# ====> Epoch: 19 Average loss: 11.8489, Recon: 8.1064, KL: 3.7383, Class: 0.0042
# ====> Validation loss: 8.2757, Recon: 4.8806, KL: 3.3910, Class: 0.0041, Accuracy: 0.9031
# New best model saved with validation loss: 8.2757
# Train Epoch: 20 [0/6931 (0%)]	Loss: 8.841509
# Train Epoch: 20 [6400/6931 (92%)]	Loss: 12.867936
# ====> Epoch: 20 Average loss: 11.6429, Recon: 7.9454, KL: 3.6934, Class: 0.0042
# ====> Validation loss: 8.9272, Recon: 5.3369, KL: 3.5863, Class: 0.0040, Accuracy: 0.9117
# Train Epoch: 21 [0/6931 (0%)]	Loss: 12.555073
# Train Epoch: 21 [6400/6931 (92%)]	Loss: 11.827496
# ====> Epoch: 21 Average loss: 11.6496, Recon: 7.9195, KL: 3.7259, Class: 0.0042
# ====> Validation loss: 8.8679, Recon: 5.3139, KL: 3.5500, Class: 0.0040, Accuracy: 0.9013
# Train Epoch: 22 [0/6931 (0%)]	Loss: 16.843918
# Train Epoch: 22 [6400/6931 (92%)]	Loss: 7.867553
# ====> Epoch: 22 Average loss: 11.5068, Recon: 7.7806, KL: 3.7219, Class: 0.0042
# ====> Validation loss: 8.3184, Recon: 5.4478, KL: 2.8663, Class: 0.0042, Accuracy: 0.9008
# Train Epoch: 23 [0/6931 (0%)]	Loss: 8.344221
# Train Epoch: 23 [6400/6931 (92%)]	Loss: 9.757497
# ====> Epoch: 23 Average loss: 11.3700, Recon: 7.6601, KL: 3.7057, Class: 0.0042
# ====> Validation loss: 8.2251, Recon: 4.7887, KL: 3.4325, Class: 0.0039, Accuracy: 0.9088
# New best model saved with validation loss: 8.2251
# Train Epoch: 24 [0/6931 (0%)]	Loss: 8.043007
# Train Epoch: 24 [6400/6931 (92%)]	Loss: 8.979754
# ====> Epoch: 24 Average loss: 11.3946, Recon: 7.7009, KL: 3.6895, Class: 0.0042
# ====> Validation loss: 8.9283, Recon: 5.6603, KL: 3.2636, Class: 0.0044, Accuracy: 0.9025
# Train Epoch: 25 [0/6931 (0%)]	Loss: 9.017040
# Train Epoch: 25 [6400/6931 (92%)]	Loss: 11.436567
# ====> Epoch: 25 Average loss: 11.2186, Recon: 7.4199, KL: 3.7947, Class: 0.0041
# ====> Validation loss: 8.0917, Recon: 4.6402, KL: 3.4475, Class: 0.0041, Accuracy: 0.8996
# New best model saved with validation loss: 8.0917
# Train Epoch: 26 [0/6931 (0%)]	Loss: 8.370863
# Train Epoch: 26 [6400/6931 (92%)]	Loss: 8.116090
# ====> Epoch: 26 Average loss: 11.0570, Recon: 7.3804, KL: 3.6725, Class: 0.0041
# ====> Validation loss: 8.0404, Recon: 4.7293, KL: 3.3072, Class: 0.0039, Accuracy: 0.9083
# New best model saved with validation loss: 8.0404
# Train Epoch: 27 [0/6931 (0%)]	Loss: 8.652020
# Train Epoch: 27 [6400/6931 (92%)]	Loss: 8.843440
# ====> Epoch: 27 Average loss: 10.9976, Recon: 7.3493, KL: 3.6441, Class: 0.0042
# ====> Validation loss: 8.8063, Recon: 5.3708, KL: 3.4317, Class: 0.0038, Accuracy: 0.9175
# New best model saved with validation accuracy: 0.9175
# Train Epoch: 28 [0/6931 (0%)]	Loss: 8.381171
# Train Epoch: 28 [6400/6931 (92%)]	Loss: 9.093246
# ====> Epoch: 28 Average loss: 11.2707, Recon: 7.5449, KL: 3.7217, Class: 0.0041
# ====> Validation loss: 8.6467, Recon: 5.0487, KL: 3.5941, Class: 0.0039, Accuracy: 0.9146
# Train Epoch: 29 [0/6931 (0%)]	Loss: 19.604397
# Train Epoch: 29 [6400/6931 (92%)]	Loss: 8.221148
# ====> Epoch: 29 Average loss: 10.7904, Recon: 7.1533, KL: 3.6330, Class: 0.0041
# ====> Validation loss: 8.1736, Recon: 4.8177, KL: 3.3519, Class: 0.0040, Accuracy: 0.9088
# Train Epoch: 30 [0/6931 (0%)]	Loss: 10.447799
# Train Epoch: 30 [6400/6931 (92%)]	Loss: 8.632773
# ====> Epoch: 30 Average loss: 10.6975, Recon: 7.0408, KL: 3.6526, Class: 0.0041
# ====> Validation loss: 7.7302, Recon: 4.4795, KL: 3.2467, Class: 0.0039, Accuracy: 0.9088
# New best model saved with validation loss: 7.7302
# Train Epoch: 31 [0/6931 (0%)]	Loss: 10.405993
# Train Epoch: 31 [6400/6931 (92%)]	Loss: 13.599301
# ====> Epoch: 31 Average loss: 10.6388, Recon: 7.0420, KL: 3.5926, Class: 0.0042
# ====> Validation loss: 8.2153, Recon: 4.7783, KL: 3.4331, Class: 0.0039, Accuracy: 0.9054
# Train Epoch: 32 [0/6931 (0%)]	Loss: 8.724118
# Train Epoch: 32 [6400/6931 (92%)]	Loss: 8.822384
# ====> Epoch: 32 Average loss: 10.6873, Recon: 7.0725, KL: 3.6108, Class: 0.0040
# ====> Validation loss: 8.4994, Recon: 5.0456, KL: 3.4500, Class: 0.0038, Accuracy: 0.9158
# Train Epoch: 33 [0/6931 (0%)]	Loss: 8.187441
# Train Epoch: 33 [6400/6931 (92%)]	Loss: 8.159519
# ====> Epoch: 33 Average loss: 10.3849, Recon: 6.7345, KL: 3.6462, Class: 0.0041
# ====> Validation loss: 8.2480, Recon: 4.9272, KL: 3.3168, Class: 0.0040, Accuracy: 0.9065
# Train Epoch: 34 [0/6931 (0%)]	Loss: 8.505939
# Train Epoch: 34 [6400/6931 (92%)]	Loss: 10.776691
# ====> Epoch: 34 Average loss: 10.6951, Recon: 7.0457, KL: 3.6453, Class: 0.0042
# ====> Validation loss: 7.9819, Recon: 5.2241, KL: 2.7538, Class: 0.0041, Accuracy: 0.9042
# Train Epoch: 35 [0/6931 (0%)]	Loss: 10.055765
# Train Epoch: 35 [6400/6931 (92%)]	Loss: 10.023846
# ====> Epoch: 35 Average loss: 10.4456, Recon: 6.8485, KL: 3.5930, Class: 0.0041
# ====> Validation loss: 9.4072, Recon: 6.0327, KL: 3.3704, Class: 0.0041, Accuracy: 0.9048
# Train Epoch: 36 [0/6931 (0%)]	Loss: 7.745572
# Train Epoch: 36 [6400/6931 (92%)]	Loss: 7.964829
# ====> Epoch: 36 Average loss: 10.2228, Recon: 6.6483, KL: 3.5703, Class: 0.0042
# ====> Validation loss: 8.1607, Recon: 4.8511, KL: 3.3056, Class: 0.0039, Accuracy: 0.9065
# Train Epoch: 37 [0/6931 (0%)]	Loss: 7.543505
# Train Epoch: 37 [6400/6931 (92%)]	Loss: 7.772689
# ====> Epoch: 37 Average loss: 10.0151, Recon: 6.3480, KL: 3.6631, Class: 0.0040
# ====> Validation loss: 7.7694, Recon: 4.6410, KL: 3.1244, Class: 0.0041, Accuracy: 0.9013
# Train Epoch: 38 [0/6931 (0%)]	Loss: 8.670647
# Train Epoch: 38 [6400/6931 (92%)]	Loss: 9.850331
# ====> Epoch: 38 Average loss: 9.9068, Recon: 6.3415, KL: 3.5613, Class: 0.0041
# ====> Validation loss: 7.9596, Recon: 5.0310, KL: 2.9246, Class: 0.0040, Accuracy: 0.9025
# Train Epoch: 39 [0/6931 (0%)]	Loss: 7.636747
# Train Epoch: 39 [6400/6931 (92%)]	Loss: 10.726449
# ====> Epoch: 39 Average loss: 9.8856, Recon: 6.3698, KL: 3.5117, Class: 0.0040
# ====> Validation loss: 7.6334, Recon: 4.6508, KL: 2.9788, Class: 0.0038, Accuracy: 0.8990
# New best model saved with validation loss: 7.6334
# Train Epoch: 40 [0/6931 (0%)]	Loss: 6.916719
# Train Epoch: 40 [6400/6931 (92%)]	Loss: 8.548965
# ====> Epoch: 40 Average loss: 9.9282, Recon: 6.3290, KL: 3.5952, Class: 0.0040
# ====> Validation loss: 7.5446, Recon: 4.2261, KL: 3.3148, Class: 0.0038, Accuracy: 0.9181
# New best model saved with validation loss: 7.5446
# New best model saved with validation accuracy: 0.9181
# Train Epoch: 41 [0/6931 (0%)]	Loss: 22.851135
# Train Epoch: 41 [6400/6931 (92%)]	Loss: 7.915344
# ====> Epoch: 41 Average loss: 9.9132, Recon: 6.2840, KL: 3.6252, Class: 0.0040
# ====> Validation loss: 7.5133, Recon: 4.2805, KL: 3.2289, Class: 0.0040, Accuracy: 0.9065
# New best model saved with validation loss: 7.5133
# Train Epoch: 42 [0/6931 (0%)]	Loss: 10.335815
# Train Epoch: 42 [6400/6931 (92%)]	Loss: 7.080229
# ====> Epoch: 42 Average loss: 9.8403, Recon: 6.2752, KL: 3.5611, Class: 0.0040
# ====> Validation loss: 8.6321, Recon: 5.5026, KL: 3.1254, Class: 0.0041, Accuracy: 0.9025
# Train Epoch: 43 [0/6931 (0%)]	Loss: 9.931148
# Train Epoch: 43 [6400/6931 (92%)]	Loss: 7.885400
# ====> Epoch: 43 Average loss: 9.6302, Recon: 6.0880, KL: 3.5381, Class: 0.0041
# ====> Validation loss: 8.1414, Recon: 4.7636, KL: 3.3738, Class: 0.0040, Accuracy: 0.9031
# Train Epoch: 44 [0/6931 (0%)]	Loss: 10.290524
# Train Epoch: 44 [6400/6931 (92%)]	Loss: 8.883121
# ====> Epoch: 44 Average loss: 9.6492, Recon: 6.1039, KL: 3.5413, Class: 0.0040
# ====> Validation loss: 8.0969, Recon: 4.7563, KL: 3.3368, Class: 0.0039, Accuracy: 0.9134
# Train Epoch: 45 [0/6931 (0%)]	Loss: 8.865914
# Train Epoch: 45 [6400/6931 (92%)]	Loss: 8.047831
# ====> Epoch: 45 Average loss: 9.7827, Recon: 6.2525, KL: 3.5260, Class: 0.0042
# ====> Validation loss: 8.5638, Recon: 5.2659, KL: 3.2940, Class: 0.0039, Accuracy: 0.9088
# Train Epoch: 46 [0/6931 (0%)]	Loss: 7.276834
# Train Epoch: 46 [6400/6931 (92%)]	Loss: 10.069166
# ====> Epoch: 46 Average loss: 9.6667, Recon: 6.1427, KL: 3.5199, Class: 0.0040
# ====> Validation loss: 7.6966, Recon: 4.7633, KL: 2.9292, Class: 0.0041, Accuracy: 0.9065
# Train Epoch: 47 [0/6931 (0%)]	Loss: 7.403936
# Train Epoch: 47 [6400/6931 (92%)]	Loss: 8.861184
# ====> Epoch: 47 Average loss: 9.5384, Recon: 5.9460, KL: 3.5884, Class: 0.0040
# ====> Validation loss: 7.6578, Recon: 4.3796, KL: 3.2743, Class: 0.0039, Accuracy: 0.9100
# Train Epoch: 48 [0/6931 (0%)]	Loss: 7.033919
# Train Epoch: 48 [6400/6931 (92%)]	Loss: 7.101739
# ====> Epoch: 48 Average loss: 9.4054, Recon: 5.8286, KL: 3.5728, Class: 0.0040
# ====> Validation loss: 7.6589, Recon: 4.3407, KL: 3.3143, Class: 0.0039, Accuracy: 0.9059
# Train Epoch: 49 [0/6931 (0%)]	Loss: 7.380967
# Train Epoch: 49 [6400/6931 (92%)]	Loss: 7.216021
# ====> Epoch: 49 Average loss: 9.4458, Recon: 5.9075, KL: 3.5343, Class: 0.0040
# ====> Validation loss: 7.5065, Recon: 4.4323, KL: 3.0701, Class: 0.0041, Accuracy: 0.9042
# New best model saved with validation loss: 7.5065
# Train Epoch: 50 [0/6931 (0%)]	Loss: 7.068724
# Train Epoch: 50 [6400/6931 (92%)]	Loss: 10.928886
# ====> Epoch: 50 Average loss: 9.3999, Recon: 5.8988, KL: 3.4971, Class: 0.0039
# ====> Validation loss: 7.6419, Recon: 4.7048, KL: 2.9331, Class: 0.0041, Accuracy: 0.9071
# Train Epoch: 51 [0/6931 (0%)]	Loss: 6.881305
# Train Epoch: 51 [6400/6931 (92%)]	Loss: 7.632929
# ====> Epoch: 51 Average loss: 9.4893, Recon: 5.9159, KL: 3.5694, Class: 0.0040
# ====> Validation loss: 8.0725, Recon: 4.7192, KL: 3.3494, Class: 0.0039, Accuracy: 0.9065
# Train Epoch: 52 [0/6931 (0%)]	Loss: 7.942745
# Train Epoch: 52 [6400/6931 (92%)]	Loss: 11.091451
# ====> Epoch: 52 Average loss: 9.3285, Recon: 5.8291, KL: 3.4954, Class: 0.0041
# ====> Validation loss: 8.1597, Recon: 4.9733, KL: 3.1825, Class: 0.0039, Accuracy: 0.9094
# Train Epoch: 53 [0/6931 (0%)]	Loss: 9.276685
# Train Epoch: 53 [6400/6931 (92%)]	Loss: 7.857612
# ====> Epoch: 53 Average loss: 9.3733, Recon: 5.8232, KL: 3.5461, Class: 0.0039
# ====> Validation loss: 7.5236, Recon: 4.1920, KL: 3.3277, Class: 0.0039, Accuracy: 0.9106
# Train Epoch: 54 [0/6931 (0%)]	Loss: 9.989408
# Train Epoch: 54 [6400/6931 (92%)]	Loss: 10.564503
# ====> Epoch: 54 Average loss: 9.3850, Recon: 5.8777, KL: 3.5033, Class: 0.0041
# ====> Validation loss: 7.5568, Recon: 4.2665, KL: 3.2866, Class: 0.0036, Accuracy: 0.9129
# Train Epoch: 55 [0/6931 (0%)]	Loss: 12.029985
# Train Epoch: 55 [6400/6931 (92%)]	Loss: 7.566006
# ====> Epoch: 55 Average loss: 9.2605, Recon: 5.7542, KL: 3.5022, Class: 0.0040
# ====> Validation loss: 7.3523, Recon: 4.2929, KL: 3.0552, Class: 0.0041, Accuracy: 0.9008
# New best model saved with validation loss: 7.3523
# Train Epoch: 56 [0/6931 (0%)]	Loss: 9.156915
# Train Epoch: 56 [6400/6931 (92%)]	Loss: 8.315586
# ====> Epoch: 56 Average loss: 9.2800, Recon: 5.7996, KL: 3.4766, Class: 0.0039
# ====> Validation loss: 7.3143, Recon: 4.3233, KL: 2.9869, Class: 0.0041, Accuracy: 0.9042
# New best model saved with validation loss: 7.3143
# Train Epoch: 57 [0/6931 (0%)]	Loss: 8.781544
# Train Epoch: 57 [6400/6931 (92%)]	Loss: 8.272736
# ====> Epoch: 57 Average loss: 9.2411, Recon: 5.6874, KL: 3.5497, Class: 0.0040
# ====> Validation loss: 7.5908, Recon: 4.0625, KL: 3.5247, Class: 0.0036, Accuracy: 0.9215
# New best model saved with validation accuracy: 0.9215
# Train Epoch: 58 [0/6931 (0%)]	Loss: 7.813383
# Train Epoch: 58 [6400/6931 (92%)]	Loss: 9.404161
# ====> Epoch: 58 Average loss: 9.3579, Recon: 5.8363, KL: 3.5176, Class: 0.0040
# ====> Validation loss: 7.5296, Recon: 4.4840, KL: 3.0417, Class: 0.0039, Accuracy: 0.9042
# Train Epoch: 59 [0/6931 (0%)]	Loss: 9.812462
# Train Epoch: 59 [6400/6931 (92%)]	Loss: 10.440684
# ====> Epoch: 59 Average loss: 9.4411, Recon: 5.9129, KL: 3.5243, Class: 0.0039
# ====> Validation loss: 8.0589, Recon: 5.5112, KL: 2.5434, Class: 0.0043, Accuracy: 0.8956
# Train Epoch: 60 [0/6931 (0%)]	Loss: 6.953945
# Train Epoch: 60 [6400/6931 (92%)]	Loss: 9.754163
# ====> Epoch: 60 Average loss: 9.4394, Recon: 5.9403, KL: 3.4951, Class: 0.0039
# ====> Validation loss: 7.7357, Recon: 4.4330, KL: 3.2987, Class: 0.0040, Accuracy: 0.9106
# Train Epoch: 61 [0/6931 (0%)]	Loss: 8.201692
# Train Epoch: 61 [6400/6931 (92%)]	Loss: 7.649419
# ====> Epoch: 61 Average loss: 9.3034, Recon: 5.7879, KL: 3.5115, Class: 0.0040
# ====> Validation loss: 7.5702, Recon: 4.4821, KL: 3.0843, Class: 0.0039, Accuracy: 0.9100
# Train Epoch: 62 [0/6931 (0%)]	Loss: 7.975960
# Train Epoch: 62 [6400/6931 (92%)]	Loss: 6.878787
# ====> Epoch: 62 Average loss: 9.2890, Recon: 5.7587, KL: 3.5263, Class: 0.0040
# ====> Validation loss: 7.7543, Recon: 4.3997, KL: 3.3507, Class: 0.0038, Accuracy: 0.9123
# Train Epoch: 63 [0/6931 (0%)]	Loss: 8.401369
# Train Epoch: 63 [6400/6931 (92%)]	Loss: 8.536713
# ====> Epoch: 63 Average loss: 9.2450, Recon: 5.7449, KL: 3.4962, Class: 0.0040
# ====> Validation loss: 7.8768, Recon: 4.4572, KL: 3.4157, Class: 0.0039, Accuracy: 0.9129
# Train Epoch: 64 [0/6931 (0%)]	Loss: 8.499760
# Train Epoch: 64 [6400/6931 (92%)]	Loss: 22.920818
# ====> Epoch: 64 Average loss: 9.2194, Recon: 5.7193, KL: 3.4961, Class: 0.0039
# ====> Validation loss: 7.4912, Recon: 4.5567, KL: 2.9306, Class: 0.0039, Accuracy: 0.9031
# Train Epoch: 65 [0/6931 (0%)]	Loss: 8.790850
# Train Epoch: 65 [6400/6931 (92%)]	Loss: 8.064149
# ====> Epoch: 65 Average loss: 9.2745, Recon: 5.7465, KL: 3.5239, Class: 0.0040
# ====> Validation loss: 7.4803, Recon: 4.1831, KL: 3.2933, Class: 0.0038, Accuracy: 0.9117
# Train Epoch: 66 [0/6931 (0%)]	Loss: 9.625346
# Train Epoch: 66 [6400/6931 (92%)]	Loss: 7.929160
# ====> Epoch: 66 Average loss: 9.2518, Recon: 5.7213, KL: 3.5266, Class: 0.0039
# ====> Validation loss: 7.4459, Recon: 4.5387, KL: 2.9034, Class: 0.0038, Accuracy: 0.9083
# Train Epoch: 67 [0/6931 (0%)]	Loss: 8.535325
# Train Epoch: 67 [6400/6931 (92%)]	Loss: 8.281248
# ====> Epoch: 67 Average loss: 9.2946, Recon: 5.7861, KL: 3.5046, Class: 0.0039
# ====> Validation loss: 7.9059, Recon: 4.4866, KL: 3.4155, Class: 0.0038, Accuracy: 0.9129
# Train Epoch: 68 [0/6931 (0%)]	Loss: 9.792614
# Train Epoch: 68 [6400/6931 (92%)]	Loss: 14.005747
# ====> Epoch: 68 Average loss: 9.1704, Recon: 5.6867, KL: 3.4799, Class: 0.0039
# ====> Validation loss: 7.5085, Recon: 4.5068, KL: 2.9977, Class: 0.0039, Accuracy: 0.9071
# Train Epoch: 69 [0/6931 (0%)]	Loss: 8.673863
# Train Epoch: 69 [6400/6931 (92%)]	Loss: 9.944350
# ====> Epoch: 69 Average loss: 9.0637, Recon: 5.5538, KL: 3.5059, Class: 0.0040
# ====> Validation loss: 7.4761, Recon: 4.2880, KL: 3.1843, Class: 0.0037, Accuracy: 0.9088
# Train Epoch: 70 [0/6931 (0%)]	Loss: 7.907053
# Train Epoch: 70 [6400/6931 (92%)]	Loss: 10.142146
# ====> Epoch: 70 Average loss: 9.2125, Recon: 5.7369, KL: 3.4717, Class: 0.0039
# ====> Validation loss: 7.7230, Recon: 4.4373, KL: 3.2821, Class: 0.0037, Accuracy: 0.9152
# Train Epoch: 71 [0/6931 (0%)]	Loss: 13.405067
# Train Epoch: 71 [6400/6931 (92%)]	Loss: 8.175134
# ====> Epoch: 71 Average loss: 9.0459, Recon: 5.5199, KL: 3.5221, Class: 0.0039
# ====> Validation loss: 7.6078, Recon: 4.3983, KL: 3.2058, Class: 0.0037, Accuracy: 0.9065
# Train Epoch: 72 [0/6931 (0%)]	Loss: 9.317949
# Train Epoch: 72 [6400/6931 (92%)]	Loss: 10.775941
# ====> Epoch: 72 Average loss: 9.0784, Recon: 5.6053, KL: 3.4691, Class: 0.0039
# ====> Validation loss: 7.6547, Recon: 4.5186, KL: 3.1323, Class: 0.0038, Accuracy: 0.9077
# Train Epoch: 73 [0/6931 (0%)]	Loss: 9.624184
# Train Epoch: 73 [6400/6931 (92%)]	Loss: 8.358863
# ====> Epoch: 73 Average loss: 9.1478, Recon: 5.6501, KL: 3.4938, Class: 0.0040
# ====> Validation loss: 7.4267, Recon: 4.2688, KL: 3.1541, Class: 0.0038, Accuracy: 0.9106
# Train Epoch: 74 [0/6931 (0%)]	Loss: 7.522166
# Train Epoch: 74 [6400/6931 (92%)]	Loss: 6.976096
# ====> Epoch: 74 Average loss: 9.1932, Recon: 5.7011, KL: 3.4882, Class: 0.0039
# ====> Validation loss: 7.6727, Recon: 4.4192, KL: 3.2497, Class: 0.0038, Accuracy: 0.9140
# Train Epoch: 75 [0/6931 (0%)]	Loss: 7.849751
# Train Epoch: 75 [6400/6931 (92%)]	Loss: 16.514765
# ====> Epoch: 75 Average loss: 9.1563, Recon: 5.6682, KL: 3.4841, Class: 0.0040
# ====> Validation loss: 7.5520, Recon: 4.2483, KL: 3.3000, Class: 0.0037, Accuracy: 0.9163
# Train Epoch: 76 [0/6931 (0%)]	Loss: 8.434632
# Train Epoch: 76 [6400/6931 (92%)]	Loss: 8.590385
# ====> Epoch: 76 Average loss: 9.2615, Recon: 5.7660, KL: 3.4916, Class: 0.0039
# ====> Validation loss: 7.8592, Recon: 5.1145, KL: 2.7404, Class: 0.0043, Accuracy: 0.8996
# Train Epoch: 77 [0/6931 (0%)]	Loss: 8.252630
# Train Epoch: 77 [6400/6931 (92%)]	Loss: 8.698215
# ====> Epoch: 77 Average loss: 9.1884, Recon: 5.6914, KL: 3.4932, Class: 0.0039
# ====> Validation loss: 7.7974, Recon: 5.1331, KL: 2.6599, Class: 0.0043, Accuracy: 0.9036
# Train Epoch: 78 [0/6931 (0%)]	Loss: 7.896851
# Train Epoch: 78 [6400/6931 (92%)]	Loss: 9.775923
# ====> Epoch: 78 Average loss: 9.3136, Recon: 5.7890, KL: 3.5207, Class: 0.0039
# ====> Validation loss: 7.5509, Recon: 4.4451, KL: 3.1020, Class: 0.0037, Accuracy: 0.9094
# Train Epoch: 79 [0/6931 (0%)]	Loss: 11.351240
# Train Epoch: 79 [6400/6931 (92%)]	Loss: 18.005974
# ====> Epoch: 79 Average loss: 9.1813, Recon: 5.6786, KL: 3.4987, Class: 0.0039
# ====> Validation loss: 7.4880, Recon: 4.6427, KL: 2.8412, Class: 0.0040, Accuracy: 0.9054
# Train Epoch: 80 [0/6931 (0%)]	Loss: 11.016581
# Train Epoch: 80 [6400/6931 (92%)]	Loss: 8.317371
# ====> Epoch: 80 Average loss: 9.0316, Recon: 5.5264, KL: 3.5011, Class: 0.0040
# ====> Validation loss: 7.7139, Recon: 4.4126, KL: 3.2976, Class: 0.0037, Accuracy: 0.9123
# Train Epoch: 81 [0/6931 (0%)]	Loss: 7.169880
# Train Epoch: 81 [6400/6931 (92%)]	Loss: 9.082355
# ====> Epoch: 81 Average loss: 9.2996, Recon: 5.8003, KL: 3.4954, Class: 0.0039
# ====> Validation loss: 7.5323, Recon: 4.4579, KL: 3.0705, Class: 0.0039, Accuracy: 0.9013
# Train Epoch: 82 [0/6931 (0%)]	Loss: 7.046193
# Train Epoch: 82 [6400/6931 (92%)]	Loss: 9.118790
# ====> Epoch: 82 Average loss: 9.1774, Recon: 5.6648, KL: 3.5088, Class: 0.0039
# ====> Validation loss: 7.6786, Recon: 4.3262, KL: 3.3488, Class: 0.0036, Accuracy: 0.9198
# Train Epoch: 83 [0/6931 (0%)]	Loss: 9.713131
# Train Epoch: 83 [6400/6931 (92%)]	Loss: 13.862771
# ====> Epoch: 83 Average loss: 9.1536, Recon: 5.6292, KL: 3.5204, Class: 0.0040
# ====> Validation loss: 7.6907, Recon: 4.3767, KL: 3.3104, Class: 0.0037, Accuracy: 0.9175
# Train Epoch: 84 [0/6931 (0%)]	Loss: 13.794695
# Train Epoch: 84 [6400/6931 (92%)]	Loss: 7.886759
# ====> Epoch: 84 Average loss: 9.1873, Recon: 5.6445, KL: 3.5388, Class: 0.0039
# ====> Validation loss: 7.4577, Recon: 4.2176, KL: 3.2363, Class: 0.0039, Accuracy: 0.9111
# Train Epoch: 85 [0/6931 (0%)]	Loss: 11.385825
# Train Epoch: 85 [6400/6931 (92%)]	Loss: 8.145628
# ====> Epoch: 85 Average loss: 9.2483, Recon: 5.7187, KL: 3.5256, Class: 0.0040
# ====> Validation loss: 7.7320, Recon: 4.3951, KL: 3.3332, Class: 0.0038, Accuracy: 0.9198
# Train Epoch: 86 [0/6931 (0%)]	Loss: 7.449350
# Train Epoch: 86 [6400/6931 (92%)]	Loss: 7.238538
# ====> Epoch: 86 Average loss: 9.3551, Recon: 5.8687, KL: 3.4824, Class: 0.0039
# ====> Validation loss: 7.4195, Recon: 4.1496, KL: 3.2662, Class: 0.0036, Accuracy: 0.9169
# Train Epoch: 87 [0/6931 (0%)]	Loss: 6.973949
# Train Epoch: 87 [6400/6931 (92%)]	Loss: 7.163499
# ====> Epoch: 87 Average loss: 9.2195, Recon: 5.6910, KL: 3.5245, Class: 0.0040
# ====> Validation loss: 7.7079, Recon: 4.7878, KL: 2.9161, Class: 0.0040, Accuracy: 0.9054
# Train Epoch: 88 [0/6931 (0%)]	Loss: 7.202398
# Train Epoch: 88 [6400/6931 (92%)]	Loss: 6.377947
# ====> Epoch: 88 Average loss: 9.1067, Recon: 5.5779, KL: 3.5249, Class: 0.0039
# ====> Validation loss: 7.8532, Recon: 4.6252, KL: 3.2239, Class: 0.0041, Accuracy: 0.9054
# Train Epoch: 89 [0/6931 (0%)]	Loss: 8.518962
# Train Epoch: 89 [6400/6931 (92%)]	Loss: 6.828739
# ====> Epoch: 89 Average loss: 9.1288, Recon: 5.6215, KL: 3.5034, Class: 0.0040
# ====> Validation loss: 7.5871, Recon: 4.3926, KL: 3.1909, Class: 0.0036, Accuracy: 0.9152
# Train Epoch: 90 [0/6931 (0%)]	Loss: 8.466143
# Train Epoch: 90 [6400/6931 (92%)]	Loss: 7.204332
# ====> Epoch: 90 Average loss: 9.3123, Recon: 5.7701, KL: 3.5383, Class: 0.0039
# ====> Validation loss: 7.5123, Recon: 4.3759, KL: 3.1325, Class: 0.0038, Accuracy: 0.9129
# Train Epoch: 91 [0/6931 (0%)]	Loss: 9.404961
# Train Epoch: 91 [6400/6931 (92%)]	Loss: 9.905252
# ====> Epoch: 91 Average loss: 9.0462, Recon: 5.5245, KL: 3.5178, Class: 0.0039
# ====> Validation loss: 7.5564, Recon: 4.1331, KL: 3.4197, Class: 0.0036, Accuracy: 0.9175
# Train Epoch: 92 [0/6931 (0%)]	Loss: 8.561891
# Train Epoch: 92 [6400/6931 (92%)]	Loss: 7.526600
# ====> Epoch: 92 Average loss: 9.2530, Recon: 5.7501, KL: 3.4989, Class: 0.0040
# ====> Validation loss: 7.5931, Recon: 4.2735, KL: 3.3158, Class: 0.0038, Accuracy: 0.9111
# Train Epoch: 93 [0/6931 (0%)]	Loss: 8.620131
# Train Epoch: 93 [6400/6931 (92%)]	Loss: 7.375568
# ====> Epoch: 93 Average loss: 9.0233, Recon: 5.5089, KL: 3.5105, Class: 0.0038
# ====> Validation loss: 7.4820, Recon: 4.1695, KL: 3.3087, Class: 0.0038, Accuracy: 0.9152
# Train Epoch: 94 [0/6931 (0%)]	Loss: 15.996266
# Train Epoch: 94 [6400/6931 (92%)]	Loss: 9.108897
# ====> Epoch: 94 Average loss: 9.0869, Recon: 5.5545, KL: 3.5284, Class: 0.0040
# ====> Validation loss: 7.4781, Recon: 4.4532, KL: 3.0209, Class: 0.0040, Accuracy: 0.9002
# Train Epoch: 95 [0/6931 (0%)]	Loss: 13.326781
# Train Epoch: 95 [6400/6931 (92%)]	Loss: 8.041410
# ====> Epoch: 95 Average loss: 9.2656, Recon: 5.7691, KL: 3.4925, Class: 0.0040
# ====> Validation loss: 7.6256, Recon: 4.4251, KL: 3.1967, Class: 0.0038, Accuracy: 0.9123
# Train Epoch: 96 [0/6931 (0%)]	Loss: 7.606492
# Train Epoch: 96 [6400/6931 (92%)]	Loss: 9.754707
# ====> Epoch: 96 Average loss: 9.2774, Recon: 5.7651, KL: 3.5084, Class: 0.0040
# ====> Validation loss: 7.4942, Recon: 4.3797, KL: 3.1106, Class: 0.0039, Accuracy: 0.9134
# Train Epoch: 97 [0/6931 (0%)]	Loss: 9.212233
# Train Epoch: 97 [6400/6931 (92%)]	Loss: 9.730878
# ====> Epoch: 97 Average loss: 9.0785, Recon: 5.5573, KL: 3.5173, Class: 0.0039
# ====> Validation loss: 7.7995, Recon: 4.6843, KL: 3.1114, Class: 0.0038, Accuracy: 0.9042
# Train Epoch: 98 [0/6931 (0%)]	Loss: 7.418927
# Train Epoch: 98 [6400/6931 (92%)]	Loss: 7.436714
# ====> Epoch: 98 Average loss: 9.2313, Recon: 5.7126, KL: 3.5147, Class: 0.0040
# ====> Validation loss: 7.4866, Recon: 4.2128, KL: 3.2701, Class: 0.0037, Accuracy: 0.9158
# Train Epoch: 99 [0/6931 (0%)]	Loss: 7.630681
# Train Epoch: 99 [6400/6931 (92%)]	Loss: 8.576703
# ====> Epoch: 99 Average loss: 9.7454, Recon: 6.2678, KL: 3.4736, Class: 0.0040
# ====> Validation loss: 9.1987, Recon: 6.9940, KL: 2.1999, Class: 0.0048, Accuracy: 0.8823
# Train Epoch: 100 [0/6931 (0%)]	Loss: 8.904516
# Train Epoch: 100 [6400/6931 (92%)]	Loss: 11.910713
# ====> Epoch: 100 Average loss: 9.2592, Recon: 5.7155, KL: 3.5397, Class: 0.0039
# ====> Validation loss: 7.7594, Recon: 4.7466, KL: 3.0087, Class: 0.0041, Accuracy: 0.9025
# Train Epoch: 101 [0/6931 (0%)]	Loss: 9.700175
# Train Epoch: 101 [6400/6931 (92%)]	Loss: 7.928510
# ====> Epoch: 101 Average loss: 9.0755, Recon: 5.5668, KL: 3.5047, Class: 0.0040
# ====> Validation loss: 8.1029, Recon: 5.4738, KL: 2.6248, Class: 0.0043, Accuracy: 0.8927
# Train Epoch: 102 [0/6931 (0%)]	Loss: 9.379544
# Train Epoch: 102 [6400/6931 (92%)]	Loss: 10.110198
# ====> Epoch: 102 Average loss: 8.9557, Recon: 5.4352, KL: 3.5165, Class: 0.0039
# ====> Validation loss: 7.4707, Recon: 4.1861, KL: 3.2809, Class: 0.0038, Accuracy: 0.9071
# Train Epoch: 103 [0/6931 (0%)]	Loss: 6.193236
# Train Epoch: 103 [6400/6931 (92%)]	Loss: 13.514509
# ====> Epoch: 103 Average loss: 9.2078, Recon: 5.7176, KL: 3.4862, Class: 0.0040
# ====> Validation loss: 7.5759, Recon: 4.2901, KL: 3.2821, Class: 0.0038, Accuracy: 0.9129
# Train Epoch: 104 [0/6931 (0%)]	Loss: 7.414254
# Train Epoch: 104 [6400/6931 (92%)]	Loss: 7.702901
# ====> Epoch: 104 Average loss: 9.1613, Recon: 5.6643, KL: 3.4929, Class: 0.0040
# ====> Validation loss: 7.4612, Recon: 4.1801, KL: 3.2773, Class: 0.0038, Accuracy: 0.9158
# Train Epoch: 105 [0/6931 (0%)]	Loss: 8.935200
# Train Epoch: 105 [6400/6931 (92%)]	Loss: 7.273891
# ====> Epoch: 105 Average loss: 9.2958, Recon: 5.7949, KL: 3.4969, Class: 0.0040
# ====> Validation loss: 7.5513, Recon: 4.6611, KL: 2.8861, Class: 0.0041, Accuracy: 0.8996
# Train Epoch: 106 [0/6931 (0%)]	Loss: 12.458855
# Train Epoch: 106 [6400/6931 (92%)]	Loss: 7.863858
# ====> Epoch: 106 Average loss: 9.0839, Recon: 5.5775, KL: 3.5024, Class: 0.0040
# ====> Validation loss: 7.5659, Recon: 4.3447, KL: 3.2173, Class: 0.0039, Accuracy: 0.9117
# Train Epoch: 107 [0/6931 (0%)]	Loss: 7.403043
# Train Epoch: 107 [6400/6931 (92%)]	Loss: 8.937851
# ====> Epoch: 107 Average loss: 9.0965, Recon: 5.5830, KL: 3.5095, Class: 0.0040
# ====> Validation loss: 7.7537, Recon: 4.5905, KL: 3.1595, Class: 0.0037, Accuracy: 0.9140
# Train Epoch: 108 [0/6931 (0%)]	Loss: 34.767075
# Train Epoch: 108 [6400/6931 (92%)]	Loss: 11.830234
# ====> Epoch: 108 Average loss: 9.0582, Recon: 5.5279, KL: 3.5263, Class: 0.0040
# ====> Validation loss: 7.6209, Recon: 4.3487, KL: 3.2685, Class: 0.0037, Accuracy: 0.9158
# Train Epoch: 109 [0/6931 (0%)]	Loss: 7.081164
# Train Epoch: 109 [6400/6931 (92%)]	Loss: 7.166633
# ====> Epoch: 109 Average loss: 9.1723, Recon: 5.6954, KL: 3.4730, Class: 0.0039
# ====> Validation loss: 7.7419, Recon: 4.3770, KL: 3.3610, Class: 0.0039, Accuracy: 0.9158
# Train Epoch: 110 [0/6931 (0%)]	Loss: 8.292305
# Train Epoch: 110 [6400/6931 (92%)]	Loss: 7.879775
# ====> Epoch: 110 Average loss: 9.1134, Recon: 5.6127, KL: 3.4968, Class: 0.0039
# ====> Validation loss: 7.8029, Recon: 5.0240, KL: 2.7748, Class: 0.0042, Accuracy: 0.8944
# Train Epoch: 111 [0/6931 (0%)]	Loss: 10.089433
# Train Epoch: 111 [6400/6931 (92%)]	Loss: 8.660898
# ====> Epoch: 111 Average loss: 9.0849, Recon: 5.5808, KL: 3.5000, Class: 0.0040
# ====> Validation loss: 7.7121, Recon: 4.4462, KL: 3.2621, Class: 0.0039, Accuracy: 0.9204
# Train Epoch: 112 [0/6931 (0%)]	Loss: 7.097393
# Train Epoch: 112 [6400/6931 (92%)]	Loss: 7.833877
# ====> Epoch: 112 Average loss: 9.1623, Recon: 5.6644, KL: 3.4940, Class: 0.0039
# ====> Validation loss: 7.5497, Recon: 4.3043, KL: 3.2417, Class: 0.0037, Accuracy: 0.9048
# Train Epoch: 113 [0/6931 (0%)]	Loss: 8.522855
# Train Epoch: 113 [6400/6931 (92%)]	Loss: 8.070628
# ====> Epoch: 113 Average loss: 9.0571, Recon: 5.5555, KL: 3.4976, Class: 0.0040
# ====> Validation loss: 7.4272, Recon: 4.2495, KL: 3.1737, Class: 0.0040, Accuracy: 0.9036
# Train Epoch: 114 [0/6931 (0%)]	Loss: 8.809597
# Train Epoch: 114 [6400/6931 (92%)]	Loss: 18.374788
# ====> Epoch: 114 Average loss: 9.1415, Recon: 5.5973, KL: 3.5403, Class: 0.0038
# ====> Validation loss: 7.7928, Recon: 4.9997, KL: 2.7888, Class: 0.0042, Accuracy: 0.8967
# Train Epoch: 115 [0/6931 (0%)]	Loss: 8.119328
# Train Epoch: 115 [6400/6931 (92%)]	Loss: 10.937341
# ====> Epoch: 115 Average loss: 9.1880, Recon: 5.6646, KL: 3.5194, Class: 0.0040
# ====> Validation loss: 7.7550, Recon: 4.8771, KL: 2.8740, Class: 0.0039, Accuracy: 0.9036
# Train Epoch: 116 [0/6931 (0%)]	Loss: 7.231391
# Train Epoch: 116 [6400/6931 (92%)]	Loss: 7.497643
# ====> Epoch: 116 Average loss: 9.2302, Recon: 5.7129, KL: 3.5133, Class: 0.0039
# ====> Validation loss: 7.5027, Recon: 4.1787, KL: 3.3201, Class: 0.0039, Accuracy: 0.9042
# Train Epoch: 117 [0/6931 (0%)]	Loss: 9.868119
# Train Epoch: 117 [6400/6931 (92%)]	Loss: 9.127037
# ====> Epoch: 117 Average loss: 9.0649, Recon: 5.5368, KL: 3.5241, Class: 0.0040
# ====> Validation loss: 7.5260, Recon: 4.5816, KL: 2.9405, Class: 0.0039, Accuracy: 0.9163
# Train Epoch: 118 [0/6931 (0%)]	Loss: 6.744526
# Train Epoch: 118 [6400/6931 (92%)]	Loss: 10.518689
# ====> Epoch: 118 Average loss: 9.2225, Recon: 5.7260, KL: 3.4926, Class: 0.0039
# ====> Validation loss: 7.3855, Recon: 4.2806, KL: 3.1011, Class: 0.0038, Accuracy: 0.9036
# Train Epoch: 119 [0/6931 (0%)]	Loss: 11.964593
# Train Epoch: 119 [6400/6931 (92%)]	Loss: 11.137458
# ====> Epoch: 119 Average loss: 9.0740, Recon: 5.5489, KL: 3.5211, Class: 0.0039
# ====> Validation loss: 7.3658, Recon: 4.1799, KL: 3.1821, Class: 0.0038, Accuracy: 0.9077
# Train Epoch: 120 [0/6931 (0%)]	Loss: 8.035567
# Train Epoch: 120 [6400/6931 (92%)]	Loss: 8.880186
# ====> Epoch: 120 Average loss: 9.0538, Recon: 5.5461, KL: 3.5037, Class: 0.0039
# ====> Validation loss: 7.6395, Recon: 4.7533, KL: 2.8824, Class: 0.0039, Accuracy: 0.9054
# Train Epoch: 121 [0/6931 (0%)]	Loss: 9.600294
# Train Epoch: 121 [6400/6931 (92%)]	Loss: 6.651559
# ====> Epoch: 121 Average loss: 9.0601, Recon: 5.5444, KL: 3.5118, Class: 0.0040
# ====> Validation loss: 7.5463, Recon: 4.2346, KL: 3.3080, Class: 0.0037, Accuracy: 0.9146
# Train Epoch: 122 [0/6931 (0%)]	Loss: 8.748020
# Train Epoch: 122 [6400/6931 (92%)]	Loss: 7.977385
# ====> Epoch: 122 Average loss: 9.0564, Recon: 5.5534, KL: 3.4990, Class: 0.0040
# ====> Validation loss: 7.4809, Recon: 4.4821, KL: 2.9949, Class: 0.0039, Accuracy: 0.9071
# Train Epoch: 123 [0/6931 (0%)]	Loss: 16.274092
# Train Epoch: 123 [6400/6931 (92%)]	Loss: 7.043948
# ====> Epoch: 123 Average loss: 9.1795, Recon: 5.6907, KL: 3.4848, Class: 0.0040
# ====> Validation loss: 7.7008, Recon: 4.8243, KL: 2.8727, Class: 0.0038, Accuracy: 0.9129
# Train Epoch: 124 [0/6931 (0%)]	Loss: 7.573999
# Train Epoch: 124 [6400/6931 (92%)]	Loss: 7.057319
# ====> Epoch: 124 Average loss: 9.2111, Recon: 5.7063, KL: 3.5009, Class: 0.0039
# ====> Validation loss: 7.8371, Recon: 4.4844, KL: 3.3487, Class: 0.0039, Accuracy: 0.9071
# Train Epoch: 125 [0/6931 (0%)]	Loss: 8.965337
# Train Epoch: 125 [6400/6931 (92%)]	Loss: 8.927301
# ====> Epoch: 125 Average loss: 9.0668, Recon: 5.5276, KL: 3.5353, Class: 0.0039
# ====> Validation loss: 7.3381, Recon: 4.1501, KL: 3.1842, Class: 0.0037, Accuracy: 0.9111
# Train Epoch: 126 [0/6931 (0%)]	Loss: 7.557213
# Train Epoch: 126 [6400/6931 (92%)]	Loss: 6.592429
# ====> Epoch: 126 Average loss: 9.2133, Recon: 5.7079, KL: 3.5015, Class: 0.0039
# ====> Validation loss: 7.5321, Recon: 4.5091, KL: 3.0191, Class: 0.0039, Accuracy: 0.9094
# Train Epoch: 127 [0/6931 (0%)]	Loss: 6.961568
# Train Epoch: 127 [6400/6931 (92%)]	Loss: 6.682988
# ====> Epoch: 127 Average loss: 9.0356, Recon: 5.5232, KL: 3.5085, Class: 0.0039
# ====> Validation loss: 7.6752, Recon: 4.4489, KL: 3.2227, Class: 0.0036, Accuracy: 0.9186
# Train Epoch: 128 [0/6931 (0%)]	Loss: 8.157368
# Train Epoch: 128 [6400/6931 (92%)]	Loss: 9.431319
# ====> Epoch: 128 Average loss: 9.2735, Recon: 5.7356, KL: 3.5340, Class: 0.0040
# ====> Validation loss: 7.6639, Recon: 4.6325, KL: 3.0275, Class: 0.0040, Accuracy: 0.9042
# Train Epoch: 129 [0/6931 (0%)]	Loss: 6.444685
# Train Epoch: 129 [6400/6931 (92%)]	Loss: 7.513674
# ====> Epoch: 129 Average loss: 9.1555, Recon: 5.6298, KL: 3.5218, Class: 0.0039
# ====> Validation loss: 7.8497, Recon: 4.6163, KL: 3.2296, Class: 0.0038, Accuracy: 0.9146
# Train Epoch: 130 [0/6931 (0%)]	Loss: 6.952115
# Train Epoch: 130 [6400/6931 (92%)]	Loss: 18.324890
# ====> Epoch: 130 Average loss: 9.1207, Recon: 5.6098, KL: 3.5069, Class: 0.0041
# ====> Validation loss: 7.6162, Recon: 4.7612, KL: 2.8512, Class: 0.0037, Accuracy: 0.9059
# Train Epoch: 131 [0/6931 (0%)]	Loss: 8.008727
# Train Epoch: 131 [6400/6931 (92%)]	Loss: 8.614225
# ====> Epoch: 131 Average loss: 9.1700, Recon: 5.6441, KL: 3.5220, Class: 0.0039
# ====> Validation loss: 7.5784, Recon: 4.4118, KL: 3.1627, Class: 0.0039, Accuracy: 0.9059
# Train Epoch: 132 [0/6931 (0%)]	Loss: 6.836878
# Train Epoch: 132 [6400/6931 (92%)]	Loss: 48.385021
# ====> Epoch: 132 Average loss: 9.1097, Recon: 5.5878, KL: 3.5179, Class: 0.0040
# ====> Validation loss: 7.6864, Recon: 4.9056, KL: 2.7766, Class: 0.0042, Accuracy: 0.9048
# Train Epoch: 133 [0/6931 (0%)]	Loss: 7.850571
# Train Epoch: 133 [6400/6931 (92%)]	Loss: 12.697475
# ====> Epoch: 133 Average loss: 9.2191, Recon: 5.7115, KL: 3.5036, Class: 0.0040
# ====> Validation loss: 7.5522, Recon: 4.2820, KL: 3.2663, Class: 0.0039, Accuracy: 0.9083
# Train Epoch: 134 [0/6931 (0%)]	Loss: 9.010394
# Train Epoch: 134 [6400/6931 (92%)]	Loss: 7.821941
# ====> Epoch: 134 Average loss: 9.2628, Recon: 5.7341, KL: 3.5247, Class: 0.0039
# ====> Validation loss: 7.6973, Recon: 4.2936, KL: 3.4000, Class: 0.0037, Accuracy: 0.9181
# Train Epoch: 135 [0/6931 (0%)]	Loss: 8.787167
# Train Epoch: 135 [6400/6931 (92%)]	Loss: 8.375935
# ====> Epoch: 135 Average loss: 9.2105, Recon: 5.6979, KL: 3.5085, Class: 0.0041
# ====> Validation loss: 7.5767, Recon: 4.5592, KL: 3.0135, Class: 0.0040, Accuracy: 0.9111
# Train Epoch: 136 [0/6931 (0%)]	Loss: 13.305859
# Train Epoch: 136 [6400/6931 (92%)]	Loss: 7.600966
# ====> Epoch: 136 Average loss: 9.2162, Recon: 5.7262, KL: 3.4860, Class: 0.0040
# ====> Validation loss: 7.6867, Recon: 4.3110, KL: 3.3720, Class: 0.0038, Accuracy: 0.9186
# Train Epoch: 137 [0/6931 (0%)]	Loss: 7.422233
# Train Epoch: 137 [6400/6931 (92%)]	Loss: 7.260317
# ====> Epoch: 137 Average loss: 9.0070, Recon: 5.4900, KL: 3.5131, Class: 0.0039
# ====> Validation loss: 7.6046, Recon: 4.2805, KL: 3.3205, Class: 0.0036, Accuracy: 0.9186
# Train Epoch: 138 [0/6931 (0%)]	Loss: 10.123131
# Train Epoch: 138 [6400/6931 (92%)]	Loss: 8.921792
# ====> Epoch: 138 Average loss: 9.2138, Recon: 5.7153, KL: 3.4946, Class: 0.0039
# ====> Validation loss: 7.6776, Recon: 4.2764, KL: 3.3975, Class: 0.0036, Accuracy: 0.9140
# Train Epoch: 139 [0/6931 (0%)]	Loss: 7.291476
# Train Epoch: 139 [6400/6931 (92%)]	Loss: 8.035497
# ====> Epoch: 139 Average loss: 9.0358, Recon: 5.5222, KL: 3.5096, Class: 0.0039
# ====> Validation loss: 7.5691, Recon: 4.4391, KL: 3.1260, Class: 0.0040, Accuracy: 0.9094
# Train Epoch: 140 [0/6931 (0%)]	Loss: 8.627075
# Train Epoch: 140 [6400/6931 (92%)]	Loss: 18.041267
# ====> Epoch: 140 Average loss: 9.2653, Recon: 5.7775, KL: 3.4839, Class: 0.0039
# ====> Validation loss: 7.5058, Recon: 4.2692, KL: 3.2326, Class: 0.0040, Accuracy: 0.9100
# Train Epoch: 141 [0/6931 (0%)]	Loss: 9.946256
# Train Epoch: 141 [6400/6931 (92%)]	Loss: 8.699387
# ====> Epoch: 141 Average loss: 9.1693, Recon: 5.6532, KL: 3.5121, Class: 0.0040
# ====> Validation loss: 7.3482, Recon: 4.3179, KL: 3.0264, Class: 0.0040, Accuracy: 0.9117
# Train Epoch: 142 [0/6931 (0%)]	Loss: 8.476682
# Train Epoch: 142 [6400/6931 (92%)]	Loss: 7.133299
# ====> Epoch: 142 Average loss: 9.0056, Recon: 5.4703, KL: 3.5312, Class: 0.0041
# ====> Validation loss: 7.4909, Recon: 4.3004, KL: 3.1867, Class: 0.0038, Accuracy: 0.9146
# Train Epoch: 143 [0/6931 (0%)]	Loss: 6.518011
# Train Epoch: 143 [6400/6931 (92%)]	Loss: 7.322682
# ====> Epoch: 143 Average loss: 8.9790, Recon: 5.4385, KL: 3.5366, Class: 0.0040
# ====> Validation loss: 7.4520, Recon: 4.2603, KL: 3.1878, Class: 0.0039, Accuracy: 0.9106
# Train Epoch: 144 [0/6931 (0%)]	Loss: 7.166206
# Train Epoch: 144 [6400/6931 (92%)]	Loss: 9.069032
# ====> Epoch: 144 Average loss: 9.1922, Recon: 5.6609, KL: 3.5273, Class: 0.0040
# ====> Validation loss: 7.5315, Recon: 4.4371, KL: 3.0906, Class: 0.0038, Accuracy: 0.9134
# Train Epoch: 145 [0/6931 (0%)]	Loss: 7.639254
# Train Epoch: 145 [6400/6931 (92%)]	Loss: 7.219204
# ====> Epoch: 145 Average loss: 9.3384, Recon: 5.8227, KL: 3.5118, Class: 0.0039
# ====> Validation loss: 7.5691, Recon: 4.2001, KL: 3.3653, Class: 0.0038, Accuracy: 0.9146
# Train Epoch: 146 [0/6931 (0%)]	Loss: 8.346614
# Train Epoch: 146 [6400/6931 (92%)]	Loss: 8.195608
# ====> Epoch: 146 Average loss: 9.2322, Recon: 5.7381, KL: 3.4901, Class: 0.0040
# ====> Validation loss: 7.5605, Recon: 4.2909, KL: 3.2657, Class: 0.0038, Accuracy: 0.9065
# Train Epoch: 147 [0/6931 (0%)]	Loss: 8.664241
# Train Epoch: 147 [6400/6931 (92%)]	Loss: 7.032802
# ====> Epoch: 147 Average loss: 9.2115, Recon: 5.6459, KL: 3.5616, Class: 0.0040
# ====> Validation loss: 7.7042, Recon: 4.3011, KL: 3.3993, Class: 0.0039, Accuracy: 0.9100
# Train Epoch: 148 [0/6931 (0%)]	Loss: 9.199248
# Train Epoch: 148 [6400/6931 (92%)]	Loss: 8.346083
# ====> Epoch: 148 Average loss: 9.2849, Recon: 5.7707, KL: 3.5101, Class: 0.0040
# ====> Validation loss: 7.4175, Recon: 4.4930, KL: 2.9207, Class: 0.0039, Accuracy: 0.9083
# Train Epoch: 149 [0/6931 (0%)]	Loss: 7.711047
# Train Epoch: 149 [6400/6931 (92%)]	Loss: 6.161635
# ====> Epoch: 149 Average loss: 9.1244, Recon: 5.6090, KL: 3.5116, Class: 0.0038
# ====> Validation loss: 7.6101, Recon: 4.3890, KL: 3.2175, Class: 0.0036, Accuracy: 0.9117
# Train Epoch: 150 [0/6931 (0%)]	Loss: 7.785755
# Train Epoch: 150 [6400/6931 (92%)]	Loss: 7.983859
# ====> Epoch: 150 Average loss: 9.1910, Recon: 5.6767, KL: 3.5102, Class: 0.0040
# ====> Validation loss: 7.7502, Recon: 4.8982, KL: 2.8481, Class: 0.0040, Accuracy: 0.8996
# Training complete.

# %%
torch.save(model.state_dict(), 'ssfrb_vae_model.pth')

# %%
def get_latent_representations(model, dataloader, device):
    model.eval()
    latent_representations = []
    all_labels = []
    with torch.no_grad():
        for data, labels in dataloader:
            data = data.to(device)
            mu, _ = model.encode(data)
            latent_representations.append(mu.cpu().numpy())
            all_labels.append(labels.numpy())
    return np.concatenate(latent_representations), np.concatenate(all_labels)


def visualize_latent_space_pca(latent_representations, labels, model, device):
    # Perform PCA
    pca = PCA(n_components=2)
    latent_2d = pca.fit_transform(latent_representations)

    # Plot the 2D latent space
    plt.figure(figsize=(12, 10))
    #scatter = plt.scatter(latent_2d[:, 0], latent_2d[:, 1], c=labels, cmap='plasma', s=10)
    sns.scatterplot(x=latent_2d[:, 0], y=latent_2d[:, 1], hue=labels, palette='coolwarm', s=60, alpha=0.8)
    plt.title('PCA of Latent Space Representations')
    plt.xlabel('First Principal Component')
    plt.ylabel('Second Principal Component')
    plt.show()

train_latent, train_labels_np = get_latent_representations(model, train_loader, device)
visualize_latent_space_pca(train_latent, train_labels_np, model, device)

# %%
# Apply K-Means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(train_latent)
train_clusters = kmeans.labels_

# Evaluate Clustering Performance
sil_score = silhouette_score(train_latent, train_clusters)
ari_score = adjusted_rand_score(train_labels_np, train_clusters)
conf_matrix = confusion_matrix(train_labels_np, train_clusters)

print(f"KMeans Silhouette Score: {sil_score:.4f}")
print(f"KMeans Adjusted Rand Index: {ari_score:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# KMeans Silhouette Score: 0.8782
# KMeans Adjusted Rand Index: 0.0136
# Confusion Matrix:
# [[ 944    9]
#  [5978    0]]

# %%
gmm = GaussianMixture(n_components=2, random_state=42)
gmm_clusters = gmm.fit_predict(train_latent)
sil_score = silhouette_score(train_latent, gmm_clusters)
ari_score = adjusted_rand_score(train_labels_np, gmm_clusters)
print(f"GMM Silhouette Score: {sil_score:.4f}")
print(f"GMM Adjusted Rand Index: {ari_score:.4f}")

conf_matrix = confusion_matrix(train_labels_np, gmm_clusters)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# GMM Silhouette Score: 0.8782
# GMM Adjusted Rand Index: 0.0136
# Confusion Matrix:
# [[ 944    9]
#  [5978    0]]

# %%
def svm_on_pca(latent_representations, labels, test_size=0.2, random_state=42):
    pca = PCA(n_components=2)
    latent_pca = pca.fit_transform(latent_representations)
    X_train, X_test, y_train, y_test = train_test_split(latent_pca, labels, test_size=test_size, random_state=random_state)

    svm_model = SVC(kernel='rbf', random_state=random_state)
    svm_model.fit(X_train, y_train)

    # Predict on test set
    y_pred = svm_model.predict(X_test)

    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    plt.figure(figsize=(12, 10))

    sns.scatterplot(x=latent_pca[:, 0], y=latent_pca[:, 1], hue=labels, palette='coolwarm', s=60, alpha=0.8, edgecolor='k')

    # Plot decision boundary
    x_min, x_max = latent_pca[:, 0].min() - 1, latent_pca[:, 0].max() + 1
    y_min, y_max = latent_pca[:, 1].min() - 1, latent_pca[:, 1].max() + 1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 500), np.linspace(y_min, y_max, 500))
    
    Z = svm_model.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, levels=20, cmap="RdBu", alpha=0.6)  # SVM decision boundary
    
    # Titles and labels
    plt.colorbar()
    plt.title('SVM Decision Boundary on t-SNE Latent Space')
    plt.xlabel('t-SNE Component 1')
    plt.ylabel('t-SNE Component 2')
    plt.legend(title='Repeater')

    plt.show()

svm_on_pca(train_latent, train_labels_np, test_size=0.2, random_state=42)
# Out:
# Accuracy: 0.9250
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.49      0.63       184
#            1       0.93      0.99      0.96      1203
#
#     accuracy                           0.93      1387
#    macro avg       0.91      0.74      0.80      1387
# weighted avg       0.92      0.93      0.92      1387

# %%
def svm_on_pca_grid(latent_representations, labels, test_size=0.2, random_state=42):
    pca = PCA(n_components=2)
    latent_pca = pca.fit_transform(latent_representations)
    
    X_train, X_test, y_train, y_test = train_test_split(latent_pca, labels, test_size=test_size, random_state=random_state)
    
    param_grid = {
        'C': [0.1, 1, 10, 100], 
        'gamma': ['scale', 'auto', 0.01, 0.1, 1],
        'kernel': ['rbf', 'linear'] 
    }

    grid_search = GridSearchCV(SVC(random_state=random_state), param_grid, cv=5, verbose=1, n_jobs=-1)
    grid_search.fit(X_train, y_train)

    best_params = grid_search.best_params_
    print(f"Best parameters found: {best_params}")

    best_svm_model = grid_search.best_estimator_
    y_pred = best_svm_model.predict(X_test)

    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    plt.figure(figsize=(12, 10))
    sns.scatterplot(x=latent_pca[:, 0], y=latent_pca[:, 1], hue=labels, palette='coolwarm', s=60, alpha=0.8, edgecolor='k')

    x_min, x_max = latent_pca[:, 0].min() - 1, latent_pca[:, 0].max() + 1
    y_min, y_max = latent_pca[:, 1].min() - 1, latent_pca[:, 1].max() + 1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 500), np.linspace(y_min, y_max, 500))
    
    Z = best_svm_model.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, levels=20, cmap="RdBu", alpha=0.6)
    
    plt.colorbar()
    plt.title('SVM Decision Boundary on PCA Latent Space')
    plt.xlabel('PCA Component 1')
    plt.ylabel('PCA Component 2')
    plt.legend(title='Repeater')

    plt.show()

svm_on_pca_grid(train_latent, train_labels_np, test_size=0.2, random_state=42)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# Best parameters found: {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# Accuracy: 0.9308
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.52      0.66       184
#            1       0.93      0.99      0.96      1203
#
#     accuracy                           0.93      1387
#    macro avg       0.93      0.76      0.81      1387
# weighted avg       0.93      0.93      0.92      1387
